# %%
import requests
from bs4 import BeautifulSoup
from selenium import webdriver
import time
import os
import urllib
import pandas as pd

# %%
class Client:
    SCROLL_PAUSE_TIME = 1
    CHROME_PATH = 'chromedriver.exe'
    
    def __init__(self):
        self.driver = self.create_driver()
           
    def run(self, url: str, scroll: bool, quit: bool) -> BeautifulSoup:
        self.driver.get(url)
        time.sleep(1)
        if scroll:
            self.scroll_down()
        soup = BeautifulSoup(self.driver.page_source, 'lxml')
        if quit:
            self.driver.quit()
        return soup
    
    def create_driver(self):
        self.profile = webdriver.ChromeOptions()
        #profile.add_argument('headless')
        driver = webdriver.Chrome(
            options=self.profile, 
            executable_path=self.CHROME_PATH)
        return driver
    
    def scroll_down(self):
        last_height = self.driver.execute_script("return document.body.scrollHeight")

        while True:
            # Scroll down to bottom
            self.driver.execute_script("window.scrollTo(0, document.body.scrollHeight);")

            # Wait to load page
            time.sleep(SCROLL_PAUSE_TIME)

            # Calculate new scroll height and compare with last scroll height
            new_height = self.driver.execute_script("return document.body.scrollHeight")
            if new_height == last_height:
                break
            last_height = new_height

class Interencheres:
    BASE_URL = 'https://www.interencheres.com'
    SEARCH_URL = '/recherche/lots?search='
    
    def __init__(self, item: str):
        self.client = Client()
        self.url = self.BASE_URL + self.SEARCH_URL + urllib.parse.quote(item)
        self.soup = self.client.run(self.url, True)
    
    def transform(self) -> pd.DataFrame:
        items = self.soup.find('div', class_='results') \
            .find('div', class_='row--dense').find_all('div', class_='col-sm-6')
        lst = []
        for div in items:
            link = BASE_URL + div.find('a')['href'] 
            lot = div.find('span').text
            description = div.find('div', class_='description').text.replace('  ','').replace('\n', '')
            estimation = div.find('div', class_='estimates')
            if estimation:
                estimation = estimation.text.replace('  ','')
            lst += [(description, lot, estimation, link)]
        return pd.DataFrame(lst, columns=['item', 'number', 'estimation', 'link'])
    
class Drouot:
    BASE_URL = 'https://www.drouotonline.com'
    SEARCH_URL = '/recherche/lots?query='
    
    def __init__(self, item: str):
        self.client = Client()
        self.url = self.BASE_URL + self.SEARCH_URL + urllib.parse.quote_plus(item)
        self.soup = self.client.run(self.url, False, False)
        
        # They have pages and not infinite scroll down
        self.nb_items = self.soup.find('div', class_='toolbar').find('h4').text.replace('\n', '').replace('  ', '')
        self.nb_items = int(self.nb_items[:self.nb_items.find('résultats')])
        
        # Iterate trought pages
        self.soups = []
        for i in range(0, nb_items, 50):
            url = self.url + f"&max=50&offset={i}"
            if i == max(range(0, nb_items, 50)):
                self.soups.append(self.client.run(url, False, True))
            else:
                self.soups.append(self.client.run(url, False, False))

    def transform(self) -> pd.DataFrame:
        dfs = []
        for soup in self.soups:
            items = soup.find('div', id='list-lots').find_all('div', class_='lot vsListe')
            lst = []
            for div in items:
                link = str(div.find('div', class_='blog-page').find_all('a')[1])
                link = link[6 + link.find('href="'):link.find('?')]
                link = BASE_URL + link
                dt = div.find('div', class_='infoDateListe').text.replace("\n", "").replace('  ', '')
                description = div.find('div', class_='product-cell').find('h5').text.replace("\n", "").replace('  ', '')
                estimation = div.find('h5', class_='Estimation')
                if estimation:
                    estimation = estimation.text.replace("\n", "").replace('  ', '')
                lst += [(description, description, dt, estimation, link)]
            dfs.append(pd.DataFrame(lst, columns=['item', 'description', 'date', 'estimation', 'link']))
        return pd.concat(dfs)

# %%
interencheres = Interencheres('appareil photo')
df = interencheres.transform()

# %%
drouot = Drouot('appareil photo')
df = drouot.transform()

# %%
df
# Out:
#                                                  item  \
# 0                        Collection d’appareils photo
# 1                          un appareil photo Praktica
# 2                  OLYMPUSAppareil de photo IS - 3000
# 3           KODAK - Appareil photo avec écrin en cuir
# 4   LOT comprenant : un appareil photo AGFA BOX et...
# ..                                                ...
# 47  MINOLTA : appareil photo SR T303 avec quatre o...
# 48  Artiste – Jean Loup SIEFF (1933 2000) – « La f...
# 49  Scratch book et carnets de vol du pilote franc...
# 0   Nungesser, L'oiseau Blanc. Buste en bronze, pa...
# 1       Watchmaking. CAPRIGLIA-MARTINELLI. Two works.
#
#                                           description  \
# 0                        Collection d’appareils photo
# 1                          un appareil photo Praktica
# 2                  OLYMPUSAppareil de photo IS - 3000
# 3           KODAK - Appareil photo avec écrin en cuir
# 4   LOT comprenant : un appareil photo AGFA BOX et...
# ..                                                ...
# 47  MINOLTA : appareil photo SR T303 avec quatre o...
# 48  Artiste – Jean Loup SIEFF (1933 2000) – « La f...
# 49  Scratch book et carnets de vol du pilote franc...
# 0   Nungesser, L'oiseau Blanc. Buste en bronze, pa...
# 1       Watchmaking. CAPRIGLIA-MARTINELLI. Two works.
#
#                                      date                    estimation  \
# 0                  jeudi 04 févr.à- 14:30        Estimation 30 - 50 EUR
# 1                  mardi 09 févr.à- 09:30             Aucune estimation
# 2   Jusqu'audimanche 31 janv.01j03h08m26s        Estimation 30 - 50 EUR
# 3                 samedi 06 févr.à- 14:00        Estimation 10 - 20 EUR
# 4                  lundi 08 févr.à- 13:00        Estimation 10 - 20 EUR
# ..                                    ...                           ...
# 47                 lundi 08 févr.à- 13:00        Estimation 40 - 50 EUR
# 48                 lundi 08 févr.à- 14:00        Estimation 30 - 40 EUR
# 49     Jusqu'aumardi 09 févr.10j01h33m54s      Estimation 140 - 220 EUR
# 0      Jusqu'aumardi 09 févr.10j00h50m22s    Estimation 800 - 1 000 EUR
# 1               mercredi 10 févr.à- 14:00  Estimation 6 000 - 7 000 EUR
#
#                                           link
# 0   https://www.drouotonline.com/lots/14256294
# 1   https://www.drouotonline.com/lots/14239018
# 2   https://www.drouotonline.com/lots/14234000
# 3   https://www.drouotonline.com/lots/14259746
# 4   https://www.drouotonline.com/lots/14243642
# ..                                         ...
# 47  https://www.drouotonline.com/lots/14243907
# 48  https://www.drouotonline.com/lots/14151975
# 49  https://www.drouotonline.com/lots/14171536
# 0   https://www.drouotonline.com/lots/14171449
# 1   https://www.drouotonline.com/lots/14197663
#
# [102 rows x 5 columns]

# %%
df.drop_duplicates()
# Out:
#                                                  item  \
# 0                        Collection d’appareils photo
# 1                          un appareil photo Praktica
# 2                  OLYMPUSAppareil de photo IS - 3000
# 3           KODAK - Appareil photo avec écrin en cuir
# 4   LOT comprenant : un appareil photo AGFA BOX et...
# ..                                                ...
# 47  MINOLTA : appareil photo SR T303 avec quatre o...
# 48  Artiste – Jean Loup SIEFF (1933 2000) – « La f...
# 49  Scratch book et carnets de vol du pilote franc...
# 0   Nungesser, L'oiseau Blanc. Buste en bronze, pa...
# 1       Watchmaking. CAPRIGLIA-MARTINELLI. Two works.
#
#                                           description  \
# 0                        Collection d’appareils photo
# 1                          un appareil photo Praktica
# 2                  OLYMPUSAppareil de photo IS - 3000
# 3           KODAK - Appareil photo avec écrin en cuir
# 4   LOT comprenant : un appareil photo AGFA BOX et...
# ..                                                ...
# 47  MINOLTA : appareil photo SR T303 avec quatre o...
# 48  Artiste – Jean Loup SIEFF (1933 2000) – « La f...
# 49  Scratch book et carnets de vol du pilote franc...
# 0   Nungesser, L'oiseau Blanc. Buste en bronze, pa...
# 1       Watchmaking. CAPRIGLIA-MARTINELLI. Two works.
#
#                                      date                    estimation  \
# 0                  jeudi 04 févr.à- 14:30        Estimation 30 - 50 EUR
# 1                  mardi 09 févr.à- 09:30             Aucune estimation
# 2   Jusqu'audimanche 31 janv.01j03h25m51s        Estimation 30 - 50 EUR
# 3                 samedi 06 févr.à- 14:00        Estimation 10 - 20 EUR
# 4                  lundi 08 févr.à- 13:00        Estimation 10 - 20 EUR
# ..                                    ...                           ...
# 47                 lundi 08 févr.à- 13:00        Estimation 40 - 50 EUR
# 48                 lundi 08 févr.à- 14:00        Estimation 30 - 40 EUR
# 49     Jusqu'aumardi 09 févr.10j01h51m19s      Estimation 140 - 220 EUR
# 0      Jusqu'aumardi 09 févr.10j01h07m47s    Estimation 800 - 1 000 EUR
# 1               mercredi 10 févr.à- 14:00  Estimation 6 000 - 7 000 EUR
#
#                                           link
# 0   https://www.drouotonline.com/lots/14256294
# 1   https://www.drouotonline.com/lots/14239018
# 2   https://www.drouotonline.com/lots/14234000
# 3   https://www.drouotonline.com/lots/14259746
# 4   https://www.drouotonline.com/lots/14243642
# ..                                         ...
# 47  https://www.drouotonline.com/lots/14243907
# 48  https://www.drouotonline.com/lots/14151975
# 49  https://www.drouotonline.com/lots/14171536
# 0   https://www.drouotonline.com/lots/14171449
# 1   https://www.drouotonline.com/lots/14197663
#
# [102 rows x 5 columns]

# %%
chrome = webdriver.Chrome('chromedriver.exe')

# %%
chrome.get('https://www.drouotonline.com/recherche/lots?query=appareil+photo')
soup = BeautifulSoup(chrome.page_source, 'lxml')

# %%
soup
# Out:
# <html class="" lang="fr"><!--<![endif]--><head>
# <meta content="text/html; charset=utf-8" http-equiv="Content-Type"/>
# <meta content="telephone=no" name="format-detection"/>
# <title>Rechercher des lots</title>
# <meta content="enchères, tableaux, design, bijoux, montres, brocante" name="keywords"/>
# <meta content="drouotonline.com" name="author"/>
# <meta content="width=device-width, initial-scale=1.0, maximum-scale=1.0, user-scalable=no" name="viewport"/>
# <meta content="true" name="HandheldFriendly"/>
# <meta content="DrouotDigital" name="copyright"/>
# <meta content="no-cache" http-equiv="cache-Control"/>
# <meta content="no-cache" http-equiv="pragma"/>
# <script async="" src="https://www.google-analytics.com/analytics.js" type="text/javascript"></script><script async="" src="https://www.googletagmanager.com/gtm.js?id=GTM-PN8H4ZT"></script><script>dataLayer = [{"userStatus":"Internaute","lang":"fr","cid":"","contentGroup1":"Recherche","contentGroup2":"","contentGroup3":"","contentGroup4":""}]</script>
# <meta content="text/html; charset=utf-8" http-equiv="Content-Type"/>
# <meta content="main" name="layout"/>
# <meta content="Ventes aux enchères live, online et cataloguée. Découvrez des milliers produits diversifiés : bijoux, meubles, objets d’art, tableaux anciens et contemporains, vins et spiritueux, mode, luminaires, argenterie et bien plus encore !" name="description"/>
# <link href="/assets/owl_carousel/owl.carousel.min-18897fb72e298d3185f39e0052aaa6e0.css" rel="stylesheet" type="text/css"/>
# <link href="/assets/owl_carousel/owl.theme.default-25637daf79c1ad95719bde4dbad877e2.css" rel="stylesheet" type="text/css"/>
# <link href="/en/search/lots" hreflang="en" rel="alternate"/>
# <!-- Preload Link -->
# <link as="font" crossorigin="anonymous" href="/assets/bootstrap/fonts/bootstrap/glyphicons-halflings-regular-fa2772327f55d8198301fdb8bcfc8158.woff" rel="preload" type="font/woff"/>
# <link as="font" crossorigin="anonymous" href="/assets/bootstrap/fonts/bootstrap/glyphicons-halflings-regular-e18bbf611f2a2e43afc071aa2f4e1512.ttf" rel="preload" type="font/ttf"/>
# <link href="/assets/logo/faviconDD-3eab651c594cab93304b374d6c990c83.ico" rel="shortcut icon" type="image/x-icon"/>
# <link href="/assets/mainApplication-d0d0e28c09a5fe69f1a647c0944f6cf2.css" rel="stylesheet"/>
# <!-- Google Tag Manager -->
# <script>
#         (function(w,d,s,l,i){w[l]=w[l]||[];w[l].push({'gtm.start':new Date().getTime(),event:'gtm.js'});var f=d.getElementsByTagName(s)[0],	j=d.createElement(s),dl=l!='dataLayer'?'&l='+l:'';j.async=true;j.src='https://www.googletagmanager.com/gtm.js?id='+i+dl;f.parentNode.insertBefore(j,f);
#         })(window,document,'script','dataLayer','GTM-PN8H4ZT');
#     </script>
# <!-- End Google Tag Manager -->
# <script src="https://cdn.jsdelivr.net/npm/vanilla-lazyload@17.1.2/dist/lazyload.min.js"></script>
# <style type="text/css">.fancybox-margin{margin-right:0px;}</style></head>
# <body class="fr isNormal page-container-bg-solid page-header-menu-fixed device-sm"><div class="wsmenucontainer" style="min-width: 929px;">
# <!-- GTM-NoScript -->
# <noscript><iframe height="0" src="https://www.googletagmanager.com/ns.html?id=GTM-PN8H4ZT" style="display:none;visibility:hidden" width="0"></iframe></noscript>
# <!-- End-GTM-NoScript -->
# <div class="page-wrapper-row">
# <div class="page-wrapper-top">
# <div class="page-header">
# <div class="page-header-menu">
# <div class="container padding0">
# <!-- MOBILE HEADER-->
# <div class="wsmobileheader clearfix">
# <a class="wsanimated-arrow" id="wsnavtoggle"><span></span></a>
# <span class="smllogo">
# <a href="/">
# <div class="logoDrouotDigital"></div>
# </a>
# </span>
# <div class="wssearch clearfix">
# <i class="wsopensearch fa fa-search"></i>
# <div class="wssearchform clearfix">
# <form action="/recherche/lots" class="topmenusearch" id="form-recherche-top">
# <input autofocus="" id="query" name="query" placeholder="Recherche d'objets par mots-clés" tabindex="1" type="text"/>
# <button class="searchMob" onclick="document.forms['form-recherche-top'].submit();" type="submit">
# <i class="fa fa-search"></i></button>
# </form>
# </div>
# </div>
# <!-- ACCES TOP : COMPTE - langue - aide - favoris : hidden-xxs -->
# <div class="accesTop hidden-xs">
# <!-- MON COMPTE -->
# <ul class="nav navbar-nav pull-right" style="z-index:inherit">
# <!-- BEGIN USER LOGIN DROPDOWN -->
# <li class="padding0 dropdown dropdown-user">
# <a class="dsi-modal-link padding0" data-dsi-url="/publicPasseport/publicLoginModal2?redirUri=" data-toggle="modal" href="#modal-content">
# <div class="btn ghost">Connexion</div>
# </a>
# </li>
# </ul>
# <a href="/compte/favoris"><div class="icon fav floatRight"></div></a>
# <a href="/aide?lang=fr"><div class="icon question floatRight"></div></a>
# <div class="floatRight choixLangue">
# <form id="dsi-save-language-form">
# <input id="dsi-redirect-url" name="url" type="hidden" value="/en/search/lots?query=appareil+photo"/>
# <input id="dsi-save-language-url" type="hidden" value="/passeport/saveLanguage"/>
# <select class="dsi-form-elm form-control" id="dsi-language" name="lang" onchange="this.form.submit()">
# <option selected="" value="fr">FR</option>
# <option value="en">EN</option>
# <option value="zh">中文</option>
# </select>
# </form>
# </div>
# </div>
# </div>
# <!-- MOBILE HEADER -->
# <!-- MENU LIGNE 1 : TOP BAR-->
# <div class="col-md-12">
# <div class="col-md-4 noPaddingLeft">
# <a href="/">
# <div class="logoDrouotDigital"></div>
# </a>
# </div>
# <!-- ACCES TOP : COMPTE - langue - aide - favoris -->
# <div class="hidden-xs hidden-sm col-md-4 noPaddingRight floatRight accesTop">
# <!-- MON COMPTE -->
# <ul class="nav navbar-nav pull-right" style="z-index:inherit">
# <!-- BEGIN USER LOGIN DROPDOWN -->
# <li class="padding0 dropdown dropdown-user">
# <a class="dsi-modal-link padding0" data-dsi-url="/publicPasseport/publicLoginModal2?redirUri=" data-toggle="modal" href="#modal-content">
# <div class="btn ghost">Connexion</div>
# </a>
# </li>
# </ul>
# <a href="/compte/favoris"><div class="icon fav floatRight"></div></a>
# <a href="/aide?lang=fr"><div class="icon question floatRight"></div></a>
# <div class="floatRight choixLangue">
# <form id="dsi-save-language-form">
# <input id="dsi-redirect-url" name="url" type="hidden" value="/en/search/lots?query=appareil+photo"/>
# <input id="dsi-save-language-url" type="hidden" value="/passeport/saveLanguage"/>
# <select class="dsi-form-elm form-control" id="dsi-language" name="lang" onchange="this.form.submit()">
# <option selected="" value="fr">FR</option>
# <option value="en">EN</option>
# <option value="zh">中文</option>
# </select>
# </form>
# </div>
# </div>
# <div class="col-sm-4 col-md-3 floatRight noPaddingRight">
# <div class="hidden-xs hidden-sm alignRight font11 search-advanced">
# <a href="/search/searchAdvanced">
# <i aria-hidden="true" class="fa fa-plus-circle marginRight5"></i>Recherche avancée
#             </a>
# </div>
# <nav class="wsmenu clearfix" style="height: 888px;"><div class="overlapblackbg"></div>
# <ul class="wsmenu-list">
# <li class="wssearchbar clearfix">
# <form action="/recherche/lots" class="topmenusearch" id="form-recherche-top">
# <input autofocus="" class="" id="query" name="query" placeholder="Recherche d'objets par mots-clés" tabindex="1" type="text" value=""/>
# <button class="btnstyle" onclick="document.forms['form-recherche-top'].submit();" type="submit">
# <i class="searchicon fa fa-search"></i></button>
# </form>
# </li>
# </ul>
# </nav>
# </div>
# <!-- MENU LIGNE 2 -->
# <div class="headerfull">
# <div class="wsmain clearfix">
# <nav class="wsmenu clearfix" style="height: 888px;"><div class="overlapblackbg"></div>
# <ul class="wsmenu-list">
# <li class="leftlogo mobOnly">
# <a href="/">
# <div class="logoDrouotDigital"></div>
# </a>
# </li>
# <li aria-haspopup="true" class="wssalemain"><span class="wsmenu-click"><i class="wsmenu-arrow"></i></span>
# <a class="navtext" href="/ventes-aux-encheres/futures">
# <span>Ventes aux enchères</span>
# </a>
# <div class="wsmegamenu clearfix halfmenu">
# <div class="container-fluid">
# <div class="row">
# <div class="col-lg-12 padding0">
# <ul class="wstliststy02 clearfix">
# <li>
# <a href="/ventes-aux-encheres/futures">
# <i class="fa fa-angle-right"></i>Toutes les ventes
#                                             </a>
# </li>
# <li>
# <a href="/ventes-aux-encheres/aujourdhui">
# <i class="fa fa-angle-right"></i>Ventes du jour
#                                             </a>
# </li>
# <li>
# <a href="/ventes-aux-encheres/futures?venteType=live">
# <i class="fa fa-angle-right"></i>Ventes Live
#
#                                             </a>
# </li>
# <li>
# <a href="/ventes-aux-encheres/futures?venteType=online">
# <i class="fa fa-angle-right"></i>Ventes Online
#                                             </a>
# </li>
# <li>
# <a href="/ventes-aux-encheres/futures?venteType=live&amp;lieuxExpo=HOTEL-DROUOT">
# <i class="fa fa-angle-right"></i>Ventes à l'Hôtel Drouot
#                                             </a>
# </li>
# </ul>
# </div>
# </div>
# </div>
# </div>
# </li>
# <li aria-haspopup="true" class="wssalemain">
# <a class="navtext" href="/ventes-aux-encheres/futures?venteType=buynow">
# <span>Buy now</span>
# </a>
# </li>
# <div class="wsclear"></div>
# <li aria-haspopup="true" class="wscatmain"><span class="wsmenu-click"><i class="wsmenu-arrow"></i></span>
# <a class="navtext c-cat6" href="/specialites/1055/Arts%20du%20monde?lotGroupTheme=all&amp;offset=0">
# <span>Arts du monde</span></a>
# <div class="wsmegamenu clearfix">
# <div class="container-fluid">
# <div class="row">
# <div class="col-lg-12">
# <ul class="wstliststy02 clearfix" style="padding: 0">
# <li class="wstheading clearfix">
# <a href="/specialites/1055/Arts%20du%20monde?lotGroupTheme=all&amp;offset=0">
#                                                     Arts du monde</a>
# </li>
# </ul>
# </div>
# <div class="col-lg-12">
# <div class="col-sm-12 col-md-5 padding0">
# <ul class="wstliststy02 clearfix">
# <li>
# <a href="/specialites/16/Arch%C3%A9ologie%20-%20Antiquit%C3%A9?lotGroupTheme=all&amp;offset=0">
# <i class="fa fa-angle-right"></i>Archéologie - Antiquité</a>
# </li>
# <li>
# <a href="/specialites/5/Arts%20d%27Afrique%2C%20d%27Am%C3%A9rique%20et%20d%27Oc%C3%A9anie?lotGroupTheme=all&amp;offset=0">
# <i class="fa fa-angle-right"></i>Arts d'Afrique, d'Amérique et d'Océanie</a>
# </li>
# </ul>
# </div>
# <div class="col-sm-12 col-md-3 padding0">
# <ul class="wstliststy02 clearfix">
# <li>
# <a href="/specialites/119/Art%20inuit?lotGroupTheme=all&amp;offset=0">
# <i class="fa fa-angle-right"></i>Art inuit</a>
# </li>
# <li>
# <a href="/specialites/152/Art%20islamique?lotGroupTheme=all&amp;offset=0">
# <i class="fa fa-angle-right"></i>Art islamique</a>
# </li>
# </ul>
# </div>
# <div class="col-sm-12 col-md-2 padding0">
# <ul class="wstliststy02 clearfix">
# <li>
# <a href="/specialites/126/Juda%C3%AFca?lotGroupTheme=all&amp;offset=0">
# <i class="fa fa-angle-right"></i>Judaïca</a>
# </li>
# <li>
# <a href="/specialites/312/Religions?lotGroupTheme=all&amp;offset=0">
# <i class="fa fa-angle-right"></i>Religions</a>
# </li>
# </ul>
# </div>
# <div class="col-sm-12 col-md-2 padding0">
# <ul class="wstliststy02 clearfix">
# <li>
# <a href="/specialites/321/Tableaux%20russes?lotGroupTheme=all&amp;offset=0">
# <i class="fa fa-angle-right"></i>Tableaux russes</a>
# </li>
# </ul>
# </div>
# </div>
# </div>
# </div>
# </div>
# </li>
# <li aria-haspopup="true" class="wscatmain">
# <a class="navtext c-cat5" href="/specialites/43/Arts%20d%27Asie?lotGroupTheme=all&amp;offset=0">
# <span>Arts d'Asie</span></a>
# </li>
# <li aria-haspopup="true" class="wscatmain"><span class="wsmenu-click"><i class="wsmenu-arrow"></i></span>
# <a class="navtext c-cat4" href="/specialites/1053/Luxe%20%26%20Art%20de%20vivre?lotGroupTheme=all&amp;offset=0">
# <span>Luxe &amp; Art de vivre</span></a>
# <div class="wsmegamenu clearfix">
# <div class="container-fluid">
# <div class="row">
# <div class="col-sm-12 col-md-3">
# <ul class="wstliststy02 clearfix">
# <li class="wstheading clearfix">
# <a href="/specialites/1/Bijoux%20et%20pierres%20pr%C3%A9cieuses?lotGroupTheme=all&amp;offset=0">
#                                                     Bijoux et pierres précieuses</a>
# </li>
# <li>
# <a href="/specialites/650/Bagues?lotGroupTheme=all&amp;offset=0">
# <i class="fa fa-angle-right"></i>Bagues</a>
# </li>
# <li>
# <a href="/specialites/657/Bijoux%20homme?lotGroupTheme=all&amp;offset=0">
# <i class="fa fa-angle-right"></i>Bijoux homme</a>
# </li>
# <li>
# <a href="/specialites/651/Boucles%20d%27oreilles?lotGroupTheme=all&amp;offset=0">
# <i class="fa fa-angle-right"></i>Boucles d'oreilles</a>
# </li>
# <li>
# <a href="/specialites/652/Boutons%20de%20manchettes?lotGroupTheme=all&amp;offset=0">
# <i class="fa fa-angle-right"></i>Boutons de manchettes</a>
# </li>
# <li>
# <a href="/specialites/653/Bracelets?lotGroupTheme=all&amp;offset=0">
# <i class="fa fa-angle-right"></i>Bracelets</a>
# </li>
# <li>
# <a href="/specialites/654/Broches%20et%20%C3%A9pingles?lotGroupTheme=all&amp;offset=0">
# <i class="fa fa-angle-right"></i>Broches et épingles</a>
# </li>
# <li>
# <a href="/specialites/655/Colliers%2C%20colliers%20de%20perles%20et%20sautoirs?lotGroupTheme=all&amp;offset=0">
# <i class="fa fa-angle-right"></i>Colliers, colliers de perles et sautoirs</a>
# </li>
# <li>
# <a href="/specialites/658/Pierres%20pr%C3%A9cieuses?lotGroupTheme=all&amp;offset=0">
# <i class="fa fa-angle-right"></i>Pierres précieuses</a>
# </li>
# <li>
# <a href="/specialites/659/Pierres%20fines?lotGroupTheme=all&amp;offset=0">
# <i class="fa fa-angle-right"></i>Pierres fines</a>
# </li>
# <li>
# <a href="/specialites/656/Pendentifs?lotGroupTheme=all&amp;offset=0">
# <i class="fa fa-angle-right"></i>Pendentifs</a>
# </li>
# </ul>
# </div>
# <div class="ccol-sm-12 col-md-3">
# <ul class="wstliststy02 clearfix">
# <li class="wstheading clearfix">
# <a href="/specialites/204/Mode%20et%20vintage?lotGroupTheme=all&amp;offset=0">
#                                                     Mode et vintage</a>
# </li>
# <li>
# <a href="/specialites/695/Ceintures%20et%20accessoires?lotGroupTheme=all&amp;offset=0">
# <i class="fa fa-angle-right"></i>Ceintures et accessoires</a>
# </li>
# <li>
# <a href="/specialites/341/Fourrures?lotGroupTheme=all&amp;offset=0">
# <i class="fa fa-angle-right"></i>Fourrures</a>
# </li>
# <li>
# <a href="/specialites/209/haute-couture?lotGroupTheme=all&amp;offset=0">
# <i class="fa fa-angle-right"></i>Haute couture </a>
# </li>
# <li>
# <a href="/specialites/696/Portefeuilles?lotGroupTheme=all&amp;offset=0">
# <i class="fa fa-angle-right"></i>Portefeuilles</a>
# </li>
# <li>
# <a href="/specialites/697/Sacs%20%C3%A0%20main?lotGroupTheme=all&amp;offset=0">
# <i class="fa fa-angle-right"></i>Sacs à main</a>
# </li>
# <li>
# <a href="/specialites/42/Tapisseries?lotGroupTheme=all&amp;offset=0">
# <i class="fa fa-angle-right"></i>Tapisseries</a>
# </li>
# <li>
# <a href="/specialites/464/Textile%2C%20dentelles%2C%20tissu?lotGroupTheme=all&amp;offset=0">
# <i class="fa fa-angle-right"></i>Textile, dentelles, tissu</a>
# </li>
# <li>
# <a href="/specialites/190/Valises%20et%20malles?lotGroupTheme=all&amp;offset=0">
# <i class="fa fa-angle-right"></i>Valises et malles</a>
# </li>
# <li>
# <a href="/specialites/185/V%C3%AAtements%20et%20mode?lotGroupTheme=all&amp;offset=0">
# <i class="fa fa-angle-right"></i>Vêtements et mode</a>
# </li>
# </ul>
# </div>
# <div class="col-sm-12 col-md-3">
# <ul class="wstliststy02 clearfix">
# <li class="wstheading clearfix">
# <a href="/specialites/622/Montres%20et%20horlogerie?lotGroupTheme=all&amp;offset=0">
#                                                     Montres et horlogerie</a>
# </li>
# <li>
# <a href="/specialites/9/Montres%20bracelet?lotGroupTheme=all&amp;offset=0">
# <i class="fa fa-angle-right"></i>Montres bracelet</a>
# </li>
# <li>
# <a href="/specialites/701/Montres%20gousset%20et%20poche?lotGroupTheme=all&amp;offset=0">
# <i class="fa fa-angle-right"></i>Montres gousset et poche</a>
# </li>
# <li>
# <a href="/specialites/437/Pendules%20et%20garniture%20de%20chemin%C3%A9e?lotGroupTheme=all&amp;offset=0">
# <i class="fa fa-angle-right"></i>Pendules et garniture de cheminée</a>
# </li>
# </ul>
# <ul class="wstliststy02 clearfix">
# <li class="wstheading clearfix">
#
#                                                     Marques de luxe
#                                                     <span class="wstmenutag greentag">nouveau</span>
# </li>
# <li><i class="fa fa-angle-right"></i><a href="/recherche/lots?query=cartier&amp;categorie=1,204">Cartier</a></li>
# <li><i class="fa fa-angle-right"></i><a href="/recherche/lots?query=chanel&amp;categorie=1,204">Chanel</a></li>
# <li><i class="fa fa-angle-right"></i><a href="/recherche/lots?query=hermès&amp;categorie=1,204">Hermès</a></li>
# <li><i class="fa fa-angle-right"></i><a href="/recherche/lots?query=rolex&amp;categorie=622">Rolex</a></li>
# </ul>
# <ul class="wstliststy02 clearfix">
# <li class="wstheading clearfix" style="border-bottom:transparent">
# <a href="/specialites/65/Chevaux%2C%20Equitation?lotGroupTheme=all&amp;offset=0">
#                                                     Chevaux, Equitation</a>
# </li>
# </ul>
# </div>
# <div class="col-sm-12 col-md-3">
# <ul class="wstliststy02 clearfix">
# <li class="wstheading clearfix">
# <a href="/specialites/205/Arts%20de%20la%20table%20et%20argenterie?lotGroupTheme=all&amp;offset=0">
#                                                     Arts de la table et argenterie</a>
# </li>
# <li>
# <a href="/specialites/634/Accessoires%20de%20cuisine?lotGroupTheme=all&amp;offset=0">
# <i class="fa fa-angle-right"></i>Accessoires de cuisine</a>
# </li>
# <li>
# <a href="/specialites/628/Assiettes%20et%20Plats?lotGroupTheme=all&amp;offset=0">
# <i class="fa fa-angle-right"></i>Assiettes et Plats</a>
# </li>
# <li>
# <a href="/specialites/629/M%C3%A9nag%C3%A8res%20et%20Couverts?lotGroupTheme=all&amp;offset=0">
# <i class="fa fa-angle-right"></i>Ménagères et Couverts</a>
# </li>
# <li>
# <a href="/specialites/631/Pi%C3%A8ces%20de%20forme?lotGroupTheme=all&amp;offset=0">
# <i class="fa fa-angle-right"></i>Pièces de forme</a>
# </li>
# <li>
# <a href="/specialites/632/Services%20de%20table?lotGroupTheme=all&amp;offset=0">
# <i class="fa fa-angle-right"></i>Services de table</a>
# </li>
# <li>
# <a href="/specialites/194/Verres%2C%20carafes%20et%20caves%20%C3%A0%20liqueur?lotGroupTheme=all&amp;offset=0">
# <i class="fa fa-angle-right"></i>Verres, carafes et caves à liqueur</a>
# </li>
# </ul>
# <ul class="wstliststy02 clearfix">
# <li class="wstheading clearfix">
# <a href="/specialites/187/Vins%20et%20Spiritueux?lotGroupTheme=all&amp;offset=0">
#                                                     Vins et Spiritueux</a>
# </li>
# <li>
# <a href="/specialites/724/Bi%C3%A8re?lotGroupTheme=all&amp;offset=0">
# <i class="fa fa-angle-right"></i>Bière</a>
# </li>
# <li>
# <a href="/specialites/358/Champagne?lotGroupTheme=all&amp;offset=0">
# <i class="fa fa-angle-right"></i>Champagne</a>
# </li>
# <li>
# <a href="/specialites/727/Vin%20et%20pineau?lotGroupTheme=all&amp;offset=0">
# <i class="fa fa-angle-right"></i>Vin et pineau</a>
# </li>
# <li>
# <a href="/specialites/726/Whisky%2C%20rhum%20et%20cognac?lotGroupTheme=all&amp;offset=0">
# <i class="fa fa-angle-right"></i>Whisky, rhum et cognac</a>
# </li>
# </ul>
# </div>
# </div>
# </div>
# </div>
# </li>
# <li aria-haspopup="true" class="wscatmain"><span class="wsmenu-click"><i class="wsmenu-arrow"></i></span>
# <a class="navtext c-cat3" href="/specialites/1052/Collections?lotGroupTheme=all&amp;offset=0">
# <span>Collections</span></a>
# <div class="wsmegamenu clearfix">
# <div class="container-fluid">
# <div class="row">
# <div class="col-sm-12 col-md-5">
# <ul class="wstliststy02 clearfix">
# <li class="wstheading clearfix">
# <a href="/specialites/206/Objets%20de%20collection?lotGroupTheme=all&amp;offset=0">
#                                                     Objets de collection</a>
# </li>
# <li>
# <a href="/specialites/363/Animalia%20et%20taxidermie?lotGroupTheme=all&amp;offset=0">
# <i class="fa fa-angle-right"></i>Animalia et taxidermie</a>
# </li>
# <li>
# <a href="/specialites/711/Appareils%20photo%2C%20cam%C3%A9ras%20et%20t%C3%A9l%C3%A9viseurs?lotGroupTheme=all&amp;offset=0">
# <i class="fa fa-angle-right"></i>Appareils photo, caméras et téléviseurs</a>
# </li>
# <li>
# <a href="/specialites/132/cannes?lotGroupTheme=all&amp;offset=0">
# <i class="fa fa-angle-right"></i>Cannes </a>
# </li>
# <li>
# <a href="/specialites/49/Flacons%20et%20parfums?lotGroupTheme=all&amp;offset=0">
# <i class="fa fa-angle-right"></i>Flacons et parfums</a>
# </li>
# <li>
# <a href="/specialites/74/Histoire%20Naturelle?lotGroupTheme=all&amp;offset=0">
# <i class="fa fa-angle-right"></i>Histoire Naturelle</a>
# </li>
# <li>
# <a href="/specialites/133/Instruments%20scientifiques?lotGroupTheme=all&amp;offset=0">
# <i class="fa fa-angle-right"></i>Instruments scientifiques</a>
# </li>
# <li>
# <a href="/specialites/707/Musique?lotGroupTheme=all&amp;offset=0">
# <i class="fa fa-angle-right"></i>Musique</a>
# </li>
# <li>
# <a href="/specialites/273/Panneaux%20publicitaires%20et%20plaques%20%C3%A9maill%C3%A9es?lotGroupTheme=all&amp;offset=0">
# <i class="fa fa-angle-right"></i>Panneaux publicitaires et plaques émaillées</a>
# </li>
# <li>
# <a href="/specialites/82/Pipes%2C%20briquets%20et%20univers%20du%20tabac?lotGroupTheme=all&amp;offset=0">
# <i class="fa fa-angle-right"></i>Pipes, briquets et univers du tabac</a>
# </li>
# <li>
# <a href="/specialites/712/Stylos%2C%20presse-papiers%20et%20encriers?lotGroupTheme=all&amp;offset=0">
# <i class="fa fa-angle-right"></i>Stylos, presse-papiers et encriers</a>
# </li>
# <li>
# <a href="/specialites/36/Timbres?lotGroupTheme=all&amp;offset=0">
# <i class="fa fa-angle-right"></i>Timbres</a>
# </li>
# <li>
# <a href="/specialites/714/Voitures%2C%20v%C3%A9los%20et%20autres?lotGroupTheme=all&amp;offset=0">
# <i class="fa fa-angle-right"></i>Voitures, vélos et autres</a>
# </li>
# </ul>
# </div>
# <div class="col-sm-12 col-md-7">
# <div class="col-sm-12 col-md-6 noPaddingLeft">
# <ul class="wstliststy02 clearfix">
# <li class="wstheading clearfix">
# <a href="/specialites/203/Livres%20et%20Manuscrits?lotGroupTheme=all&amp;offset=0">
#                                                         Livres et Manuscrits</a>
# </li>
# <li>
# <a href="/specialites/27/Bandes%20dessin%C3%A9es?lotGroupTheme=all&amp;offset=0">
# <i class="fa fa-angle-right"></i>Bandes dessinées</a>
# </li>
# <li>
# <a href="/specialites/352/Cartes%20de%20g%C3%A9ographie?lotGroupTheme=all&amp;offset=0">
# <i class="fa fa-angle-right"></i>Cartes de géographie</a>
# </li>
# <li>
# <a href="/specialites/46/Cartes%20postales?lotGroupTheme=all&amp;offset=0">
# <i class="fa fa-angle-right"></i>Cartes postales</a>
# </li>
# <li>
# <a href="/specialites/665/lettres-et-autographes?lotGroupTheme=all&amp;offset=0">
# <i class="fa fa-angle-right"></i>Lettres et autographes </a>
# </li>
# <li>
# <a href="/specialites/203/Livres%20et%20Manuscrits?lotGroupTheme=all&amp;offset=0">
# <i class="fa fa-angle-right"></i>Livres et Manuscrits</a>
# </li>
# <li>
# <a href="/specialites/765/Livres%20religieux?lotGroupTheme=all&amp;offset=0">
# <i class="fa fa-angle-right"></i>Livres religieux</a>
# </li>
# </ul>
# </div>
# <div class="col-sm-12 col-md-6 noPaddingLeft">
# <ul class="wstliststy02 clearfix">
# <li class="wstheading clearfix">
# <a href="/specialites/26/Armes%2C%20chasse%20et%20militaria?lotGroupTheme=all&amp;offset=0">
#                                                         Armes, chasse et militaria</a>
# </li>
# <li>
# <a href="/specialites/671/Armes?lotGroupTheme=all&amp;offset=0">
# <i class="fa fa-angle-right"></i>Armes</a>
# </li>
# <li>
# <a href="/specialites/672/Casques%20et%20uniformes?lotGroupTheme=all&amp;offset=0">
# <i class="fa fa-angle-right"></i>Casques et uniformes</a>
# </li>
# <li>
# <a href="/specialites/282/Chasse%20%28sur%20le%20th%C3%A8me%20de%29?lotGroupTheme=all&amp;offset=0">
# <i class="fa fa-angle-right"></i>Chasse (sur le thème de)</a>
# </li>
# <li>
# <a href="/specialites/674/Drapeaux%20et%20troph%C3%A9es?lotGroupTheme=all&amp;offset=0">
# <i class="fa fa-angle-right"></i>Drapeaux et trophées</a>
# </li>
# <li>
# <a href="/specialites/675/Souvenirs%20historiques?lotGroupTheme=all&amp;offset=0">
# <i class="fa fa-angle-right"></i>Souvenirs historiques</a>
# </li>
# <li>
# <a href="/specialites/325/M%C3%A9dailles%20et%20insignes?lotGroupTheme=all&amp;offset=0">
# <i class="fa fa-angle-right"></i>Médailles et insignes</a>
# </li>
# </ul>
# </div>
# <div class="col-sm-12 col-md-6 noPaddingLeft">
# <ul class="wstliststy02 clearfix">
# <li class="wstheading clearfix">
# <a href="/specialites/615/Jouets%20et%20maquettes?lotGroupTheme=all&amp;offset=0">
#                                                         Jouets et maquettes</a>
# </li>
# <li>
# <a href="/specialites/371/Jeux%20de%20soci%C3%A9t%C3%A9?lotGroupTheme=all&amp;offset=0">
# <i class="fa fa-angle-right"></i>Jeux de société</a>
# </li>
# <li>
# <a href="/specialites/661/Jeux?lotGroupTheme=all&amp;offset=0">
# <i class="fa fa-angle-right"></i>Jeux</a>
# </li>
# <li>
# <a href="/specialites/660/Maquettes%20et%20mod%C3%A8les%20r%C3%A9duits?lotGroupTheme=all&amp;offset=0">
# <i class="fa fa-angle-right"></i>Maquettes et modèles réduits</a>
# </li>
# <li>
# <a href="/specialites/662/Poup%C3%A9es%2C%20peluches%20et%20jouets?lotGroupTheme=all&amp;offset=0">
# <i class="fa fa-angle-right"></i>Poupées, peluches et jouets</a>
# </li>
# </ul>
# </div>
# <div class="col-sm-12 col-md-6 noPaddingLeft">
# <ul class="wstliststy02 clearfix">
# <li class="wstheading clearfix">
# <a href="/specialites/14/Numismatique?lotGroupTheme=all&amp;offset=0">
#                                                         Numismatique</a>
# </li>
# <li>
# <a href="/specialites/700/lingots?lotGroupTheme=all&amp;offset=0">
# <i class="fa fa-angle-right"></i>Lingots </a>
# </li>
# <li>
# <a href="/specialites/699/Pi%C3%A8ces%20et%20billets?lotGroupTheme=all&amp;offset=0">
# <i class="fa fa-angle-right"></i>Pièces et billets</a>
# </li>
# </ul>
# </div>
# </div>
# </div>
# </div>
# </div>
# </li>
# <li aria-haspopup="true" class="wscatmain"><span class="wsmenu-click"><i class="wsmenu-arrow"></i></span>
# <a class="navtext c-cat2" href="/specialites/1051/Mobilier%20%26%20Objets%20d%27art?lotGroupTheme=all&amp;offset=0">
# <span>Mobilier &amp; Objets d'art</span></a>
# <div class="wsmegamenu clearfix">
# <div class="container-fluid">
# <div class="row">
# <div class="col-sm-12 col-md-3">
# <ul class="wstliststy02 clearfix">
# <li class="wstheading clearfix">
# <a href="/specialites/199/Mobilier?lotGroupTheme=all&amp;offset=0">
#                                                     Mobilier</a>
# </li>
# <li>
# <a href="/specialites/677/Biblioth%C3%A8ques?lotGroupTheme=all&amp;offset=0">
# <i class="fa fa-angle-right"></i>Bibliothèques</a>
# </li>
# <li>
# <a href="/specialites/678/Buffets%20et%20enfilades?lotGroupTheme=all&amp;offset=0">
# <i class="fa fa-angle-right"></i>Buffets et enfilades</a>
# </li>
# <li>
# <a href="/specialites/679/Bureaux?lotGroupTheme=all&amp;offset=0">
# <i class="fa fa-angle-right"></i>Bureaux</a>
# </li>
# <li>
# <a href="/specialites/682/Coffres?lotGroupTheme=all&amp;offset=0">
# <i class="fa fa-angle-right"></i>Coffres</a>
# </li>
# <li>
# <a href="/specialites/684/Consoles%20et%20encoignures?lotGroupTheme=all&amp;offset=0">
# <i class="fa fa-angle-right"></i>Consoles et encoignures</a>
# </li>
# <li>
# <a href="/specialites/691/Ensembles%20de%20mobilier?lotGroupTheme=all&amp;offset=0">
# <i class="fa fa-angle-right"></i>Ensembles de mobilier</a>
# </li>
# <li>
# <a href="/specialites/686/Lits?lotGroupTheme=all&amp;offset=0">
# <i class="fa fa-angle-right"></i>Lits</a>
# </li>
# <li>
# <a href="/specialites/687/Paravents?lotGroupTheme=all&amp;offset=0">
# <i class="fa fa-angle-right"></i>Paravents</a>
# </li>
# <li>
# <a href="/specialites/689/Tables?lotGroupTheme=all&amp;offset=0">
# <i class="fa fa-angle-right"></i>Tables</a>
# </li>
# </ul>
# </div>
# <div class="col-sm-12 col-md-3">
# <ul class="wstliststy02 clearfix">
# <li class="wstheading clearfix">
# <a href="/specialites/230/Objets%20d%27Art?lotGroupTheme=all&amp;offset=0">
#                                                     Objets d'Art</a>
# </li>
# <li>
# <a href="/specialites/67/Cadres%20anciens%20et%20modernes?lotGroupTheme=all&amp;offset=0">
# <i class="fa fa-angle-right"></i>Cadres anciens et modernes</a>
# </li>
# <li>
# <a href="/specialites/153/C%C3%A9ramiques?lotGroupTheme=all&amp;offset=0">
# <i class="fa fa-angle-right"></i>Céramiques</a>
# </li>
# <li>
# <a href="/specialites/637/Coffrets%20et%20bo%C3%AEtes?lotGroupTheme=all&amp;offset=0">
# <i class="fa fa-angle-right"></i>Coffrets et boîtes</a>
# </li>
# <li>
# <a href="/specialites/37/Objets%20de%20vitrine?lotGroupTheme=all&amp;offset=0">
# <i class="fa fa-angle-right"></i>Objets de vitrine</a>
# </li>
# <li>
# <a href="/specialites/638/Miroirs?lotGroupTheme=all&amp;offset=0">
# <i class="fa fa-angle-right"></i>Miroirs</a>
# </li>
# <li>
# <a href="/specialites/41/Tapis?lotGroupTheme=all&amp;offset=0">
# <i class="fa fa-angle-right"></i>Tapis</a>
# </li>
# <li>
# <a href="/specialites/643/Vases?lotGroupTheme=all&amp;offset=0">
# <i class="fa fa-angle-right"></i>Vases</a>
# </li>
# </ul>
# </div>
# <div class="col-sm-12 col-md-3">
# <ul class="wstliststy02 clearfix">
# <li class="wstheading clearfix">
# <a href="/specialites/617/Luminaires?lotGroupTheme=all&amp;offset=0">
#                                                     Luminaires</a>
# </li>
# <li>
# <a href="/specialites/666/Appliques?lotGroupTheme=all&amp;offset=0">
# <i class="fa fa-angle-right"></i>Appliques</a>
# </li>
# <li>
# <a href="/specialites/667/Chandeliers%2C%20flambeaux%20et%20cand%C3%A9labres?lotGroupTheme=all&amp;offset=0">
# <i class="fa fa-angle-right"></i>Chandeliers, flambeaux et candélabres</a>
# </li>
# <li>
# <a href="/specialites/668/Lampadaire?lotGroupTheme=all&amp;offset=0">
# <i class="fa fa-angle-right"></i>Lampadaire</a>
# </li>
# <li>
# <a href="/specialites/669/Lampes%20et%20lanternes?lotGroupTheme=all&amp;offset=0">
# <i class="fa fa-angle-right"></i>Lampes et lanternes</a>
# </li>
# <li>
# <a href="/specialites/670/Lustres%20et%20suspensions?lotGroupTheme=all&amp;offset=0">
# <i class="fa fa-angle-right"></i>Lustres et suspensions</a>
# </li>
# </ul>
# </div>
# <div class="col-sm-12 col-md-3">
# <ul class="wstliststy02 clearfix">
# <li class="wstheading clearfix">
# <a href="/specialites/625/Si%C3%A8ges?lotGroupTheme=all&amp;offset=0">
#                                                     Sièges</a>
# </li>
# <li>
# <a href="/specialites/717/Berg%C3%A8res?lotGroupTheme=all&amp;offset=0">
# <i class="fa fa-angle-right"></i>Bergères</a>
# </li>
# <li>
# <a href="/specialites/718/Chaises?lotGroupTheme=all&amp;offset=0">
# <i class="fa fa-angle-right"></i>Chaises</a>
# </li>
# <li>
# <a href="/specialites/716/Canap%C3%A9s%20et%20banquettes?lotGroupTheme=all&amp;offset=0">
# <i class="fa fa-angle-right"></i>Canapés et banquettes</a>
# </li>
# <li>
# <a href="/specialites/719/Fauteuils?lotGroupTheme=all&amp;offset=0">
# <i class="fa fa-angle-right"></i>Fauteuils</a>
# </li>
# <li>
# <a href="/specialites/720/Tabourets?lotGroupTheme=all&amp;offset=0">
# <i class="fa fa-angle-right"></i>Tabourets</a>
# </li>
# </ul>
# </div>
# </div>
# </div>
# </div>
# </li>
# <li aria-haspopup="true" class="wscatmain"><span class="wsmenu-click"><i class="wsmenu-arrow"></i></span>
# <a class="navtext c-cat1" href="/specialites/1050/Beaux%20Arts?lotGroupTheme=all&amp;offset=0">
# <span>Beaux Arts</span></a>
# <div class="wsmegamenu clearfix">
# <div class="container-fluid">
# <div class="row">
# <div class="col-sm-12 col-md-5">
# <ul class="wstliststy02 clearfix">
# <li class="wstheading clearfix">
# <a href="/specialites/626/Tableaux?lotGroupTheme=all&amp;offset=0">
#                                                     Tableaux</a>
# </li>
# <li>
# <a href="/specialites/30/Ic%C3%B4nes?lotGroupTheme=all&amp;offset=0">
# <i class="fa fa-angle-right"></i>Icônes</a>
# </li>
# <li>
# <a href="/specialites/156/Tableaux%20anciens%20%28avant%201870%29?lotGroupTheme=all&amp;offset=0">
# <i class="fa fa-angle-right"></i>Tableaux anciens (avant 1870)</a>
# </li>
# <li>
# <a href="/specialites/39/Tableaux%20impressionnistes%20et%20modernes?lotGroupTheme=all&amp;offset=0">
# <i class="fa fa-angle-right"></i>Tableaux impressionnistes et modernes</a>
# </li>
# <li>
# <a href="/specialites/75/Tableaux%20apr%C3%A8s%20guerre%20et%20contemporains?lotGroupTheme=all&amp;offset=0">
# <i class="fa fa-angle-right"></i>Tableaux après guerre et contemporains</a>
# </li>
# </ul>
# </div>
# <div class="col-sm-12 col-md-3">
# <ul class="wstliststy02 clearfix">
# <li class="wstheading clearfix">
# <a href="/specialites/164/Arts%20graphiques?lotGroupTheme=all&amp;offset=0">
#                                                     Arts graphiques</a>
# </li>
# <li>
# <a href="/specialites/25/Affiches?lotGroupTheme=all&amp;offset=0">
# <i class="fa fa-angle-right"></i>Affiches</a>
# </li>
# <li>
# <a href="/specialites/310/Aquarelles?lotGroupTheme=all&amp;offset=0">
# <i class="fa fa-angle-right"></i>Aquarelles</a>
# </li>
# <li>
# <a href="/specialites/50/Lithographies?lotGroupTheme=all&amp;offset=0">
# <i class="fa fa-angle-right"></i>Lithographies</a>
# </li>
# <li>
# <a href="/specialites/28/%C5%92uvres%20sur%20papier?lotGroupTheme=all&amp;offset=0">
# <i class="fa fa-angle-right"></i>Œuvres sur papier</a>
# </li>
# <li>
# <a href="/specialites/21/Photographies?lotGroupTheme=all&amp;offset=0">
# <i class="fa fa-angle-right"></i>Photographies</a>
# </li>
# <li>
# <a href="/specialites/234/Street%20Art%2C%20graffiti?lotGroupTheme=all&amp;offset=0">
# <i class="fa fa-angle-right"></i>Street Art, graffiti</a>
# </li>
# </ul>
# </div>
# <div class="col-sm-12 col-md-4">
# <ul class="wstliststy02 clearfix">
# <li class="wstheading clearfix">
# <a href="/specialites/40/Sculptures%2C%20marbres%20et%20bronzes?lotGroupTheme=all&amp;offset=0">
#                                                     Sculptures, marbres et bronzes</a>
# </li>
# <li>
# <a href="/specialites/635/Bronzes?lotGroupTheme=all&amp;offset=0">
# <i class="fa fa-angle-right"></i>Bronzes</a>
# </li>
# <li>
# <a href="/specialites/803/Sculptures%20en%20bois?lotGroupTheme=all&amp;offset=0">
# <i class="fa fa-angle-right"></i>Sculptures en bois</a>
# </li>
# <li>
# <a href="/specialites/800/Sculptures%20en%20marbre?lotGroupTheme=all&amp;offset=0">
# <i class="fa fa-angle-right"></i>Sculptures en marbre</a>
# </li>
# <li>
# <a href="/specialites/801/Sculptures%20en%20pl%C3%A2tre?lotGroupTheme=all&amp;offset=0">
# <i class="fa fa-angle-right"></i>Sculptures en plâtre</a>
# </li>
# <li>
# <a href="/specialites/802/Sculptures%20en%20terre%20cuite?lotGroupTheme=all&amp;offset=0">
# <i class="fa fa-angle-right"></i>Sculptures en terre cuite</a>
# </li>
# </ul>
# </div>
# </div>
# </div>
# </div>
# </li>
# <li aria-haspopup="true" class="wsmdv menu-mobile-spec">
# <a class="dsi-modal-link navtext" data-dsi-url="/publicPasseport/publicLoginModal2?redirUri=%2Frecherche%2Flots%3Fquery%3Dappareil+photo" data-toggle="modal" href="#modal-content">
# <span>Connexion</span>
# </a>
# </li>
# <li class="menu-mobile-spec">
# <div class="floatRight choixLangue">
# <form id="dsi-save-language-form">
# <input id="dsi-redirect-url" name="url" type="hidden" value="/en/search/lots?query=appareil+photo"/>
# <input id="dsi-save-language-url" type="hidden" value="/passeport/saveLanguage"/>
# <select class="dsi-form-elm form-control" id="dsi-language" name="lang" onchange="this.form.submit()">
# <option selected="" value="fr">FR</option>
# <option value="en">EN</option>
# <option value="zh">中文</option>
# </select>
# </form>
# </div>
# </li>
# </ul>
# </nav>
# </div>
# </div>
# </div>
# </div>
# </div>
# </div>
# </div>
# </div>
# <div class="page-wrapper-row full-height">
# <div id="top"></div>
# <div class="page-wrapper-middle">
# <div class="page-container">
# <div class="page-content-wrapper">
# <div class="page-content padding0">
# <div class="container-fluid">
# <h1 class="alignCenter">
#             Recherche pour "appareil photo"
#
#                 <a class="dsi-modal-link" data-dsi-url="/alert/createModalData?query=appareil+photo&amp;mode=liste&amp;max=50&amp;offset=0&amp;theme=all&amp;cps=all&amp;venteType=all" data-toggle="modal" href="#modal-content" style="padding-right:0; padding-bottom:0;">
# <span class="btn mini secondary marginLeft15">
# <i class="fa fa-bell-o"></i> Créer une alerte " <span class="litzt600">appareil photo</span> "
#                     </span>
# </a>
# </h1>
# </div>
# <div class="PageListing container">
# <div id="list-lots">
# <div class="col-xs-4 col-sm-3 noPaddingLeft">
# <form action="/recherche/lots?id=#top" class="form-inline taille_120" id="searchForm" method="get">
# <script src="/js/vars" type="text/javascript"></script>
# <div class="col-xs-12 padding0 filtreCalendrier printHide">
# <div class="navbar yamm navbar-default">
# <!--Specialite categorie fille-->
# <div class="filter-reset">
# <a class="btn mini ghost filter marginTop5" href="/recherche/lots?id=&amp;theme=&amp;query=appareil+photo&amp;offset=0&amp;refurl=&amp;isAdvancedSearch="><i aria-hidden="true" class="fa fa-trash-o marginRight10"></i>Effacer tous les filtres</a>
# </div>
# <div class="clear"></div>
# <div class="noPaddingLeft noPaddingRight">
# <div class="noPaddingLeft noPaddingRight navbar-collapse collapse" id="navbar-collapse-1">
# <ul class="nav nav-pills navbar-nav">
# <!--specialite-->
# <input name="query" type="hidden" value="appareil photo"/>
# <!--artiste + recherche-->
# <div class="portletSousFiltre">
# <div class="portlet light">
# <div class="portlet-title">
# <div class="tools">
# <a class="collapse" data-original-title="" href="" title=""><h3><i aria-hidden="true" class="fa fa-sort-desc"></i> Date</h3></a>
# </div>
# </div>
# <div class="portlet-body marginTop10">
# <div class="checkbox-wrapper">
# <div class="dsi-selectDate">
# <span class="multiselect-native-select"><select id="selectDate" multiple="multiple" name="dateSelect">
# <option value="1612051200-1612137600">Demain </option>
# <option value="1612224000-1612310400">mar. 02 févr. </option>
# <option value="1612396800-1612483200">jeu. 04 févr. </option>
# <option value="1612483200-1612569600">ven. 05 févr. </option>
# <option value="1612569600-1612656000">sam. 06 févr. </option>
# <option value="1612742400-1612828800">08/02/2021 - 09/02/2021 </option>
# <option value="1612828800-1613433600">09/02/2021 - 16/02/2021 </option>
# </select><div id="selectDate"><ul class="multiselect-container checkbox-list"><li class="multiselect-item multiselect-filter" value="0"><div class="input-group"><span class="input-group-addon"><i class="glyphicon glyphicon-search"></i></span><input class="form-control multiselect-search" placeholder="Recherche" type="text"/><span class="input-group-btn"><button class="btn btn-default multiselect-clear-filter" type="button"><i class="glyphicon glyphicon-remove-circle"></i></button></span></div></li><li><a tabindex="0"><label class="checkbox" title="Demain "><input class="css-checkbox" type="checkbox" value="1612051200-1612137600"/> Demain <span class="tag"> 1</span></label></a></li><li><a tabindex="0"><label class="checkbox" title="mar. 02 févr. "><input class="css-checkbox" type="checkbox" value="1612224000-1612310400"/> mar. 02 févr. <span class="tag"> 4</span></label></a></li><li><a tabindex="0"><label class="checkbox" title="jeu. 04 févr. "><input class="css-checkbox" type="checkbox" value="1612396800-1612483200"/> jeu. 04 févr. <span class="tag"> 2</span></label></a></li><li><a tabindex="0"><label class="checkbox" title="ven. 05 févr. "><input class="css-checkbox" type="checkbox" value="1612483200-1612569600"/> ven. 05 févr. <span class="tag"> 2</span></label></a></li><li><a tabindex="0"><label class="checkbox" title="sam. 06 févr. "><input class="css-checkbox" type="checkbox" value="1612569600-1612656000"/> sam. 06 févr. <span class="tag"> 2</span></label></a></li><li><a tabindex="0"><label class="checkbox" title="08/02/2021 - 09/02/2021 "><input class="css-checkbox" type="checkbox" value="1612742400-1612828800"/> 08/02/2021 - 09/02/2021 <span class="tag"> 85</span></label></a></li><li><a tabindex="0"><label class="checkbox" title="09/02/2021 - 16/02/2021 "><input class="css-checkbox" type="checkbox" value="1612828800-1613433600"/> 09/02/2021 - 16/02/2021 <span class="tag"> 6</span></label></a></li></ul></div></span>
# </div>
# </div>
# </div>
# </div>
# </div>
# <li class="main filterlieu">
# <div class="portletSousFiltre">
# <div class="portlet light">
# <div class="portlet-title">
# <div class="tools">
# <a class="collapse" data-original-title="" href="" title=""><h3 class="capitalize"><i aria-hidden="true" class="fa fa-sort-desc"></i> Lieu</h3></a>
# </div>
# </div>
# <div class="portlet-body">
# <div class="yamm-content nolimit">
# <div class="checkbox-wrapper">
# <div class="dsi-selectLieu">
# <span class="multiselect-native-select"><select id="selectLieu" multiple="multiple" name="lieuxExpo">
# <option value="HOTEL-DROUOT">Hôtel Drouot</option>
# <option value="PARIS">Paris</option>
# <option value="75">France</option>
# <option value="109">Italie</option>
# <option value="140">Monaco</option>
# </select><div id="selectLieu"><ul class="multiselect-container checkbox-list"><li class="multiselect-item multiselect-filter" value="0"><div class="input-group"><span class="input-group-addon"><i class="glyphicon glyphicon-search"></i></span><input class="form-control multiselect-search" placeholder="Recherche" type="text"/><span class="input-group-btn"><button class="btn btn-default multiselect-clear-filter" type="button"><i class="glyphicon glyphicon-remove-circle"></i></button></span></div></li><li><a tabindex="0"><label class="checkbox" title="Hôtel Drouot"><input class="css-checkbox" type="checkbox" value="HOTEL-DROUOT"/> Hôtel Drouot<span class="tag"> 3</span></label></a></li><li><a tabindex="0"><label class="checkbox" title="Paris"><input class="css-checkbox" type="checkbox" value="PARIS"/> Paris<span class="tag"> 4</span></label></a></li><li><a tabindex="0"><label class="checkbox" title="France"><input class="css-checkbox" type="checkbox" value="75"/> France<span class="tag"> 99</span></label></a></li><li><a tabindex="0"><label class="checkbox" title="Italie"><input class="css-checkbox" type="checkbox" value="109"/> Italie<span class="tag"> 1</span></label></a></li><li><a tabindex="0"><label class="checkbox" title="Monaco"><input class="css-checkbox" type="checkbox" value="140"/> Monaco<span class="tag"> 2</span></label></a></li></ul></div></span>
# </div>
# </div>
# </div>
# </div>
# </div>
# </div>
# </li>
# <!--artiste + recherche-->
# <li class="main">
# <div class="portletSousFiltre">
# <div class="portlet light">
# <div class="portlet-title">
# <div class="tools">
# <a class="collapse" data-original-title="" href="" title=""><h3><i aria-hidden="true" class="fa fa-sort-desc"></i> Types de ventes</h3></a>
# </div>
# </div>
# <div class="portlet-body">
# <div class="dsi-type-sale marginTop10">
# <label class="marginRight20 checked checked">
# <div class="iradio_minimal checked" style="position: relative;"><input checked="" class="searchautosubmit" name="venteType" style="position: absolute; top: -20%; left: -20%; display: block; width: 140%; height: 140%; margin: 0px; padding: 0px; background: rgb(255, 255, 255); border: 0px; opacity: 0;" type="radio" value="all"/><ins class="iCheck-helper" style="position: absolute; top: -20%; left: -20%; display: block; width: 140%; height: 140%; margin: 0px; padding: 0px; background: rgb(255, 255, 255); border: 0px; opacity: 0;"></ins></div>
# <span class="labelTypeVente">Toutes les ventes</span>
# </label>
# <div class="clear"></div>
# <label class="tooltips" data-container="body" data-original-title="Ventes Live uniquement" data-placement="right">
# <div class="iradio_minimal" style="position: relative;"><input class="searchautosubmit" name="venteType" style="position: absolute; top: -20%; left: -20%; display: block; width: 140%; height: 140%; margin: 0px; padding: 0px; background: rgb(255, 255, 255); border: 0px; opacity: 0;" type="radio" value="live"/><ins class="iCheck-helper" style="position: absolute; top: -20%; left: -20%; display: block; width: 140%; height: 140%; margin: 0px; padding: 0px; background: rgb(255, 255, 255); border: 0px; opacity: 0;"></ins></div>
# <span class="labelTypeVente">Ventes Live</span>
# </label>
# <div class="clear"></div>
# <label class="tooltips" data-container="body" data-original-title="Ventes Online uniquement" data-placement="right">
# <div class="iradio_minimal" style="position: relative;"><input class="searchautosubmit" name="venteType" style="position: absolute; top: -20%; left: -20%; display: block; width: 140%; height: 140%; margin: 0px; padding: 0px; background: rgb(255, 255, 255); border: 0px; opacity: 0;" type="radio" value="online"/><ins class="iCheck-helper" style="position: absolute; top: -20%; left: -20%; display: block; width: 140%; height: 140%; margin: 0px; padding: 0px; background: rgb(255, 255, 255); border: 0px; opacity: 0;"></ins></div>
# <span class="labelTypeVente">Ventes Online</span>
# </label>
# <div class="clear"></div>
# <label class="tooltips" data-container="body" data-original-title="Ventes Buy Now uniquement" data-placement="right">
# <div class="iradio_minimal" style="position: relative;"><input class="searchautosubmit" name="venteType" style="position: absolute; top: -20%; left: -20%; display: block; width: 140%; height: 140%; margin: 0px; padding: 0px; background: rgb(255, 255, 255); border: 0px; opacity: 0;" type="radio" value="buynow"/><ins class="iCheck-helper" style="position: absolute; top: -20%; left: -20%; display: block; width: 140%; height: 140%; margin: 0px; padding: 0px; background: rgb(255, 255, 255); border: 0px; opacity: 0;"></ins></div>
# <span class="labelTypeVente">Ventes Buy Now</span>
# </label>
# </div>
# </div>
# </div>
# </div>
# </li>
# <!--vente-->
# <!--artiste + recherche-->
# <li class="main btFiltrePrices">
# <div class="portletSousFiltre">
# <div class="portlet light">
# <div class="portlet-title">
# <div class="tools">
# <a class="collapse" data-original-title="" href="" title=""><h3><i aria-hidden="true" class="fa fa-sort-desc"></i> Estimation</h3></a>
# </div>
# </div>
# <div class="portlet-body">
# <label class="marginTop10">
# <input class="priceFilter" name="minEstim" placeholder="Prix min" type="number" value=""/>
# <input class="priceFilter" name="maxEstim" placeholder="Prix max" type="number" value=""/>
# </label>
# </div>
# </div>
# </div>
# </li>
# <li class="yamm-fw main">
# <link href="/assets/jquery-grumble/grumble.min-1ae644b0d7198c1d405308e8be3f2673.css" rel="stylesheet" type="text/css"/>
# <div class="portletSousFiltre">
# <div class="portlet light">
# <div class="portlet-title">
# <div class="tools">
# <a class="collapse" data-original-title="" href="" title=""><h3><i aria-hidden="true" class="fa fa-sort-desc"></i> Thématiques</h3></a>
# </div>
# </div>
# <div class="portlet-body">
# <div class="yamm-content nolimit">
# <div>
# <div class="checkbox-wrapper">
# <span class="multiselect-native-select"><select id="selectCat" multiple="multiple" name="categorie">
# <option class="parentCat" value="203">Livres et Manuscrits</option>
# <option class="childCat" value="77">Livres, manuscrits</option>
# <option class="childCat" value="765">Livres religieux</option>
# <option class="parentCat" value="206">Objets de collection</option>
# <option class="childCat" value="711">Appareils photo, caméras et téléviseurs</option>
# <option class="parentCat" value="230">Objets d'Art</option>
# <option class="parentCat" value="164">Arts graphiques</option>
# <option class="childCat" value="25">Affiches</option>
# <option class="childCat" value="21">Photographies</option>
# ...
#
#         // if the target of the click isn't the container nor a descendant of the container
#         if (!container.is(e.target) && container.has(e.target).length === 0) {
#             $("#dsi-modal-ordre-confirm-" + 14243506).hide();
#         }
#     });
# </script><script>
# 	function addFavorisEvent() {
# 		dataLayer.push({
# 			"event": "Event",
# 			"eventCategory":"Lot",
# 			"eventAction":"Favori",
# 			"eventLabel":"14243508"
# 		});
# 	}
#
# 	function removeFavoris(adressUrl) {
# 		$.ajax({
# 	            url: adressUrl,
# 	            success:function(data){
# 	            	window.location.reload();
# 	            },
# 				error: function(data){
#
# 		        }
# 	        });
# }
#
# </script><script type="text/javascript">
#     $(document).mouseup(function(e)  {
#         var container = $("#dsi-modal-ordre-confirm-" + 14243508);
#
#         // if the target of the click isn't the container nor a descendant of the container
#         if (!container.is(e.target) && container.has(e.target).length === 0) {
#             $("#dsi-modal-ordre-confirm-" + 14243508).hide();
#         }
#     });
# </script><script>
# 	function addFavorisEvent() {
# 		dataLayer.push({
# 			"event": "Event",
# 			"eventCategory":"Lot",
# 			"eventAction":"Favori",
# 			"eventLabel":"14243509"
# 		});
# 	}
#
# 	function removeFavoris(adressUrl) {
# 		$.ajax({
# 	            url: adressUrl,
# 	            success:function(data){
# 	            	window.location.reload();
# 	            },
# 				error: function(data){
#
# 		        }
# 	        });
# }
#
# </script><script type="text/javascript">
#     $(document).mouseup(function(e)  {
#         var container = $("#dsi-modal-ordre-confirm-" + 14243509);
#
#         // if the target of the click isn't the container nor a descendant of the container
#         if (!container.is(e.target) && container.has(e.target).length === 0) {
#             $("#dsi-modal-ordre-confirm-" + 14243509).hide();
#         }
#     });
# </script><script>
# 	function addFavorisEvent() {
# 		dataLayer.push({
# 			"event": "Event",
# 			"eventCategory":"Lot",
# 			"eventAction":"Favori",
# 			"eventLabel":"14243511"
# 		});
# 	}
#
# 	function removeFavoris(adressUrl) {
# 		$.ajax({
# 	            url: adressUrl,
# 	            success:function(data){
# 	            	window.location.reload();
# 	            },
# 				error: function(data){
#
# 		        }
# 	        });
# }
#
# </script><script type="text/javascript">
#     $(document).mouseup(function(e)  {
#         var container = $("#dsi-modal-ordre-confirm-" + 14243511);
#
#         // if the target of the click isn't the container nor a descendant of the container
#         if (!container.is(e.target) && container.has(e.target).length === 0) {
#             $("#dsi-modal-ordre-confirm-" + 14243511).hide();
#         }
#     });
# </script><script>
# 	function addFavorisEvent() {
# 		dataLayer.push({
# 			"event": "Event",
# 			"eventCategory":"Lot",
# 			"eventAction":"Favori",
# 			"eventLabel":"14243514"
# 		});
# 	}
#
# 	function removeFavoris(adressUrl) {
# 		$.ajax({
# 	            url: adressUrl,
# 	            success:function(data){
# 	            	window.location.reload();
# 	            },
# 				error: function(data){
#
# 		        }
# 	        });
# }
#
# </script><script type="text/javascript">
#     $(document).mouseup(function(e)  {
#         var container = $("#dsi-modal-ordre-confirm-" + 14243514);
#
#         // if the target of the click isn't the container nor a descendant of the container
#         if (!container.is(e.target) && container.has(e.target).length === 0) {
#             $("#dsi-modal-ordre-confirm-" + 14243514).hide();
#         }
#     });
# </script><script>
# 	function addFavorisEvent() {
# 		dataLayer.push({
# 			"event": "Event",
# 			"eventCategory":"Lot",
# 			"eventAction":"Favori",
# 			"eventLabel":"14243542"
# 		});
# 	}
#
# 	function removeFavoris(adressUrl) {
# 		$.ajax({
# 	            url: adressUrl,
# 	            success:function(data){
# 	            	window.location.reload();
# 	            },
# 				error: function(data){
#
# 		        }
# 	        });
# }
#
# </script><script type="text/javascript">
#     $(document).mouseup(function(e)  {
#         var container = $("#dsi-modal-ordre-confirm-" + 14243542);
#
#         // if the target of the click isn't the container nor a descendant of the container
#         if (!container.is(e.target) && container.has(e.target).length === 0) {
#             $("#dsi-modal-ordre-confirm-" + 14243542).hide();
#         }
#     });
# </script><script>
# 	function addFavorisEvent() {
# 		dataLayer.push({
# 			"event": "Event",
# 			"eventCategory":"Lot",
# 			"eventAction":"Favori",
# 			"eventLabel":"14243559"
# 		});
# 	}
#
# 	function removeFavoris(adressUrl) {
# 		$.ajax({
# 	            url: adressUrl,
# 	            success:function(data){
# 	            	window.location.reload();
# 	            },
# 				error: function(data){
#
# 		        }
# 	        });
# }
#
# </script><script type="text/javascript">
#     $(document).mouseup(function(e)  {
#         var container = $("#dsi-modal-ordre-confirm-" + 14243559);
#
#         // if the target of the click isn't the container nor a descendant of the container
#         if (!container.is(e.target) && container.has(e.target).length === 0) {
#             $("#dsi-modal-ordre-confirm-" + 14243559).hide();
#         }
#     });
# </script><script>
# 	function addFavorisEvent() {
# 		dataLayer.push({
# 			"event": "Event",
# 			"eventCategory":"Lot",
# 			"eventAction":"Favori",
# 			"eventLabel":"14243560"
# 		});
# 	}
#
# 	function removeFavoris(adressUrl) {
# 		$.ajax({
# 	            url: adressUrl,
# 	            success:function(data){
# 	            	window.location.reload();
# 	            },
# 				error: function(data){
#
# 		        }
# 	        });
# }
#
# </script><script type="text/javascript">
#     $(document).mouseup(function(e)  {
#         var container = $("#dsi-modal-ordre-confirm-" + 14243560);
#
#         // if the target of the click isn't the container nor a descendant of the container
#         if (!container.is(e.target) && container.has(e.target).length === 0) {
#             $("#dsi-modal-ordre-confirm-" + 14243560).hide();
#         }
#     });
# </script><script>
# 	function addFavorisEvent() {
# 		dataLayer.push({
# 			"event": "Event",
# 			"eventCategory":"Lot",
# 			"eventAction":"Favori",
# 			"eventLabel":"14243562"
# 		});
# 	}
#
# 	function removeFavoris(adressUrl) {
# 		$.ajax({
# 	            url: adressUrl,
# 	            success:function(data){
# 	            	window.location.reload();
# 	            },
# 				error: function(data){
#
# 		        }
# 	        });
# }
#
# </script><script type="text/javascript">
#     $(document).mouseup(function(e)  {
#         var container = $("#dsi-modal-ordre-confirm-" + 14243562);
#
#         // if the target of the click isn't the container nor a descendant of the container
#         if (!container.is(e.target) && container.has(e.target).length === 0) {
#             $("#dsi-modal-ordre-confirm-" + 14243562).hide();
#         }
#     });
# </script><script>
# 	$(document).on('change', '#pageSelect', function() {
# 			window.location.href=$(this).val()
# 	});
# </script><script src="/assets/ordre-db37e3a461262fe3f9912ce928d238c3.js"></script><script>
#     $('.oc-catalogue').owlCarousel({
#     items:1,
#     lazyLoad:true,
#     nav:true,
#     dots:false,
#     navText: ["<i class='fa fa-angle-left'></i>","<i class='fa fa-angle-right'></i>"],
#     autoplay:false,
#     })
# </script><script type="text/javascript">
#     function getCautionState() {
#         $.ajax({
#             url: "/lot/getCautionState",
#             success: function (result) {
#                 $('#dsi-cal-caution').html(result);
#                 setTimeout(function () {
#                     getCautionState();
#                 }, 30000);
#             }
#         });
#     }
#     $(document).ready(function () {
#         getCautionState();
#         if ($('body').hasClass('isNormal page-container-bg-solid page-header-menu-fixed device-xxs')) {
#             var portlets = $('.portlet .portlet-title > .tools > .collapse');
#             var elts = portlets.closest(".portlet").children(".portlet-body");
#             portlets.removeClass("collapse").addClass("expand");
#             elts.slideUp(200);
#         }
#         if ($('body').hasClass('isNormal page-container-bg-solid page-header-menu-fixed device-xs')) {
#             var portlets = $('.portlet .portlet-title > .tools > .collapse');
#             var elts = portlets.closest(".portlet").children(".portlet-body");
#             portlets.removeClass("collapse").addClass("expand");
#             elts.slideUp(200);
#         }
#
#         if ($('body').hasClass('isTablet page-container-bg-solid page-header-menu-fixed device-xxs')) {
#             var portlets = $('.portlet .portlet-title > .tools > .collapse');
#             var elts = portlets.closest(".portlet").children(".portlet-body");
#             portlets.removeClass("collapse").addClass("expand");
#             elts.slideUp(200);
#         }
#         if ($('body').hasClass('isTablet page-container-bg-solid page-header-menu-fixed device-xs')) {
#             var portlets = $('.portlet .portlet-title > .tools > .collapse');
#             var elts = portlets.closest(".portlet").children(".portlet-body");
#             portlets.removeClass("collapse").addClass("expand");
#             elts.slideUp(200);
#         }
#
#     });
# </script><script type="text/javascript">
#         $(document).ready(function() {
#             $.toast({
#               icon: 'success',
#               text : "<p class=''>Enregistrez cette recherche et recevez des  <a data-dsi-url=\"/alert/createModalData?query=appareil+photo&amp;mode=liste&amp;max=50&amp;offset=0&amp;theme=all&amp;cps=all&amp;venteType=all&amp;venteId=\" data-toggle=\"modal\" class=\"dsi-modal-link\" href=\"#modal-content\" >alertes email.</a></p>",
#               allowToastClose: true,
#               showHideTransition : 'slide',  // It can be plain, fade or slide
#               hideAfter : 10000,             // `false` to make it sticky or time in miliseconds to hide after
#               stack : 2,                     // `false` to show one stack at a time count showing the number of toasts that can be shown at once
#               textAlign : 'left',            // Alignment of text i.e. left, right, center
#               position : 'bottom-right',      // bottom-left or bottom-right or bottom-center or top-left or top-right or top-center or mid-center or an object representing the left, right, top, bottom values to position the toast on page
#             });
#         });
#     </script><script src="/assets/jquery-toast/jquery.toast-54a993c75d0e24b1d45c96b550a0f24f.js"></script><script type="text/javascript">
#         $(function() {
#             $("#dsi-save-language-form").submit(function(e) {
#                 e.preventDefault();
#                 var url = form.attr('action');
#                 var dsiSaveLanguageUrl = $("#dsi-save-language-url").val();
#                 $.ajax({
#                     type: "POST",
#                     url: dsiSaveLanguageUrl,
#                     data: form.serialize(),
#                     success: function(data){
#                         window.location.href=$("#dsi-redirect-url").val();
#                     },
#                     error: function(data){
#                         window.location.href=$("#dsi-redirect-url").val();
#                     }
#                 });
#             });
#         });
#     </script><script type="text/javascript">
#         $(function() {
#             $("#dsi-save-language-form").submit(function(e) {
#                 e.preventDefault();
#                 var url = form.attr('action');
#                 var dsiSaveLanguageUrl = $("#dsi-save-language-url").val();
#                 $.ajax({
#                     type: "POST",
#                     url: dsiSaveLanguageUrl,
#                     data: form.serialize(),
#                     success: function(data){
#                         window.location.href=$("#dsi-redirect-url").val();
#                     },
#                     error: function(data){
#                         window.location.href=$("#dsi-redirect-url").val();
#                     }
#                 });
#             });
#         });
#     </script><script type="text/javascript">
#         $(function() {
#             $("#dsi-save-language-form").submit(function(e) {
#                 e.preventDefault();
#                 var url = form.attr('action');
#                 var dsiSaveLanguageUrl = $("#dsi-save-language-url").val();
#                 $.ajax({
#                     type: "POST",
#                     url: dsiSaveLanguageUrl,
#                     data: form.serialize(),
#                     success: function(data){
#                         window.location.href=$("#dsi-redirect-url").val();
#                     },
#                     error: function(data){
#                         window.location.href=$("#dsi-redirect-url").val();
#                     }
#                 });
#             });
#         });
#     </script><script>
#     document.addEventListener('DOMContentLoaded', function(event) {
#         cookieChoices.showCookieConsentBar("En naviguant sur notre site, vous acceptez l'utilisation de cookies qui nous permettront de réaliser des analyses et de vous proposer des contenus et des annonces les plus adaptés à vos centres d'intérêts.","J'accepte", "En savoir plus", "/politiqueConfidentialite");
#     });
# </script><script>
#     $(window).scroll(function(){if($(this).scrollTop()>1){$('.backtotop').css({bottom:"145px"});}else{$('.backtotop').css({bottom:"-100px"});}});$('.backtotop').click(function(){$('html, body').animate({scrollTop:'0px'},800);return false;});
# </script>
# <div aria-hidden="true" class="modal container fade" id="modal-content" tabindex="-1"></div>
# <script type="text/javascript">
#     $(document).ready(function () {
#         $('input').not('.css-checkbox').iCheck({
#             checkboxClass: 'icheckbox_minimal',
#             radioClass: 'iradio_minimal',
#             increaseArea: '20%' // optional
#         });
#         $('.sbm input').on('ifChecked', function (event) {
#             this.form.submit();
#         });
#         $('.sbm2 input').on('ifChanged', function (event) {
#             this.form.submit();
#         });
#     });
# </script>
# <script type="text/javascript">
#     function doPollList(id,urlParam,verif,duration=30000){
#         $.post(urlParam+"/?l="+id)
#         .done(function(data){ bttUpdate(data,verif);})
#         .always(function(data) {
#             var lot_near_to_close_time = data.l.reduce((min,p)=> (min != 0 && p.t >0 && p.t < min) || (min == 0 && p.t > 0)? p.t : min, data.t);
#             if(lot_near_to_close_time != 0 && duration == 30000 && lot_near_to_close_time - data.t <= 180000 ) {
#                     duration = 5000
#                     clearTimeout(t)
#             }
#             t=setTimeout('doPollList("'+id+'","'+urlParam+'","'+verif+'","'+duration+'")',duration)
#             ;})
#         ;
#     }
# </script><div class="holder"></div></div><div aria-live="polite" class="jq-toast-wrap bottom-right" role="alert"><div class="jq-toast-single jq-has-icon jq-icon-success" style="text-align: left; display: block; overflow: hidden; height: 45.3264px; padding-top: 5.61094px; margin-top: 0px; padding-bottom: 5.61094px; margin-bottom: 2.80547px;"><span class="jq-toast-loader"></span><span class="close-jq-toast-single">×</span><p class="">Enregistrez cette recherche et recevez des  <a class="dsi-modal-link" data-dsi-url="/alert/createModalData?query=appareil+photo&amp;mode=liste&amp;max=50&amp;offset=0&amp;theme=all&amp;cps=all&amp;venteType=all&amp;venteId=" data-toggle="modal" href="#modal-content">alertes email.</a></p></div></div><div id="cookieChoiceInfo" style="position: fixed; width: 100%; background-color: rgb(51, 51, 51); color: rgb(255, 255, 255); margin: 0px; left: 0px; bottom: 0px; padding: 10px 50px; z-index: 1000; text-align: center;"><span>En naviguant sur notre site, vous acceptez l'utilisation de cookies qui nous permettront de réaliser des analyses et de vous proposer des contenus et des annonces les plus adaptés à vos centres d'intérêts.</span><a href="/politiqueConfidentialite" style="margin-left: 15px; color: rgb(255, 255, 255);" target="_blank">En savoir plus</a><a href="#" id="cookieChoiceDismiss" style="margin-left: 15px; color: rgb(255, 255, 255);">J'accepte</a></div></body></html>

# %%
urllib.parse.quote_plus('appareil photo à caca')
# Out:
# 'appareil+photo+%C3%A0+caca'

# %%
BASE_URL = 'https://www.drouotonline.com/'
SCROLL_PAUSE_TIME = 0.5
url = BASE_URL + '/recherche/lots?search=appareil%20photo&area=france'
r = requests.get("https://www.interencheres.com/recherche/lots?search=appareil%20photo&area=france")
soup = BeautifulSoup(r.text, 'lxml')

# %%
 items = soup.find('div', class_='results') \
            .find('div', class_='row--dense') \
            .find_all('div', class_='col-sm-6')

# %%
for div in items:
    print(div.find('div', ''))
# Out:
# <div class="col-sm-6 col-md-4 col-lg-3 col-12" id="page-1"><a class="wrapper ma-2 v-card v-card--link v-sheet v-sheet--outlined theme--light elevation-0 wrapper--gallery" data-v-4255d580="" href="/meubles-objets-art/vente-courante-et-bon-fonds-de-maison-et-vehicules-vp-et-utilitairesapres-lj-tres-recent-electrportatifs-bosch-inscription-par-mail-obligatoire-pour-lexposition-et-la-vente-281295/lot-26491510.html" tabindex="0"><div class="v-card__text text--primary pa-0" data-v-4255d580=""><div class="container pa-0 container--fluid fill-height" data-v-4255d580=""><div class="image col col-12 pa-0" data-v-4255d580=""><div data-v-4255d580=""><div class="v-image v-responsive theme--light" data-v-4255d580=""><div class="v-image__image v-image__image--preload v-image__image--cover" style="background-image:;background-position:center center;"></div><div class="v-responsive__content"></div></div> <div class="more-media-wrapper" data-v-4255d580=""><!-- --></div></div></div> <div class="body px-4 py-2 d-flex flex-column col col-12 align-self-stretch" data-v-4255d580=""><div class="flex-grow-1" data-v-4255d580=""><!-- --> <div class="row ma-0" data-v-4255d580=""><div class="text-h6" data-v-4255d580=""><span data-v-4255d580="">Lot n°156</span></div> <button class="ml-auto v-btn v-btn--flat v-btn--icon v-btn--round theme--light v-size--default" data-v-35d523de="" data-v-4255d580="" type="button"><span class="v-btn__content"><i aria-hidden="true" class="v-icon notranslate mdi mdi-heart-outline theme--light" data-v-35d523de=""></i> <!-- --></span></button></div> <div class="row ma-0 description text-body-2 my-2" data-v-4255d580="">
#               LOT de matériel photo dont un appareil photo FUGICA et objectifs
#             </div> <div class="row ma-0 estimates text-subtitle-2" data-v-4255d580=""><!-- --></div> <div class="row estimates text-body-2 ma-0" data-v-4255d580="">Vente aujourd'hui à 09h30</div></div> <div class="row flex-grow-0 justify-end mt-2 mr-n2" data-v-4255d580=""><span class="v-tooltip v-tooltip--top" data-v-4255d580=""><!-- --><div aria-expanded="false" aria-haspopup="true"><div class="v-dialog__container" role="dialog"><button class="v-btn v-btn--flat v-btn--text theme--light v-size--default primary--text" type="button"><span class="v-btn__content">
#       Déposer un ordre
#     </span></button><!-- --></div></div></span></div></div></div></div> <!-- --></a></div>
# <div class="col-sm-6 col-md-4 col-lg-3 col-12"><a class="wrapper ma-2 v-card v-card--link v-sheet v-sheet--outlined theme--light elevation-0 wrapper--gallery" data-v-4255d580="" href="/meubles-objets-art/vente-courante-et-bon-fonds-de-maison-et-vehicules-vp-et-utilitairesapres-lj-tres-recent-electrportatifs-bosch-inscription-par-mail-obligatoire-pour-lexposition-et-la-vente-281295/lot-26491487.html" tabindex="0"><div class="v-card__text text--primary pa-0" data-v-4255d580=""><div class="container pa-0 container--fluid fill-height" data-v-4255d580=""><div class="image col col-12 pa-0" data-v-4255d580=""><div data-v-4255d580=""><div class="v-image v-responsive theme--light" data-v-4255d580=""><div class="v-image__image v-image__image--preload v-image__image--cover" style="background-image:;background-position:center center;"></div><div class="v-responsive__content"></div></div> <div class="more-media-wrapper" data-v-4255d580=""><!-- --></div></div></div> <div class="body px-4 py-2 d-flex flex-column col col-12 align-self-stretch" data-v-4255d580=""><div class="flex-grow-1" data-v-4255d580=""><!-- --> <div class="row ma-0" data-v-4255d580=""><div class="text-h6" data-v-4255d580=""><span data-v-4255d580="">Lot n°134</span></div> <button class="ml-auto v-btn v-btn--flat v-btn--icon v-btn--round theme--light v-size--default" data-v-35d523de="" data-v-4255d580="" type="button"><span class="v-btn__content"><i aria-hidden="true" class="v-icon notranslate mdi mdi-heart-outline theme--light" data-v-35d523de=""></i> <!-- --></span></button></div> <div class="row ma-0 description text-body-2 my-2" data-v-4255d580="">
#               LOT: disques, appareil photo, projecteur diapo, 3 pots de chambre
#             </div> <div class="row ma-0 estimates text-subtitle-2" data-v-4255d580=""><!-- --></div> <div class="row estimates text-body-2 ma-0" data-v-4255d580="">Vente aujourd'hui à 09h30</div></div> <div class="row flex-grow-0 justify-end mt-2 mr-n2" data-v-4255d580=""><span class="v-tooltip v-tooltip--top" data-v-4255d580=""><!-- --><div aria-expanded="false" aria-haspopup="true"><div class="v-dialog__container" role="dialog"><button class="v-btn v-btn--flat v-btn--text theme--light v-size--default primary--text" type="button"><span class="v-btn__content">
#       Déposer un ordre
#     </span></button><!-- --></div></div></span></div></div></div></div> <!-- --></a></div>
# <div class="col-sm-6 col-md-4 col-lg-3 col-12"><a class="wrapper ma-2 v-card v-card--link v-sheet v-sheet--outlined theme--light elevation-0 wrapper--gallery" data-v-4255d580="" href="/meubles-objets-art/vente-courante-et-bon-fonds-de-maison-et-vehicules-vp-et-utilitairesapres-lj-tres-recent-electrportatifs-bosch-inscription-par-mail-obligatoire-pour-lexposition-et-la-vente-281295/lot-26470673.html" tabindex="0"><div class="v-card__text text--primary pa-0" data-v-4255d580=""><div class="container pa-0 container--fluid fill-height" data-v-4255d580=""><div class="image col col-12 pa-0" data-v-4255d580=""><div data-v-4255d580=""><div class="v-image v-responsive theme--light" data-v-4255d580=""><div class="v-image__image v-image__image--preload v-image__image--cover" style="background-image:;background-position:center center;"></div><div class="v-responsive__content"></div></div> <div class="more-media-wrapper" data-v-4255d580=""><div class="media-count media-count--small" data-v-61b0a4f1=""><div data-v-61b0a4f1=""><span class="text-subtitle-2 mr-2" data-v-61b0a4f1="">3</span> <i aria-hidden="true" class="v-icon notranslate mdi mdi-image-multiple theme--light" data-v-4255d580=""></i></div></div></div></div></div> <div class="body px-4 py-2 d-flex flex-column col col-12 align-self-stretch" data-v-4255d580=""><div class="flex-grow-1" data-v-4255d580=""><!-- --> <div class="row ma-0" data-v-4255d580=""><div class="text-h6" data-v-4255d580=""><span data-v-4255d580="">Lot n°78</span></div> <button class="ml-auto v-btn v-btn--flat v-btn--icon v-btn--round theme--light v-size--default" data-v-35d523de="" data-v-4255d580="" type="button"><span class="v-btn__content"><i aria-hidden="true" class="v-icon notranslate mdi mdi-heart-outline theme--light" data-v-35d523de=""></i> <!-- --></span></button></div> <div class="row ma-0 description text-body-2 my-2" data-v-4255d580="">
#               LOT APPAREILS PHOTOS ET DIVERS ACCESSOIRES PHOTOS
#             </div> <div class="row ma-0 estimates text-subtitle-2" data-v-4255d580=""><!-- --></div> <div class="row estimates text-body-2 ma-0" data-v-4255d580="">Vente aujourd'hui à 09h30</div></div> <div class="row flex-grow-0 justify-end mt-2 mr-n2" data-v-4255d580=""><span class="v-tooltip v-tooltip--top" data-v-4255d580=""><!-- --><div aria-expanded="false" aria-haspopup="true"><div class="v-dialog__container" role="dialog"><button class="v-btn v-btn--flat v-btn--text theme--light v-size--default primary--text" type="button"><span class="v-btn__content">
#       Déposer un ordre
#     </span></button><!-- --></div></div></span></div></div></div></div> <!-- --></a></div>
# <div class="col-sm-6 col-md-4 col-lg-3 col-12"><a class="wrapper ma-2 v-card v-card--link v-sheet v-sheet--outlined theme--light elevation-0 wrapper--gallery" data-v-4255d580="" href="/meubles-objets-art/mille-et-un-papiers-284126/lot-26273246.html" tabindex="0"><div class="v-card__text text--primary pa-0" data-v-4255d580=""><div class="container pa-0 container--fluid fill-height" data-v-4255d580=""><div class="image col col-12 pa-0" data-v-4255d580=""><div data-v-4255d580=""><div class="v-image v-responsive theme--light" data-v-4255d580=""><div class="v-image__image v-image__image--preload v-image__image--cover" style="background-image:;background-position:center center;"></div><div class="v-responsive__content"></div></div> <div class="more-media-wrapper" data-v-4255d580=""><div class="media-count media-count--small" data-v-61b0a4f1=""><div data-v-61b0a4f1=""><span class="text-subtitle-2 mr-2" data-v-61b0a4f1="">2</span> <i aria-hidden="true" class="v-icon notranslate mdi mdi-image-multiple theme--light" data-v-4255d580=""></i></div></div></div></div></div> <div class="body px-4 py-2 d-flex flex-column col col-12 align-self-stretch" data-v-4255d580=""><div class="flex-grow-1" data-v-4255d580=""><!-- --> <div class="row ma-0" data-v-4255d580=""><div class="text-h6" data-v-4255d580=""><span data-v-4255d580="">Lot n°415</span></div> <button class="ml-auto v-btn v-btn--flat v-btn--icon v-btn--round theme--light v-size--default" data-v-35d523de="" data-v-4255d580="" type="button"><span class="v-btn__content"><i aria-hidden="true" class="v-icon notranslate mdi mdi-heart-outline theme--light" data-v-35d523de=""></i> <!-- --></span></button></div> <div class="row ma-0 description text-body-2 my-2" data-v-4255d580="">
#               Au Bon Marché – Catalogue de Jeux et Jouets pour enfants 1913 illustré - vues de jeux de fête foraine , sports , vélos , jouets en tôle , jeux de plage , poupées , dînettes , peluches , modélisme , appareils photos etc … - 20 pages au format 27,5x19,5cm
#             </div> <div class="row ma-0 estimates text-subtitle-2" data-v-4255d580=""><span data-v-4255d580="">Est. : 50 - 70 €</span></div> <div class="row estimates text-body-2 ma-0" data-v-4255d580="">Actuellement en live</div></div> <div class="row flex-grow-0 justify-end mt-2 mr-n2" data-v-4255d580=""><span class="v-tooltip v-tooltip--top" data-v-4255d580=""><!-- --><div aria-expanded="false" aria-haspopup="true"><div class="v-dialog__container" role="dialog"><button class="v-btn v-btn--flat v-btn--text theme--light v-size--default primary--text" type="button"><span class="v-btn__content">
#       Déposer un ordre
#     </span></button><!-- --></div></div></span></div></div></div></div> <!-- --></a></div>
# <div class="col-sm-6 col-md-4 col-lg-3 col-12"><a class="wrapper ma-2 v-card v-card--link v-sheet v-sheet--outlined theme--light elevation-0 wrapper--gallery" data-v-4255d580="" href="/meubles-objets-art/collection-dappareils-photo-et-accessoires-vente-en-live-avec-public-restreint-en-salle-285617/lot-26340944.html" tabindex="0"><div class="v-card__text text--primary pa-0 dense" data-v-4255d580=""><div class="container pa-0 container--fluid fill-height" data-v-4255d580=""><div class="image col col-12 pa-0" data-v-4255d580=""><div data-v-4255d580=""><div class="v-image v-responsive theme--light" data-v-4255d580=""><div class="v-image__image v-image__image--preload v-image__image--cover" style="background-image:;background-position:center center;"></div><div class="v-responsive__content"></div></div> <div class="more-media-wrapper" data-v-4255d580=""><!-- --></div></div></div> <div class="body px-4 py-2 d-flex flex-column col col-12 align-self-stretch" data-v-4255d580=""><div class="flex-grow-1" data-v-4255d580=""><!-- --> <div class="row ma-0" data-v-4255d580=""><div class="text-h6" data-v-4255d580=""><span data-v-4255d580="">Lot n°109</span></div> <button class="ml-auto v-btn v-btn--flat v-btn--icon v-btn--round theme--light v-size--default" data-v-35d523de="" data-v-4255d580="" type="button"><span class="v-btn__content"><i aria-hidden="true" class="v-icon notranslate mdi mdi-heart-outline theme--light" data-v-35d523de=""></i> <!-- --></span></button></div> <div class="row ma-0 description text-body-2 my-2" data-v-4255d580="">
#               Trois appareils photo : Canon EOS-1, Canon 30D, Kodak DCS 14n
#             </div> <div class="row ma-0 estimates text-subtitle-2" data-v-4255d580=""><span data-v-4255d580="">Est. : 20 - 30 €</span></div> <div class="row estimates text-body-2 ma-0" data-v-4255d580=""><!-- --></div></div> <div class="row flex-grow-0 justify-end mt-2 mr-n2" data-v-4255d580=""><span class="v-tooltip v-tooltip--top" data-v-4255d580=""><!-- --><div aria-expanded="false" aria-haspopup="true"><div class="v-dialog__container" role="dialog"><button class="v-btn v-btn--disabled v-btn--flat v-btn--text theme--light v-size--default" disabled="disabled" type="button"><span class="v-btn__content">
#       Déposer un ordre
#     </span></button><!-- --></div></div></span></div></div></div></div> <!-- --></a></div>
# <div class="col-sm-6 col-md-4 col-lg-3 col-12"><a class="wrapper ma-2 v-card v-card--link v-sheet v-sheet--outlined theme--light elevation-0 wrapper--gallery" data-v-4255d580="" href="/meubles-objets-art/collection-dappareils-photo-et-accessoires-vente-en-live-avec-public-restreint-en-salle-285617/lot-26340941.html" tabindex="0"><div class="v-card__text text--primary pa-0 dense" data-v-4255d580=""><div class="container pa-0 container--fluid fill-height" data-v-4255d580=""><div class="image col col-12 pa-0" data-v-4255d580=""><div data-v-4255d580=""><div class="v-image v-responsive theme--light" data-v-4255d580=""><div class="v-image__image v-image__image--preload v-image__image--cover" style="background-image:;background-position:center center;"></div><div class="v-responsive__content"></div></div> <div class="more-media-wrapper" data-v-4255d580=""><!-- --></div></div></div> <div class="body px-4 py-2 d-flex flex-column col col-12 align-self-stretch" data-v-4255d580=""><div class="flex-grow-1" data-v-4255d580=""><!-- --> <div class="row ma-0" data-v-4255d580=""><div class="text-h6" data-v-4255d580=""><span data-v-4255d580="">Lot n°113</span></div> <button class="ml-auto v-btn v-btn--flat v-btn--icon v-btn--round theme--light v-size--default" data-v-35d523de="" data-v-4255d580="" type="button"><span class="v-btn__content"><i aria-hidden="true" class="v-icon notranslate mdi mdi-heart-outline theme--light" data-v-35d523de=""></i> <!-- --></span></button></div> <div class="row ma-0 description text-body-2 my-2" data-v-4255d580="">
#               Quatre appareils photo : Royer Savoy III, Zeiss Ikon Ikomatic A, Bencini Koroll, Kodak Disc 4000
#             </div> <div class="row ma-0 estimates text-subtitle-2" data-v-4255d580=""><span data-v-4255d580="">Est. : 15 - 20 €</span></div> <div class="row estimates text-body-2 ma-0" data-v-4255d580=""><!-- --></div></div> <div class="row flex-grow-0 justify-end mt-2 mr-n2" data-v-4255d580=""><span class="v-tooltip v-tooltip--top" data-v-4255d580=""><!-- --><div aria-expanded="false" aria-haspopup="true"><div class="v-dialog__container" role="dialog"><button class="v-btn v-btn--disabled v-btn--flat v-btn--text theme--light v-size--default" disabled="disabled" type="button"><span class="v-btn__content">
#       Déposer un ordre
#     </span></button><!-- --></div></div></span></div></div></div></div> <!-- --></a></div>
# <div class="col-sm-6 col-md-4 col-lg-3 col-12"><a class="wrapper ma-2 v-card v-card--link v-sheet v-sheet--outlined theme--light elevation-0 wrapper--gallery" data-v-4255d580="" href="/meubles-objets-art/collection-dappareils-photo-et-accessoires-vente-en-live-avec-public-restreint-en-salle-285617/lot-26340936.html" tabindex="0"><div class="v-card__text text--primary pa-0 dense" data-v-4255d580=""><div class="container pa-0 container--fluid fill-height" data-v-4255d580=""><div class="image col col-12 pa-0" data-v-4255d580=""><div data-v-4255d580=""><div class="v-image v-responsive theme--light" data-v-4255d580=""><div class="v-image__image v-image__image--preload v-image__image--cover" style="background-image:;background-position:center center;"></div><div class="v-responsive__content"></div></div> <div class="more-media-wrapper" data-v-4255d580=""><!-- --></div></div></div> <div class="body px-4 py-2 d-flex flex-column col col-12 align-self-stretch" data-v-4255d580=""><div class="flex-grow-1" data-v-4255d580=""><!-- --> <div class="row ma-0" data-v-4255d580=""><div class="text-h6" data-v-4255d580=""><span data-v-4255d580="">Lot n°110</span></div> <button class="ml-auto v-btn v-btn--flat v-btn--icon v-btn--round theme--light v-size--default" data-v-35d523de="" data-v-4255d580="" type="button"><span class="v-btn__content"><i aria-hidden="true" class="v-icon notranslate mdi mdi-heart-outline theme--light" data-v-35d523de=""></i> <!-- --></span></button></div> <div class="row ma-0 description text-body-2 my-2" data-v-4255d580="">
#               Quatre appareils photo : Olympus OM-D, E-PL6, C-3020, Kodak DC220 Zoom
#             </div> <div class="row ma-0 estimates text-subtitle-2" data-v-4255d580=""><span data-v-4255d580="">Est. : 10 - 20 €</span></div> <div class="row estimates text-body-2 ma-0" data-v-4255d580=""><!-- --></div></div> <div class="row flex-grow-0 justify-end mt-2 mr-n2" data-v-4255d580=""><span class="v-tooltip v-tooltip--top" data-v-4255d580=""><!-- --><div aria-expanded="false" aria-haspopup="true"><div class="v-dialog__container" role="dialog"><button class="v-btn v-btn--disabled v-btn--flat v-btn--text theme--light v-size--default" disabled="disabled" type="button"><span class="v-btn__content">
#       Déposer un ordre
#     </span></button><!-- --></div></div></span></div></div></div></div> <!-- --></a></div>
# <div class="col-sm-6 col-md-4 col-lg-3 col-12"><a class="wrapper ma-2 v-card v-card--link v-sheet v-sheet--outlined theme--light elevation-0 wrapper--gallery wrapper--highlight" data-v-4255d580="" href="/meubles-objets-art/collection-dappareils-photo-et-accessoires-vente-en-live-avec-public-restreint-en-salle-285617/lot-26340890.html" tabindex="0"><div class="v-card__text text--primary pa-0 dense" data-v-4255d580=""><div class="container pa-0 container--fluid fill-height" data-v-4255d580=""><div class="image col col-12 pa-0" data-v-4255d580=""><div data-v-4255d580=""><div class="v-image v-responsive theme--light" data-v-4255d580=""><div class="v-image__image v-image__image--preload v-image__image--cover" style="background-image:;background-position:center center;"></div><div class="v-responsive__content"></div></div> <div class="more-media-wrapper" data-v-4255d580=""><!-- --></div></div></div> <div class="body px-4 py-2 d-flex flex-column col col-12 align-self-stretch" data-v-4255d580=""><div class="flex-grow-1" data-v-4255d580=""><!-- --> <div class="row ma-0" data-v-4255d580=""><div class="text-h6" data-v-4255d580=""><span data-v-4255d580="">Lot n°103</span></div> <button class="ml-auto v-btn v-btn--flat v-btn--icon v-btn--round theme--light v-size--default" data-v-35d523de="" data-v-4255d580="" type="button"><span class="v-btn__content"><i aria-hidden="true" class="v-icon notranslate mdi mdi-heart-outline theme--light" data-v-35d523de=""></i> <!-- --></span></button></div> <div class="row ma-0 description text-body-2 my-2" data-v-4255d580="">
#               Deux appareils photo à soufflet en acajou, avec plaques
# (en l’état)
#             </div> <div class="row ma-0 estimates text-subtitle-2" data-v-4255d580=""><span data-v-4255d580="">Est. : 30 - 50 €</span></div> <div class="row estimates text-body-2 ma-0" data-v-4255d580=""><!-- --></div></div> <div class="row flex-grow-0 justify-end mt-2 mr-n2" data-v-4255d580=""><span class="v-tooltip v-tooltip--top" data-v-4255d580=""><!-- --><div aria-expanded="false" aria-haspopup="true"><div class="v-dialog__container" role="dialog"><button class="v-btn v-btn--disabled v-btn--flat v-btn--text theme--light v-size--default" disabled="disabled" type="button"><span class="v-btn__content">
#       Déposer un ordre
#     </span></button><!-- --></div></div></span></div></div></div></div> <div class="inner-info inner-info--highlight" data-v-4255d580=""><div class="inner-info__info inner-info__info--highlight" data-v-4255d580=""><i aria-hidden="true" class="v-icon notranslate mdi mdi-star theme--light" data-v-4255d580=""></i></div> <!-- --></div></a></div>
# <div class="col-sm-6 col-md-4 col-lg-3 col-12"><a class="wrapper ma-2 v-card v-card--link v-sheet v-sheet--outlined theme--light elevation-0 wrapper--gallery" data-v-4255d580="" href="/meubles-objets-art/collection-dappareils-photo-et-accessoires-vente-en-live-avec-public-restreint-en-salle-285617/lot-26340886.html" tabindex="0"><div class="v-card__text text--primary pa-0 dense" data-v-4255d580=""><div class="container pa-0 container--fluid fill-height" data-v-4255d580=""><div class="image col col-12 pa-0" data-v-4255d580=""><div data-v-4255d580=""><div class="v-image v-responsive theme--light" data-v-4255d580=""><div class="v-image__image v-image__image--preload v-image__image--cover" style="background-image:;background-position:center center;"></div><div class="v-responsive__content"></div></div> <div class="more-media-wrapper" data-v-4255d580=""><!-- --></div></div></div> <div class="body px-4 py-2 d-flex flex-column col col-12 align-self-stretch" data-v-4255d580=""><div class="flex-grow-1" data-v-4255d580=""><!-- --> <div class="row ma-0" data-v-4255d580=""><div class="text-h6" data-v-4255d580=""><span data-v-4255d580="">Lot n°108</span></div> <button class="ml-auto v-btn v-btn--flat v-btn--icon v-btn--round theme--light v-size--default" data-v-35d523de="" data-v-4255d580="" type="button"><span class="v-btn__content"><i aria-hidden="true" class="v-icon notranslate mdi mdi-heart-outline theme--light" data-v-35d523de=""></i> <!-- --></span></button></div> <div class="row ma-0 description text-body-2 my-2" data-v-4255d580="">
#               Deux appareils photo : Nikon D1 et Nikon F5
#             </div> <div class="row ma-0 estimates text-subtitle-2" data-v-4255d580=""><span data-v-4255d580="">Est. : 20 - 30 €</span></div> <div class="row estimates text-body-2 ma-0" data-v-4255d580=""><!-- --></div></div> <div class="row flex-grow-0 justify-end mt-2 mr-n2" data-v-4255d580=""><span class="v-tooltip v-tooltip--top" data-v-4255d580=""><!-- --><div aria-expanded="false" aria-haspopup="true"><div class="v-dialog__container" role="dialog"><button class="v-btn v-btn--disabled v-btn--flat v-btn--text theme--light v-size--default" disabled="disabled" type="button"><span class="v-btn__content">
#       Déposer un ordre
#     </span></button><!-- --></div></div></span></div></div></div></div> <!-- --></a></div>
# <div class="col-sm-6 col-md-4 col-lg-3 col-12"><a class="wrapper ma-2 v-card v-card--link v-sheet v-sheet--outlined theme--light elevation-0 wrapper--gallery" data-v-4255d580="" href="/meubles-objets-art/collection-dappareils-photo-et-accessoires-vente-en-live-avec-public-restreint-en-salle-285617/lot-26340788.html" tabindex="0"><div class="v-card__text text--primary pa-0 dense" data-v-4255d580=""><div class="container pa-0 container--fluid fill-height" data-v-4255d580=""><div class="image col col-12 pa-0" data-v-4255d580=""><div data-v-4255d580=""><div class="v-image v-responsive theme--light" data-v-4255d580=""><div class="v-image__image v-image__image--preload v-image__image--cover" style="background-image:;background-position:center center;"></div><div class="v-responsive__content"></div></div> <div class="more-media-wrapper" data-v-4255d580=""><!-- --></div></div></div> <div class="body px-4 py-2 d-flex flex-column col col-12 align-self-stretch" data-v-4255d580=""><div class="flex-grow-1" data-v-4255d580=""><!-- --> <div class="row ma-0" data-v-4255d580=""><div class="text-h6" data-v-4255d580=""><span data-v-4255d580="">Lot n°98</span></div> <button class="ml-auto v-btn v-btn--flat v-btn--icon v-btn--round theme--light v-size--default" data-v-35d523de="" data-v-4255d580="" type="button"><span class="v-btn__content"><i aria-hidden="true" class="v-icon notranslate mdi mdi-heart-outline theme--light" data-v-35d523de=""></i> <!-- --></span></button></div> <div class="row ma-0 description text-body-2 my-2" data-v-4255d580="">
#               Deux appareils photo : Miranda Sensorex et Sensorex II
#             </div> <div class="row ma-0 estimates text-subtitle-2" data-v-4255d580=""><span data-v-4255d580="">Est. : 10 - 15 €</span></div> <div class="row estimates text-body-2 ma-0" data-v-4255d580=""><!-- --></div></div> <div class="row flex-grow-0 justify-end mt-2 mr-n2" data-v-4255d580=""><span class="v-tooltip v-tooltip--top" data-v-4255d580=""><!-- --><div aria-expanded="false" aria-haspopup="true"><div class="v-dialog__container" role="dialog"><button class="v-btn v-btn--disabled v-btn--flat v-btn--text theme--light v-size--default" disabled="disabled" type="button"><span class="v-btn__content">
#       Déposer un ordre
#     </span></button><!-- --></div></div></span></div></div></div></div> <!-- --></a></div>
# <div class="col-sm-6 col-md-4 col-lg-3 col-12"><a class="wrapper ma-2 v-card v-card--link v-sheet v-sheet--outlined theme--light elevation-0 wrapper--gallery" data-v-4255d580="" href="/meubles-objets-art/collection-dappareils-photo-et-accessoires-vente-en-live-avec-public-restreint-en-salle-285617/lot-26340785.html" tabindex="0"><div class="v-card__text text--primary pa-0 dense" data-v-4255d580=""><div class="container pa-0 container--fluid fill-height" data-v-4255d580=""><div class="image col col-12 pa-0" data-v-4255d580=""><div data-v-4255d580=""><div class="v-image v-responsive theme--light" data-v-4255d580=""><div class="v-image__image v-image__image--preload v-image__image--cover" style="background-image:;background-position:center center;"></div><div class="v-responsive__content"></div></div> <div class="more-media-wrapper" data-v-4255d580=""><!-- --></div></div></div> <div class="body px-4 py-2 d-flex flex-column col col-12 align-self-stretch" data-v-4255d580=""><div class="flex-grow-1" data-v-4255d580=""><!-- --> <div class="row ma-0" data-v-4255d580=""><div class="text-h6" data-v-4255d580=""><span data-v-4255d580="">Lot n°102</span></div> <button class="ml-auto v-btn v-btn--flat v-btn--icon v-btn--round theme--light v-size--default" data-v-35d523de="" data-v-4255d580="" type="button"><span class="v-btn__content"><i aria-hidden="true" class="v-icon notranslate mdi mdi-heart-outline theme--light" data-v-35d523de=""></i> <!-- --></span></button></div> <div class="row ma-0 description text-body-2 my-2" data-v-4255d580="">
#               Deux appareils photo : Stereo Realist et Argus C3, avec accessoires
#             </div> <div class="row ma-0 estimates text-subtitle-2" data-v-4255d580=""><span data-v-4255d580="">Est. : 10 - 15 €</span></div> <div class="row estimates text-body-2 ma-0" data-v-4255d580=""><!-- --></div></div> <div class="row flex-grow-0 justify-end mt-2 mr-n2" data-v-4255d580=""><span class="v-tooltip v-tooltip--top" data-v-4255d580=""><!-- --><div aria-expanded="false" aria-haspopup="true"><div class="v-dialog__container" role="dialog"><button class="v-btn v-btn--disabled v-btn--flat v-btn--text theme--light v-size--default" disabled="disabled" type="button"><span class="v-btn__content">
#       Déposer un ordre
#     </span></button><!-- --></div></div></span></div></div></div></div> <!-- --></a></div>
# <div class="col-sm-6 col-md-4 col-lg-3 col-12"><a class="wrapper ma-2 v-card v-card--link v-sheet v-sheet--outlined theme--light elevation-0 wrapper--gallery" data-v-4255d580="" href="/meubles-objets-art/collection-dappareils-photo-et-accessoires-vente-en-live-avec-public-restreint-en-salle-285617/lot-26340782.html" tabindex="0"><div class="v-card__text text--primary pa-0 dense" data-v-4255d580=""><div class="container pa-0 container--fluid fill-height" data-v-4255d580=""><div class="image col col-12 pa-0" data-v-4255d580=""><div data-v-4255d580=""><div class="v-image v-responsive theme--light" data-v-4255d580=""><div class="v-image__image v-image__image--preload v-image__image--cover" style="background-image:;background-position:center center;"></div><div class="v-responsive__content"></div></div> <div class="more-media-wrapper" data-v-4255d580=""><!-- --></div></div></div> <div class="body px-4 py-2 d-flex flex-column col col-12 align-self-stretch" data-v-4255d580=""><div class="flex-grow-1" data-v-4255d580=""><!-- --> <div class="row ma-0" data-v-4255d580=""><div class="text-h6" data-v-4255d580=""><span data-v-4255d580="">Lot n°99</span></div> <button class="ml-auto v-btn v-btn--flat v-btn--icon v-btn--round theme--light v-size--default" data-v-35d523de="" data-v-4255d580="" type="button"><span class="v-btn__content"><i aria-hidden="true" class="v-icon notranslate mdi mdi-heart-outline theme--light" data-v-35d523de=""></i> <!-- --></span></button></div> <div class="row ma-0 description text-body-2 my-2" data-v-4255d580="">
#               Cinq appareils photo : Pentax Zoom 70-X, Edixa 135 AF, Konica C35 AF, Hanimex 35 Reflex Flash, Hanimex 35 HS
#             </div> <div class="row ma-0 estimates text-subtitle-2" data-v-4255d580=""><span data-v-4255d580="">Est. : 10 - 15 €</span></div> <div class="row estimates text-body-2 ma-0" data-v-4255d580=""><!-- --></div></div> <div class="row flex-grow-0 justify-end mt-2 mr-n2" data-v-4255d580=""><span class="v-tooltip v-tooltip--top" data-v-4255d580=""><!-- --><div aria-expanded="false" aria-haspopup="true"><div class="v-dialog__container" role="dialog"><button class="v-btn v-btn--disabled v-btn--flat v-btn--text theme--light v-size--default" disabled="disabled" type="button"><span class="v-btn__content">
#       Déposer un ordre
#     </span></button><!-- --></div></div></span></div></div></div></div> <!-- --></a></div>
# <div class="col-sm-6 col-md-4 col-lg-3 col-12"><a class="wrapper ma-2 v-card v-card--link v-sheet v-sheet--outlined theme--light elevation-0 wrapper--gallery" data-v-4255d580="" href="/meubles-objets-art/collection-dappareils-photo-et-accessoires-vente-en-live-avec-public-restreint-en-salle-285617/lot-26340777.html" tabindex="0"><div class="v-card__text text--primary pa-0 dense" data-v-4255d580=""><div class="container pa-0 container--fluid fill-height" data-v-4255d580=""><div class="image col col-12 pa-0" data-v-4255d580=""><div data-v-4255d580=""><div class="v-image v-responsive theme--light" data-v-4255d580=""><div class="v-image__image v-image__image--preload v-image__image--cover" style="background-image:;background-position:center center;"></div><div class="v-responsive__content"></div></div> <div class="more-media-wrapper" data-v-4255d580=""><!-- --></div></div></div> <div class="body px-4 py-2 d-flex flex-column col col-12 align-self-stretch" data-v-4255d580=""><div class="flex-grow-1" data-v-4255d580=""><!-- --> <div class="row ma-0" data-v-4255d580=""><div class="text-h6" data-v-4255d580=""><span data-v-4255d580="">Lot n°97</span></div> <button class="ml-auto v-btn v-btn--flat v-btn--icon v-btn--round theme--light v-size--default" data-v-35d523de="" data-v-4255d580="" type="button"><span class="v-btn__content"><i aria-hidden="true" class="v-icon notranslate mdi mdi-heart-outline theme--light" data-v-35d523de=""></i> <!-- --></span></button></div> <div class="row ma-0 description text-body-2 my-2" data-v-4255d580="">
#               Trois appareils photo : Mamiya ZE quartz, Nikkormat, Pentax ME
# (accidents et manques)
#             </div> <div class="row ma-0 estimates text-subtitle-2" data-v-4255d580=""><span data-v-4255d580="">Est. : 5 - 10 €</span></div> <div class="row estimates text-body-2 ma-0" data-v-4255d580=""><!-- --></div></div> <div class="row flex-grow-0 justify-end mt-2 mr-n2" data-v-4255d580=""><span class="v-tooltip v-tooltip--top" data-v-4255d580=""><!-- --><div aria-expanded="false" aria-haspopup="true"><div class="v-dialog__container" role="dialog"><button class="v-btn v-btn--disabled v-btn--flat v-btn--text theme--light v-size--default" disabled="disabled" type="button"><span class="v-btn__content">
#       Déposer un ordre
#     </span></button><!-- --></div></div></span></div></div></div></div> <!-- --></a></div>
# <div class="col-sm-6 col-md-4 col-lg-3 col-12"><a class="wrapper ma-2 v-card v-card--link v-sheet v-sheet--outlined theme--light elevation-0 wrapper--gallery" data-v-4255d580="" href="/meubles-objets-art/collection-dappareils-photo-et-accessoires-vente-en-live-avec-public-restreint-en-salle-285617/lot-26340773.html" tabindex="0"><div class="v-card__text text--primary pa-0 dense" data-v-4255d580=""><div class="container pa-0 container--fluid fill-height" data-v-4255d580=""><div class="image col col-12 pa-0" data-v-4255d580=""><div data-v-4255d580=""><div class="v-image v-responsive theme--light" data-v-4255d580=""><div class="v-image__image v-image__image--preload v-image__image--cover" style="background-image:;background-position:center center;"></div><div class="v-responsive__content"></div></div> <div class="more-media-wrapper" data-v-4255d580=""><!-- --></div></div></div> <div class="body px-4 py-2 d-flex flex-column col col-12 align-self-stretch" data-v-4255d580=""><div class="flex-grow-1" data-v-4255d580=""><!-- --> <div class="row ma-0" data-v-4255d580=""><div class="text-h6" data-v-4255d580=""><span data-v-4255d580="">Lot n°101</span></div> <button class="ml-auto v-btn v-btn--flat v-btn--icon v-btn--round theme--light v-size--default" data-v-35d523de="" data-v-4255d580="" type="button"><span class="v-btn__content"><i aria-hidden="true" class="v-icon notranslate mdi mdi-heart-outline theme--light" data-v-35d523de=""></i> <!-- --></span></button></div> <div class="row ma-0 description text-body-2 my-2" data-v-4255d580="">
#               Neuf appareils photo : Hanimex 35 Micro Flash, Rollei A26, Rolleil 35 LED, Rolleil 35 SE, Rollei 35, Agfamatic 100, Pentax auto110
#             </div> <div class="row ma-0 estimates text-subtitle-2" data-v-4255d580=""><span data-v-4255d580="">Est. : 10 - 15 €</span></div> <div class="row estimates text-body-2 ma-0" data-v-4255d580=""><!-- --></div></div> <div class="row flex-grow-0 justify-end mt-2 mr-n2" data-v-4255d580=""><span class="v-tooltip v-tooltip--top" data-v-4255d580=""><!-- --><div aria-expanded="false" aria-haspopup="true"><div class="v-dialog__container" role="dialog"><button class="v-btn v-btn--disabled v-btn--flat v-btn--text theme--light v-size--default" disabled="disabled" type="button"><span class="v-btn__content">
#       Déposer un ordre
#     </span></button><!-- --></div></div></span></div></div></div></div> <!-- --></a></div>
# <div class="col-sm-6 col-md-4 col-lg-3 col-12"><a class="wrapper ma-2 v-card v-card--link v-sheet v-sheet--outlined theme--light elevation-0 wrapper--gallery" data-v-4255d580="" href="/meubles-objets-art/collection-dappareils-photo-et-accessoires-vente-en-live-avec-public-restreint-en-salle-285617/lot-26340770.html" tabindex="0"><div class="v-card__text text--primary pa-0 dense" data-v-4255d580=""><div class="container pa-0 container--fluid fill-height" data-v-4255d580=""><div class="image col col-12 pa-0" data-v-4255d580=""><div data-v-4255d580=""><div class="v-image v-responsive theme--light" data-v-4255d580=""><div class="v-image__image v-image__image--preload v-image__image--cover" style="background-image:;background-position:center center;"></div><div class="v-responsive__content"></div></div> <div class="more-media-wrapper" data-v-4255d580=""><!-- --></div></div></div> <div class="body px-4 py-2 d-flex flex-column col col-12 align-self-stretch" data-v-4255d580=""><div class="flex-grow-1" data-v-4255d580=""><!-- --> <div class="row ma-0" data-v-4255d580=""><div class="text-h6" data-v-4255d580=""><span data-v-4255d580="">Lot n°100</span></div> <button class="ml-auto v-btn v-btn--flat v-btn--icon v-btn--round theme--light v-size--default" data-v-35d523de="" data-v-4255d580="" type="button"><span class="v-btn__content"><i aria-hidden="true" class="v-icon notranslate mdi mdi-heart-outline theme--light" data-v-35d523de=""></i> <!-- --></span></button></div> <div class="row ma-0 description text-body-2 my-2" data-v-4255d580="">
#               Huit appareils photo : Pentax Zoom 90, Meikai AR-4367, Konica MG/D, Nikon AF, Yashica Partner AF, Gaf 440, Gevaert 144, Impera Indo
#             </div> <div class="row ma-0 estimates text-subtitle-2" data-v-4255d580=""><span data-v-4255d580="">Est. : 10 - 15 €</span></div> <div class="row estimates text-body-2 ma-0" data-v-4255d580=""><!-- --></div></div> <div class="row flex-grow-0 justify-end mt-2 mr-n2" data-v-4255d580=""><span class="v-tooltip v-tooltip--top" data-v-4255d580=""><!-- --><div aria-expanded="false" aria-haspopup="true"><div class="v-dialog__container" role="dialog"><button class="v-btn v-btn--disabled v-btn--flat v-btn--text theme--light v-size--default" disabled="disabled" type="button"><span class="v-btn__content">
#       Déposer un ordre
#     </span></button><!-- --></div></div></span></div></div></div></div> <!-- --></a></div>
# <div class="col-sm-6 col-md-4 col-lg-3 col-12"><a class="wrapper ma-2 v-card v-card--link v-sheet v-sheet--outlined theme--light elevation-0 wrapper--gallery" data-v-4255d580="" href="/meubles-objets-art/collection-dappareils-photo-et-accessoires-vente-en-live-avec-public-restreint-en-salle-285617/lot-26340769.html" tabindex="0"><div class="v-card__text text--primary pa-0 dense" data-v-4255d580=""><div class="container pa-0 container--fluid fill-height" data-v-4255d580=""><div class="image col col-12 pa-0" data-v-4255d580=""><div data-v-4255d580=""><div class="v-image v-responsive theme--light" data-v-4255d580=""><div class="v-image__image v-image__image--preload v-image__image--cover" style="background-image:;background-position:center center;"></div><div class="v-responsive__content"></div></div> <div class="more-media-wrapper" data-v-4255d580=""><!-- --></div></div></div> <div class="body px-4 py-2 d-flex flex-column col col-12 align-self-stretch" data-v-4255d580=""><div class="flex-grow-1" data-v-4255d580=""><!-- --> <div class="row ma-0" data-v-4255d580=""><div class="text-h6" data-v-4255d580=""><span data-v-4255d580="">Lot n°91</span></div> <button class="ml-auto v-btn v-btn--flat v-btn--icon v-btn--round theme--light v-size--default" data-v-35d523de="" data-v-4255d580="" type="button"><span class="v-btn__content"><i aria-hidden="true" class="v-icon notranslate mdi mdi-heart-outline theme--light" data-v-35d523de=""></i> <!-- --></span></button></div> <div class="row ma-0 description text-body-2 my-2" data-v-4255d580="">
#               Lot d’appareils photo anciens : Kodak, Coronet, Lumière et divers
# (accidents et manques)
#             </div> <div class="row ma-0 estimates text-subtitle-2" data-v-4255d580=""><span data-v-4255d580="">Est. : 5 - 10 €</span></div> <div class="row estimates text-body-2 ma-0" data-v-4255d580=""><!-- --></div></div> <div class="row flex-grow-0 justify-end mt-2 mr-n2" data-v-4255d580=""><span class="v-tooltip v-tooltip--top" data-v-4255d580=""><!-- --><div aria-expanded="false" aria-haspopup="true"><div class="v-dialog__container" role="dialog"><button class="v-btn v-btn--disabled v-btn--flat v-btn--text theme--light v-size--default" disabled="disabled" type="button"><span class="v-btn__content">
#       Déposer un ordre
#     </span></button><!-- --></div></div></span></div></div></div></div> <!-- --></a></div>
# <div class="col-sm-6 col-md-4 col-lg-3 col-12"><a class="wrapper ma-2 v-card v-card--link v-sheet v-sheet--outlined theme--light elevation-0 wrapper--gallery" data-v-4255d580="" href="/meubles-objets-art/collection-dappareils-photo-et-accessoires-vente-en-live-avec-public-restreint-en-salle-285617/lot-26340768.html" tabindex="0"><div class="v-card__text text--primary pa-0 dense" data-v-4255d580=""><div class="container pa-0 container--fluid fill-height" data-v-4255d580=""><div class="image col col-12 pa-0" data-v-4255d580=""><div data-v-4255d580=""><div class="v-image v-responsive theme--light" data-v-4255d580=""><div class="v-image__image v-image__image--preload v-image__image--cover" style="background-image:;background-position:center center;"></div><div class="v-responsive__content"></div></div> <div class="more-media-wrapper" data-v-4255d580=""><!-- --></div></div></div> <div class="body px-4 py-2 d-flex flex-column col col-12 align-self-stretch" data-v-4255d580=""><div class="flex-grow-1" data-v-4255d580=""><!-- --> <div class="row ma-0" data-v-4255d580=""><div class="text-h6" data-v-4255d580=""><span data-v-4255d580="">Lot n°92</span></div> <button class="ml-auto v-btn v-btn--flat v-btn--icon v-btn--round theme--light v-size--default" data-v-35d523de="" data-v-4255d580="" type="button"><span class="v-btn__content"><i aria-hidden="true" class="v-icon notranslate mdi mdi-heart-outline theme--light" data-v-35d523de=""></i> <!-- --></span></button></div> <div class="row ma-0 description text-body-2 my-2" data-v-4255d580="">
#               Trois appareils photo dont deux Kranogorsk Moskva
# (manques)
#             </div> <div class="row ma-0 estimates text-subtitle-2" data-v-4255d580=""><span data-v-4255d580="">Est. : 5 - 10 €</span></div> <div class="row estimates text-body-2 ma-0" data-v-4255d580=""><!-- --></div></div> <div class="row flex-grow-0 justify-end mt-2 mr-n2" data-v-4255d580=""><span class="v-tooltip v-tooltip--top" data-v-4255d580=""><!-- --><div aria-expanded="false" aria-haspopup="true"><div class="v-dialog__container" role="dialog"><button class="v-btn v-btn--disabled v-btn--flat v-btn--text theme--light v-size--default" disabled="disabled" type="button"><span class="v-btn__content">
#       Déposer un ordre
#     </span></button><!-- --></div></div></span></div></div></div></div> <!-- --></a></div>
# <div class="col-sm-6 col-md-4 col-lg-3 col-12"><a class="wrapper ma-2 v-card v-card--link v-sheet v-sheet--outlined theme--light elevation-0 wrapper--gallery" data-v-4255d580="" href="/meubles-objets-art/collection-dappareils-photo-et-accessoires-vente-en-live-avec-public-restreint-en-salle-285617/lot-26340767.html" tabindex="0"><div class="v-card__text text--primary pa-0 dense" data-v-4255d580=""><div class="container pa-0 container--fluid fill-height" data-v-4255d580=""><div class="image col col-12 pa-0" data-v-4255d580=""><div data-v-4255d580=""><div class="v-image v-responsive theme--light" data-v-4255d580=""><div class="v-image__image v-image__image--preload v-image__image--cover" style="background-image:;background-position:center center;"></div><div class="v-responsive__content"></div></div> <div class="more-media-wrapper" data-v-4255d580=""><!-- --></div></div></div> <div class="body px-4 py-2 d-flex flex-column col col-12 align-self-stretch" data-v-4255d580=""><div class="flex-grow-1" data-v-4255d580=""><!-- --> <div class="row ma-0" data-v-4255d580=""><div class="text-h6" data-v-4255d580=""><span data-v-4255d580="">Lot n°93</span></div> <button class="ml-auto v-btn v-btn--flat v-btn--icon v-btn--round theme--light v-size--default" data-v-35d523de="" data-v-4255d580="" type="button"><span class="v-btn__content"><i aria-hidden="true" class="v-icon notranslate mdi mdi-heart-outline theme--light" data-v-35d523de=""></i> <!-- --></span></button></div> <div class="row ma-0 description text-body-2 my-2" data-v-4255d580="">
#               Quatre appareils photo : Kinax, Rheinmetall Weltax, Agfa Solinette, Kodak Kodex
#             </div> <div class="row ma-0 estimates text-subtitle-2" data-v-4255d580=""><span data-v-4255d580="">Est. : 10 - 15 €</span></div> <div class="row estimates text-body-2 ma-0" data-v-4255d580=""><!-- --></div></div> <div class="row flex-grow-0 justify-end mt-2 mr-n2" data-v-4255d580=""><span class="v-tooltip v-tooltip--top" data-v-4255d580=""><!-- --><div aria-expanded="false" aria-haspopup="true"><div class="v-dialog__container" role="dialog"><button class="v-btn v-btn--disabled v-btn--flat v-btn--text theme--light v-size--default" disabled="disabled" type="button"><span class="v-btn__content">
#       Déposer un ordre
#     </span></button><!-- --></div></div></span></div></div></div></div> <!-- --></a></div>
# <div class="col-sm-6 col-md-4 col-lg-3 col-12"><a class="wrapper ma-2 v-card v-card--link v-sheet v-sheet--outlined theme--light elevation-0 wrapper--gallery" data-v-4255d580="" href="/meubles-objets-art/collection-dappareils-photo-et-accessoires-vente-en-live-avec-public-restreint-en-salle-285617/lot-26340766.html" tabindex="0"><div class="v-card__text text--primary pa-0 dense" data-v-4255d580=""><div class="container pa-0 container--fluid fill-height" data-v-4255d580=""><div class="image col col-12 pa-0" data-v-4255d580=""><div data-v-4255d580=""><div class="v-image v-responsive theme--light" data-v-4255d580=""><div class="v-image__image v-image__image--preload v-image__image--cover" style="background-image:;background-position:center center;"></div><div class="v-responsive__content"></div></div> <div class="more-media-wrapper" data-v-4255d580=""><!-- --></div></div></div> <div class="body px-4 py-2 d-flex flex-column col col-12 align-self-stretch" data-v-4255d580=""><div class="flex-grow-1" data-v-4255d580=""><!-- --> <div class="row ma-0" data-v-4255d580=""><div class="text-h6" data-v-4255d580=""><span data-v-4255d580="">Lot n°95</span></div> <button class="ml-auto v-btn v-btn--flat v-btn--icon v-btn--round theme--light v-size--default" data-v-35d523de="" data-v-4255d580="" type="button"><span class="v-btn__content"><i aria-hidden="true" class="v-icon notranslate mdi mdi-heart-outline theme--light" data-v-35d523de=""></i> <!-- --></span></button></div> <div class="row ma-0 description text-body-2 my-2" data-v-4255d580="">
#               Deux appareils photo : Paillard Bolex L8, Boyer Serie VIII
# On y joint un appareil à soufflet non identifié (manques)
#             </div> <div class="row ma-0 estimates text-subtitle-2" data-v-4255d580=""><span data-v-4255d580="">Est. : 5 - 10 €</span></div> <div class="row estimates text-body-2 ma-0" data-v-4255d580=""><!-- --></div></div> <div class="row flex-grow-0 justify-end mt-2 mr-n2" data-v-4255d580=""><span class="v-tooltip v-tooltip--top" data-v-4255d580=""><!-- --><div aria-expanded="false" aria-haspopup="true"><div class="v-dialog__container" role="dialog"><button class="v-btn v-btn--disabled v-btn--flat v-btn--text theme--light v-size--default" disabled="disabled" type="button"><span class="v-btn__content">
#       Déposer un ordre
#     </span></button><!-- --></div></div></span></div></div></div></div> <!-- --></a></div>
# <div class="col-sm-6 col-md-4 col-lg-3 col-12"><a class="wrapper ma-2 v-card v-card--link v-sheet v-sheet--outlined theme--light elevation-0 wrapper--gallery" data-v-4255d580="" href="/meubles-objets-art/collection-dappareils-photo-et-accessoires-vente-en-live-avec-public-restreint-en-salle-285617/lot-26340765.html" tabindex="0"><div class="v-card__text text--primary pa-0 dense" data-v-4255d580=""><div class="container pa-0 container--fluid fill-height" data-v-4255d580=""><div class="image col col-12 pa-0" data-v-4255d580=""><div data-v-4255d580=""><div class="v-image v-responsive theme--light" data-v-4255d580=""><div class="v-image__image v-image__image--preload v-image__image--cover" style="background-image:;background-position:center center;"></div><div class="v-responsive__content"></div></div> <div class="more-media-wrapper" data-v-4255d580=""><!-- --></div></div></div> <div class="body px-4 py-2 d-flex flex-column col col-12 align-self-stretch" data-v-4255d580=""><div class="flex-grow-1" data-v-4255d580=""><!-- --> <div class="row ma-0" data-v-4255d580=""><div class="text-h6" data-v-4255d580=""><span data-v-4255d580="">Lot n°94</span></div> <button class="ml-auto v-btn v-btn--flat v-btn--icon v-btn--round theme--light v-size--default" data-v-35d523de="" data-v-4255d580="" type="button"><span class="v-btn__content"><i aria-hidden="true" class="v-icon notranslate mdi mdi-heart-outline theme--light" data-v-35d523de=""></i> <!-- --></span></button></div> <div class="row ma-0 description text-body-2 my-2" data-v-4255d580="">
#               Sept appareils photo : Carena 135E, Braun Paxette, Bilora Bella, Optima Rapid 125C, Balda Baldina, Dacora Digna, Durst 66
# ...
#               ZEISS IKON,
# Six appareils photo : Ikonta 520/2, Ikonta 520, Contaflex, Contaflex synchro-compur, Contaflex synchro-compur-X, S310
#             </div> <div class="row ma-0 estimates text-subtitle-2" data-v-4255d580=""><span data-v-4255d580="">Est. : 15 - 20 €</span></div> <div class="row estimates text-body-2 ma-0" data-v-4255d580=""><!-- --></div></div> <div class="row flex-grow-0 justify-end mt-2 mr-n2" data-v-4255d580=""><span class="v-tooltip v-tooltip--top" data-v-4255d580=""><!-- --><div aria-expanded="false" aria-haspopup="true"><div class="v-dialog__container" role="dialog"><button class="v-btn v-btn--disabled v-btn--flat v-btn--text theme--light v-size--default" disabled="disabled" type="button"><span class="v-btn__content">
#       Déposer un ordre
#     </span></button><!-- --></div></div></span></div></div></div></div> <!-- --></a></div>
# <div class="col-sm-6 col-md-4 col-lg-3 col-12"><a class="wrapper ma-2 v-card v-card--link v-sheet v-sheet--outlined theme--light elevation-0 wrapper--gallery" data-v-4255d580="" href="/meubles-objets-art/collection-dappareils-photo-et-accessoires-vente-en-live-avec-public-restreint-en-salle-285617/lot-26340732.html" tabindex="0"><div class="v-card__text text--primary pa-0 dense" data-v-4255d580=""><div class="container pa-0 container--fluid fill-height" data-v-4255d580=""><div class="image col col-12 pa-0" data-v-4255d580=""><div data-v-4255d580=""><div class="v-image v-responsive theme--light" data-v-4255d580=""><div class="v-image__image v-image__image--preload v-image__image--cover" style="background-image:;background-position:center center;"></div><div class="v-responsive__content"></div></div> <div class="more-media-wrapper" data-v-4255d580=""><!-- --></div></div></div> <div class="body px-4 py-2 d-flex flex-column col col-12 align-self-stretch" data-v-4255d580=""><div class="flex-grow-1" data-v-4255d580=""><!-- --> <div class="row ma-0" data-v-4255d580=""><div class="text-h6" data-v-4255d580=""><span data-v-4255d580="">Lot n°57</span></div> <button class="ml-auto v-btn v-btn--flat v-btn--icon v-btn--round theme--light v-size--default" data-v-35d523de="" data-v-4255d580="" type="button"><span class="v-btn__content"><i aria-hidden="true" class="v-icon notranslate mdi mdi-heart-outline theme--light" data-v-35d523de=""></i> <!-- --></span></button></div> <div class="row ma-0 description text-body-2 my-2" data-v-4255d580="">
#               ARGUS,
# Trois appareils photo : C-Fourty-Four, A2B, 21et accessoires
#             </div> <div class="row ma-0 estimates text-subtitle-2" data-v-4255d580=""><span data-v-4255d580="">Est. : 10 - 20 €</span></div> <div class="row estimates text-body-2 ma-0" data-v-4255d580=""><!-- --></div></div> <div class="row flex-grow-0 justify-end mt-2 mr-n2" data-v-4255d580=""><span class="v-tooltip v-tooltip--top" data-v-4255d580=""><!-- --><div aria-expanded="false" aria-haspopup="true"><div class="v-dialog__container" role="dialog"><button class="v-btn v-btn--disabled v-btn--flat v-btn--text theme--light v-size--default" disabled="disabled" type="button"><span class="v-btn__content">
#       Déposer un ordre
#     </span></button><!-- --></div></div></span></div></div></div></div> <!-- --></a></div>
# <div class="col-sm-6 col-md-4 col-lg-3 col-12"><a class="wrapper ma-2 v-card v-card--link v-sheet v-sheet--outlined theme--light elevation-0 wrapper--gallery" data-v-4255d580="" href="/meubles-objets-art/collection-dappareils-photo-et-accessoires-vente-en-live-avec-public-restreint-en-salle-285617/lot-26340731.html" tabindex="0"><div class="v-card__text text--primary pa-0 dense" data-v-4255d580=""><div class="container pa-0 container--fluid fill-height" data-v-4255d580=""><div class="image col col-12 pa-0" data-v-4255d580=""><div data-v-4255d580=""><div class="v-image v-responsive theme--light" data-v-4255d580=""><div class="v-image__image v-image__image--preload v-image__image--cover" style="background-image:;background-position:center center;"></div><div class="v-responsive__content"></div></div> <div class="more-media-wrapper" data-v-4255d580=""><!-- --></div></div></div> <div class="body px-4 py-2 d-flex flex-column col col-12 align-self-stretch" data-v-4255d580=""><div class="flex-grow-1" data-v-4255d580=""><!-- --> <div class="row ma-0" data-v-4255d580=""><div class="text-h6" data-v-4255d580=""><span data-v-4255d580="">Lot n°58</span></div> <button class="ml-auto v-btn v-btn--flat v-btn--icon v-btn--round theme--light v-size--default" data-v-35d523de="" data-v-4255d580="" type="button"><span class="v-btn__content"><i aria-hidden="true" class="v-icon notranslate mdi mdi-heart-outline theme--light" data-v-35d523de=""></i> <!-- --></span></button></div> <div class="row ma-0 description text-body-2 my-2" data-v-4255d580="">
#               ARGUS,
# Quatre appareils photo : C-Fourty-Four, A2F, C-Four, C-Twentyet accessoires
#             </div> <div class="row ma-0 estimates text-subtitle-2" data-v-4255d580=""><span data-v-4255d580="">Est. : 10 - 20 €</span></div> <div class="row estimates text-body-2 ma-0" data-v-4255d580=""><!-- --></div></div> <div class="row flex-grow-0 justify-end mt-2 mr-n2" data-v-4255d580=""><span class="v-tooltip v-tooltip--top" data-v-4255d580=""><!-- --><div aria-expanded="false" aria-haspopup="true"><div class="v-dialog__container" role="dialog"><button class="v-btn v-btn--disabled v-btn--flat v-btn--text theme--light v-size--default" disabled="disabled" type="button"><span class="v-btn__content">
#       Déposer un ordre
#     </span></button><!-- --></div></div></span></div></div></div></div> <!-- --></a></div>
# <div class="col-sm-6 col-md-4 col-lg-3 col-12"><a class="wrapper ma-2 v-card v-card--link v-sheet v-sheet--outlined theme--light elevation-0 wrapper--gallery wrapper--highlight" data-v-4255d580="" href="/meubles-objets-art/collection-dappareils-photo-et-accessoires-vente-en-live-avec-public-restreint-en-salle-285617/lot-26340730.html" tabindex="0"><div class="v-card__text text--primary pa-0 dense" data-v-4255d580=""><div class="container pa-0 container--fluid fill-height" data-v-4255d580=""><div class="image col col-12 pa-0" data-v-4255d580=""><div data-v-4255d580=""><div class="v-image v-responsive theme--light" data-v-4255d580=""><div class="v-image__image v-image__image--preload v-image__image--cover" style="background-image:;background-position:center center;"></div><div class="v-responsive__content"></div></div> <div class="more-media-wrapper" data-v-4255d580=""><!-- --></div></div></div> <div class="body px-4 py-2 d-flex flex-column col col-12 align-self-stretch" data-v-4255d580=""><div class="flex-grow-1" data-v-4255d580=""><!-- --> <div class="row ma-0" data-v-4255d580=""><div class="text-h6" data-v-4255d580=""><span data-v-4255d580="">Lot n°60</span></div> <button class="ml-auto v-btn v-btn--flat v-btn--icon v-btn--round theme--light v-size--default" data-v-35d523de="" data-v-4255d580="" type="button"><span class="v-btn__content"><i aria-hidden="true" class="v-icon notranslate mdi mdi-heart-outline theme--light" data-v-35d523de=""></i> <!-- --></span></button></div> <div class="row ma-0 description text-body-2 my-2" data-v-4255d580="">
#               ZEISS IKON,
# Appareil photo Contarex avec parasoleil et étui
#             </div> <div class="row ma-0 estimates text-subtitle-2" data-v-4255d580=""><span data-v-4255d580="">Est. : 50 - 70 €</span></div> <div class="row estimates text-body-2 ma-0" data-v-4255d580=""><!-- --></div></div> <div class="row flex-grow-0 justify-end mt-2 mr-n2" data-v-4255d580=""><span class="v-tooltip v-tooltip--top" data-v-4255d580=""><!-- --><div aria-expanded="false" aria-haspopup="true"><div class="v-dialog__container" role="dialog"><button class="v-btn v-btn--disabled v-btn--flat v-btn--text theme--light v-size--default" disabled="disabled" type="button"><span class="v-btn__content">
#       Déposer un ordre
#     </span></button><!-- --></div></div></span></div></div></div></div> <div class="inner-info inner-info--highlight" data-v-4255d580=""><div class="inner-info__info inner-info__info--highlight" data-v-4255d580=""><i aria-hidden="true" class="v-icon notranslate mdi mdi-star theme--light" data-v-4255d580=""></i></div> <!-- --></div></a></div>
# <div class="col-sm-6 col-md-4 col-lg-3 col-12"><a class="wrapper ma-2 v-card v-card--link v-sheet v-sheet--outlined theme--light elevation-0 wrapper--gallery" data-v-4255d580="" href="/meubles-objets-art/collection-dappareils-photo-et-accessoires-vente-en-live-avec-public-restreint-en-salle-285617/lot-26340729.html" tabindex="0"><div class="v-card__text text--primary pa-0 dense" data-v-4255d580=""><div class="container pa-0 container--fluid fill-height" data-v-4255d580=""><div class="image col col-12 pa-0" data-v-4255d580=""><div data-v-4255d580=""><div class="v-image v-responsive theme--light" data-v-4255d580=""><div class="v-image__image v-image__image--preload v-image__image--cover" style="background-image:;background-position:center center;"></div><div class="v-responsive__content"></div></div> <div class="more-media-wrapper" data-v-4255d580=""><!-- --></div></div></div> <div class="body px-4 py-2 d-flex flex-column col col-12 align-self-stretch" data-v-4255d580=""><div class="flex-grow-1" data-v-4255d580=""><!-- --> <div class="row ma-0" data-v-4255d580=""><div class="text-h6" data-v-4255d580=""><span data-v-4255d580="">Lot n°56</span></div> <button class="ml-auto v-btn v-btn--flat v-btn--icon v-btn--round theme--light v-size--default" data-v-35d523de="" data-v-4255d580="" type="button"><span class="v-btn__content"><i aria-hidden="true" class="v-icon notranslate mdi mdi-heart-outline theme--light" data-v-35d523de=""></i> <!-- --></span></button></div> <div class="row ma-0 description text-body-2 my-2" data-v-4255d580="">
#               ARGUS,
# Quatre appareils photo : quatre C3 (variantes), Autronic 35
#             </div> <div class="row ma-0 estimates text-subtitle-2" data-v-4255d580=""><span data-v-4255d580="">Est. : 10 - 20 €</span></div> <div class="row estimates text-body-2 ma-0" data-v-4255d580=""><!-- --></div></div> <div class="row flex-grow-0 justify-end mt-2 mr-n2" data-v-4255d580=""><span class="v-tooltip v-tooltip--top" data-v-4255d580=""><!-- --><div aria-expanded="false" aria-haspopup="true"><div class="v-dialog__container" role="dialog"><button class="v-btn v-btn--disabled v-btn--flat v-btn--text theme--light v-size--default" disabled="disabled" type="button"><span class="v-btn__content">
#       Déposer un ordre
#     </span></button><!-- --></div></div></span></div></div></div></div> <!-- --></a></div>
# <div class="col-sm-6 col-md-4 col-lg-3 col-12"><a class="wrapper ma-2 v-card v-card--link v-sheet v-sheet--outlined theme--light elevation-0 wrapper--gallery" data-v-4255d580="" href="/meubles-objets-art/collection-dappareils-photo-et-accessoires-vente-en-live-avec-public-restreint-en-salle-285617/lot-26340728.html" tabindex="0"><div class="v-card__text text--primary pa-0 dense" data-v-4255d580=""><div class="container pa-0 container--fluid fill-height" data-v-4255d580=""><div class="image col col-12 pa-0" data-v-4255d580=""><div data-v-4255d580=""><div class="v-image v-responsive theme--light" data-v-4255d580=""><div class="v-image__image v-image__image--preload v-image__image--cover" style="background-image:;background-position:center center;"></div><div class="v-responsive__content"></div></div> <div class="more-media-wrapper" data-v-4255d580=""><!-- --></div></div></div> <div class="body px-4 py-2 d-flex flex-column col col-12 align-self-stretch" data-v-4255d580=""><div class="flex-grow-1" data-v-4255d580=""><!-- --> <div class="row ma-0" data-v-4255d580=""><div class="text-h6" data-v-4255d580=""><span data-v-4255d580="">Lot n°55</span></div> <button class="ml-auto v-btn v-btn--flat v-btn--icon v-btn--round theme--light v-size--default" data-v-35d523de="" data-v-4255d580="" type="button"><span class="v-btn__content"><i aria-hidden="true" class="v-icon notranslate mdi mdi-heart-outline theme--light" data-v-35d523de=""></i> <!-- --></span></button></div> <div class="row ma-0 description text-body-2 my-2" data-v-4255d580="">
#               ARGUS,
# Quatre appareils photo : LC3, C3, C33, Autronic II, Autronic 35
#             </div> <div class="row ma-0 estimates text-subtitle-2" data-v-4255d580=""><span data-v-4255d580="">Est. : 10 - 20 €</span></div> <div class="row estimates text-body-2 ma-0" data-v-4255d580=""><!-- --></div></div> <div class="row flex-grow-0 justify-end mt-2 mr-n2" data-v-4255d580=""><span class="v-tooltip v-tooltip--top" data-v-4255d580=""><!-- --><div aria-expanded="false" aria-haspopup="true"><div class="v-dialog__container" role="dialog"><button class="v-btn v-btn--disabled v-btn--flat v-btn--text theme--light v-size--default" disabled="disabled" type="button"><span class="v-btn__content">
#       Déposer un ordre
#     </span></button><!-- --></div></div></span></div></div></div></div> <!-- --></a></div>
# <div class="col-sm-6 col-md-4 col-lg-3 col-12"><a class="wrapper ma-2 v-card v-card--link v-sheet v-sheet--outlined theme--light elevation-0 wrapper--gallery" data-v-4255d580="" href="/meubles-objets-art/collection-dappareils-photo-et-accessoires-vente-en-live-avec-public-restreint-en-salle-285617/lot-26340727.html" tabindex="0"><div class="v-card__text text--primary pa-0 dense" data-v-4255d580=""><div class="container pa-0 container--fluid fill-height" data-v-4255d580=""><div class="image col col-12 pa-0" data-v-4255d580=""><div data-v-4255d580=""><div class="v-image v-responsive theme--light" data-v-4255d580=""><div class="v-image__image v-image__image--preload v-image__image--cover" style="background-image:;background-position:center center;"></div><div class="v-responsive__content"></div></div> <div class="more-media-wrapper" data-v-4255d580=""><!-- --></div></div></div> <div class="body px-4 py-2 d-flex flex-column col col-12 align-self-stretch" data-v-4255d580=""><div class="flex-grow-1" data-v-4255d580=""><!-- --> <div class="row ma-0" data-v-4255d580=""><div class="text-h6" data-v-4255d580=""><span data-v-4255d580="">Lot n°59</span></div> <button class="ml-auto v-btn v-btn--flat v-btn--icon v-btn--round theme--light v-size--default" data-v-35d523de="" data-v-4255d580="" type="button"><span class="v-btn__content"><i aria-hidden="true" class="v-icon notranslate mdi mdi-heart-outline theme--light" data-v-35d523de=""></i> <!-- --></span></button></div> <div class="row ma-0 description text-body-2 my-2" data-v-4255d580="">
#               ZEISS IKON,
# Trois appareils photo : Contina, Vitessa 1000 SR, Nettar et accessoires
#             </div> <div class="row ma-0 estimates text-subtitle-2" data-v-4255d580=""><span data-v-4255d580="">Est. : 10 - 20 €</span></div> <div class="row estimates text-body-2 ma-0" data-v-4255d580=""><!-- --></div></div> <div class="row flex-grow-0 justify-end mt-2 mr-n2" data-v-4255d580=""><span class="v-tooltip v-tooltip--top" data-v-4255d580=""><!-- --><div aria-expanded="false" aria-haspopup="true"><div class="v-dialog__container" role="dialog"><button class="v-btn v-btn--disabled v-btn--flat v-btn--text theme--light v-size--default" disabled="disabled" type="button"><span class="v-btn__content">
#       Déposer un ordre
#     </span></button><!-- --></div></div></span></div></div></div></div> <!-- --></a></div>

# %%
BASE_URL = 'https://www.drouotonline.com'
soup.find
# Out:
# <bound method Tag.find of <html class="" lang="fr"><!--<![endif]--><head>
# <meta content="text/html; charset=utf-8" http-equiv="Content-Type"/>
# <meta content="telephone=no" name="format-detection"/>
# <title>Rechercher des lots</title>
# <meta content="enchères, tableaux, design, bijoux, montres, brocante" name="keywords"/>
# <meta content="drouotonline.com" name="author"/>
# <meta content="width=device-width, initial-scale=1.0, maximum-scale=1.0, user-scalable=no" name="viewport"/>
# <meta content="true" name="HandheldFriendly"/>
# <meta content="DrouotDigital" name="copyright"/>
# <meta content="no-cache" http-equiv="cache-Control"/>
# <meta content="no-cache" http-equiv="pragma"/>
# <script async="" src="https://www.google-analytics.com/analytics.js" type="text/javascript"></script><script async="" src="https://www.googletagmanager.com/gtm.js?id=GTM-PN8H4ZT"></script><script>dataLayer = [{"userStatus":"Internaute","lang":"fr","cid":"","contentGroup1":"Recherche","contentGroup2":"","contentGroup3":"","contentGroup4":""}]</script>
# <meta content="text/html; charset=utf-8" http-equiv="Content-Type"/>
# <meta content="main" name="layout"/>
# <meta content="Ventes aux enchères live, online et cataloguée. Découvrez des milliers produits diversifiés : bijoux, meubles, objets d’art, tableaux anciens et contemporains, vins et spiritueux, mode, luminaires, argenterie et bien plus encore !" name="description"/>
# <link href="/assets/owl_carousel/owl.carousel.min-18897fb72e298d3185f39e0052aaa6e0.css" rel="stylesheet" type="text/css"/>
# <link href="/assets/owl_carousel/owl.theme.default-25637daf79c1ad95719bde4dbad877e2.css" rel="stylesheet" type="text/css"/>
# <link href="/en/search/lots" hreflang="en" rel="alternate"/>
# <!-- Preload Link -->
# <link as="font" crossorigin="anonymous" href="/assets/bootstrap/fonts/bootstrap/glyphicons-halflings-regular-fa2772327f55d8198301fdb8bcfc8158.woff" rel="preload" type="font/woff"/>
# <link as="font" crossorigin="anonymous" href="/assets/bootstrap/fonts/bootstrap/glyphicons-halflings-regular-e18bbf611f2a2e43afc071aa2f4e1512.ttf" rel="preload" type="font/ttf"/>
# <link href="/assets/logo/faviconDD-3eab651c594cab93304b374d6c990c83.ico" rel="shortcut icon" type="image/x-icon"/>
# <link href="/assets/mainApplication-d0d0e28c09a5fe69f1a647c0944f6cf2.css" rel="stylesheet"/>
# <!-- Google Tag Manager -->
# <script>
#         (function(w,d,s,l,i){w[l]=w[l]||[];w[l].push({'gtm.start':new Date().getTime(),event:'gtm.js'});var f=d.getElementsByTagName(s)[0],	j=d.createElement(s),dl=l!='dataLayer'?'&l='+l:'';j.async=true;j.src='https://www.googletagmanager.com/gtm.js?id='+i+dl;f.parentNode.insertBefore(j,f);
#         })(window,document,'script','dataLayer','GTM-PN8H4ZT');
#     </script>
# <!-- End Google Tag Manager -->
# <script src="https://cdn.jsdelivr.net/npm/vanilla-lazyload@17.1.2/dist/lazyload.min.js"></script>
# <style type="text/css">.fancybox-margin{margin-right:0px;}</style></head>
# <body class="fr isNormal page-container-bg-solid page-header-menu-fixed device-sm"><div class="wsmenucontainer" style="min-width: 929px;">
# <!-- GTM-NoScript -->
# <noscript><iframe height="0" src="https://www.googletagmanager.com/ns.html?id=GTM-PN8H4ZT" style="display:none;visibility:hidden" width="0"></iframe></noscript>
# <!-- End-GTM-NoScript -->
# <div class="page-wrapper-row">
# <div class="page-wrapper-top">
# <div class="page-header">
# <div class="page-header-menu">
# <div class="container padding0">
# <!-- MOBILE HEADER-->
# <div class="wsmobileheader clearfix">
# <a class="wsanimated-arrow" id="wsnavtoggle"><span></span></a>
# <span class="smllogo">
# <a href="/">
# <div class="logoDrouotDigital"></div>
# </a>
# </span>
# <div class="wssearch clearfix">
# <i class="wsopensearch fa fa-search"></i>
# <div class="wssearchform clearfix">
# <form action="/recherche/lots" class="topmenusearch" id="form-recherche-top">
# <input autofocus="" id="query" name="query" placeholder="Recherche d'objets par mots-clés" tabindex="1" type="text"/>
# <button class="searchMob" onclick="document.forms['form-recherche-top'].submit();" type="submit">
# <i class="fa fa-search"></i></button>
# </form>
# </div>
# </div>
# <!-- ACCES TOP : COMPTE - langue - aide - favoris : hidden-xxs -->
# <div class="accesTop hidden-xs">
# <!-- MON COMPTE -->
# <ul class="nav navbar-nav pull-right" style="z-index:inherit">
# <!-- BEGIN USER LOGIN DROPDOWN -->
# <li class="padding0 dropdown dropdown-user">
# <a class="dsi-modal-link padding0" data-dsi-url="/publicPasseport/publicLoginModal2?redirUri=" data-toggle="modal" href="#modal-content">
# <div class="btn ghost">Connexion</div>
# </a>
# </li>
# </ul>
# <a href="/compte/favoris"><div class="icon fav floatRight"></div></a>
# <a href="/aide?lang=fr"><div class="icon question floatRight"></div></a>
# <div class="floatRight choixLangue">
# <form id="dsi-save-language-form">
# <input id="dsi-redirect-url" name="url" type="hidden" value="/en/search/lots?query=appareil+photo"/>
# <input id="dsi-save-language-url" type="hidden" value="/passeport/saveLanguage"/>
# <select class="dsi-form-elm form-control" id="dsi-language" name="lang" onchange="this.form.submit()">
# <option selected="" value="fr">FR</option>
# <option value="en">EN</option>
# <option value="zh">中文</option>
# </select>
# </form>
# </div>
# </div>
# </div>
# <!-- MOBILE HEADER -->
# <!-- MENU LIGNE 1 : TOP BAR-->
# <div class="col-md-12">
# <div class="col-md-4 noPaddingLeft">
# <a href="/">
# <div class="logoDrouotDigital"></div>
# </a>
# </div>
# <!-- ACCES TOP : COMPTE - langue - aide - favoris -->
# <div class="hidden-xs hidden-sm col-md-4 noPaddingRight floatRight accesTop">
# <!-- MON COMPTE -->
# <ul class="nav navbar-nav pull-right" style="z-index:inherit">
# <!-- BEGIN USER LOGIN DROPDOWN -->
# <li class="padding0 dropdown dropdown-user">
# <a class="dsi-modal-link padding0" data-dsi-url="/publicPasseport/publicLoginModal2?redirUri=" data-toggle="modal" href="#modal-content">
# <div class="btn ghost">Connexion</div>
# </a>
# </li>
# </ul>
# <a href="/compte/favoris"><div class="icon fav floatRight"></div></a>
# <a href="/aide?lang=fr"><div class="icon question floatRight"></div></a>
# <div class="floatRight choixLangue">
# <form id="dsi-save-language-form">
# <input id="dsi-redirect-url" name="url" type="hidden" value="/en/search/lots?query=appareil+photo"/>
# <input id="dsi-save-language-url" type="hidden" value="/passeport/saveLanguage"/>
# <select class="dsi-form-elm form-control" id="dsi-language" name="lang" onchange="this.form.submit()">
# <option selected="" value="fr">FR</option>
# <option value="en">EN</option>
# <option value="zh">中文</option>
# </select>
# </form>
# </div>
# </div>
# <div class="col-sm-4 col-md-3 floatRight noPaddingRight">
# <div class="hidden-xs hidden-sm alignRight font11 search-advanced">
# <a href="/search/searchAdvanced">
# <i aria-hidden="true" class="fa fa-plus-circle marginRight5"></i>Recherche avancée
#             </a>
# </div>
# <nav class="wsmenu clearfix" style="height: 888px;"><div class="overlapblackbg"></div>
# <ul class="wsmenu-list">
# <li class="wssearchbar clearfix">
# <form action="/recherche/lots" class="topmenusearch" id="form-recherche-top">
# <input autofocus="" class="" id="query" name="query" placeholder="Recherche d'objets par mots-clés" tabindex="1" type="text" value=""/>
# <button class="btnstyle" onclick="document.forms['form-recherche-top'].submit();" type="submit">
# <i class="searchicon fa fa-search"></i></button>
# </form>
# </li>
# </ul>
# </nav>
# </div>
# <!-- MENU LIGNE 2 -->
# <div class="headerfull">
# <div class="wsmain clearfix">
# <nav class="wsmenu clearfix" style="height: 888px;"><div class="overlapblackbg"></div>
# <ul class="wsmenu-list">
# <li class="leftlogo mobOnly">
# <a href="/">
# <div class="logoDrouotDigital"></div>
# </a>
# </li>
# <li aria-haspopup="true" class="wssalemain"><span class="wsmenu-click"><i class="wsmenu-arrow"></i></span>
# <a class="navtext" href="/ventes-aux-encheres/futures">
# <span>Ventes aux enchères</span>
# </a>
# <div class="wsmegamenu clearfix halfmenu">
# <div class="container-fluid">
# <div class="row">
# <div class="col-lg-12 padding0">
# <ul class="wstliststy02 clearfix">
# <li>
# <a href="/ventes-aux-encheres/futures">
# <i class="fa fa-angle-right"></i>Toutes les ventes
#                                             </a>
# </li>
# <li>
# <a href="/ventes-aux-encheres/aujourdhui">
# <i class="fa fa-angle-right"></i>Ventes du jour
#                                             </a>
# </li>
# <li>
# <a href="/ventes-aux-encheres/futures?venteType=live">
# <i class="fa fa-angle-right"></i>Ventes Live
#
#                                             </a>
# </li>
# <li>
# <a href="/ventes-aux-encheres/futures?venteType=online">
# <i class="fa fa-angle-right"></i>Ventes Online
#                                             </a>
# </li>
# <li>
# <a href="/ventes-aux-encheres/futures?venteType=live&amp;lieuxExpo=HOTEL-DROUOT">
# <i class="fa fa-angle-right"></i>Ventes à l'Hôtel Drouot
#                                             </a>
# </li>
# </ul>
# </div>
# </div>
# </div>
# </div>
# </li>
# <li aria-haspopup="true" class="wssalemain">
# <a class="navtext" href="/ventes-aux-encheres/futures?venteType=buynow">
# <span>Buy now</span>
# </a>
# </li>
# <div class="wsclear"></div>
# <li aria-haspopup="true" class="wscatmain"><span class="wsmenu-click"><i class="wsmenu-arrow"></i></span>
# <a class="navtext c-cat6" href="/specialites/1055/Arts%20du%20monde?lotGroupTheme=all&amp;offset=0">
# <span>Arts du monde</span></a>
# <div class="wsmegamenu clearfix">
# <div class="container-fluid">
# <div class="row">
# <div class="col-lg-12">
# <ul class="wstliststy02 clearfix" style="padding: 0">
# <li class="wstheading clearfix">
# <a href="/specialites/1055/Arts%20du%20monde?lotGroupTheme=all&amp;offset=0">
#                                                     Arts du monde</a>
# </li>
# </ul>
# </div>
# <div class="col-lg-12">
# <div class="col-sm-12 col-md-5 padding0">
# <ul class="wstliststy02 clearfix">
# <li>
# <a href="/specialites/16/Arch%C3%A9ologie%20-%20Antiquit%C3%A9?lotGroupTheme=all&amp;offset=0">
# <i class="fa fa-angle-right"></i>Archéologie - Antiquité</a>
# </li>
# <li>
# <a href="/specialites/5/Arts%20d%27Afrique%2C%20d%27Am%C3%A9rique%20et%20d%27Oc%C3%A9anie?lotGroupTheme=all&amp;offset=0">
# <i class="fa fa-angle-right"></i>Arts d'Afrique, d'Amérique et d'Océanie</a>
# </li>
# </ul>
# </div>
# <div class="col-sm-12 col-md-3 padding0">
# <ul class="wstliststy02 clearfix">
# <li>
# <a href="/specialites/119/Art%20inuit?lotGroupTheme=all&amp;offset=0">
# <i class="fa fa-angle-right"></i>Art inuit</a>
# </li>
# <li>
# <a href="/specialites/152/Art%20islamique?lotGroupTheme=all&amp;offset=0">
# <i class="fa fa-angle-right"></i>Art islamique</a>
# </li>
# </ul>
# </div>
# <div class="col-sm-12 col-md-2 padding0">
# <ul class="wstliststy02 clearfix">
# <li>
# <a href="/specialites/126/Juda%C3%AFca?lotGroupTheme=all&amp;offset=0">
# <i class="fa fa-angle-right"></i>Judaïca</a>
# </li>
# <li>
# <a href="/specialites/312/Religions?lotGroupTheme=all&amp;offset=0">
# <i class="fa fa-angle-right"></i>Religions</a>
# </li>
# </ul>
# </div>
# <div class="col-sm-12 col-md-2 padding0">
# <ul class="wstliststy02 clearfix">
# <li>
# <a href="/specialites/321/Tableaux%20russes?lotGroupTheme=all&amp;offset=0">
# <i class="fa fa-angle-right"></i>Tableaux russes</a>
# </li>
# </ul>
# </div>
# </div>
# </div>
# </div>
# </div>
# </li>
# <li aria-haspopup="true" class="wscatmain">
# <a class="navtext c-cat5" href="/specialites/43/Arts%20d%27Asie?lotGroupTheme=all&amp;offset=0">
# <span>Arts d'Asie</span></a>
# </li>
# <li aria-haspopup="true" class="wscatmain"><span class="wsmenu-click"><i class="wsmenu-arrow"></i></span>
# <a class="navtext c-cat4" href="/specialites/1053/Luxe%20%26%20Art%20de%20vivre?lotGroupTheme=all&amp;offset=0">
# <span>Luxe &amp; Art de vivre</span></a>
# <div class="wsmegamenu clearfix">
# <div class="container-fluid">
# <div class="row">
# <div class="col-sm-12 col-md-3">
# <ul class="wstliststy02 clearfix">
# <li class="wstheading clearfix">
# <a href="/specialites/1/Bijoux%20et%20pierres%20pr%C3%A9cieuses?lotGroupTheme=all&amp;offset=0">
#                                                     Bijoux et pierres précieuses</a>
# </li>
# <li>
# <a href="/specialites/650/Bagues?lotGroupTheme=all&amp;offset=0">
# <i class="fa fa-angle-right"></i>Bagues</a>
# </li>
# <li>
# <a href="/specialites/657/Bijoux%20homme?lotGroupTheme=all&amp;offset=0">
# <i class="fa fa-angle-right"></i>Bijoux homme</a>
# </li>
# <li>
# <a href="/specialites/651/Boucles%20d%27oreilles?lotGroupTheme=all&amp;offset=0">
# <i class="fa fa-angle-right"></i>Boucles d'oreilles</a>
# </li>
# <li>
# <a href="/specialites/652/Boutons%20de%20manchettes?lotGroupTheme=all&amp;offset=0">
# <i class="fa fa-angle-right"></i>Boutons de manchettes</a>
# </li>
# <li>
# <a href="/specialites/653/Bracelets?lotGroupTheme=all&amp;offset=0">
# <i class="fa fa-angle-right"></i>Bracelets</a>
# </li>
# <li>
# <a href="/specialites/654/Broches%20et%20%C3%A9pingles?lotGroupTheme=all&amp;offset=0">
# <i class="fa fa-angle-right"></i>Broches et épingles</a>
# </li>
# <li>
# <a href="/specialites/655/Colliers%2C%20colliers%20de%20perles%20et%20sautoirs?lotGroupTheme=all&amp;offset=0">
# <i class="fa fa-angle-right"></i>Colliers, colliers de perles et sautoirs</a>
# </li>
# <li>
# <a href="/specialites/658/Pierres%20pr%C3%A9cieuses?lotGroupTheme=all&amp;offset=0">
# <i class="fa fa-angle-right"></i>Pierres précieuses</a>
# </li>
# <li>
# <a href="/specialites/659/Pierres%20fines?lotGroupTheme=all&amp;offset=0">
# <i class="fa fa-angle-right"></i>Pierres fines</a>
# </li>
# <li>
# <a href="/specialites/656/Pendentifs?lotGroupTheme=all&amp;offset=0">
# <i class="fa fa-angle-right"></i>Pendentifs</a>
# </li>
# </ul>
# </div>
# <div class="ccol-sm-12 col-md-3">
# <ul class="wstliststy02 clearfix">
# <li class="wstheading clearfix">
# <a href="/specialites/204/Mode%20et%20vintage?lotGroupTheme=all&amp;offset=0">
#                                                     Mode et vintage</a>
# </li>
# <li>
# <a href="/specialites/695/Ceintures%20et%20accessoires?lotGroupTheme=all&amp;offset=0">
# <i class="fa fa-angle-right"></i>Ceintures et accessoires</a>
# </li>
# <li>
# <a href="/specialites/341/Fourrures?lotGroupTheme=all&amp;offset=0">
# <i class="fa fa-angle-right"></i>Fourrures</a>
# </li>
# <li>
# <a href="/specialites/209/haute-couture?lotGroupTheme=all&amp;offset=0">
# <i class="fa fa-angle-right"></i>Haute couture </a>
# </li>
# <li>
# <a href="/specialites/696/Portefeuilles?lotGroupTheme=all&amp;offset=0">
# <i class="fa fa-angle-right"></i>Portefeuilles</a>
# </li>
# <li>
# <a href="/specialites/697/Sacs%20%C3%A0%20main?lotGroupTheme=all&amp;offset=0">
# <i class="fa fa-angle-right"></i>Sacs à main</a>
# </li>
# <li>
# <a href="/specialites/42/Tapisseries?lotGroupTheme=all&amp;offset=0">
# <i class="fa fa-angle-right"></i>Tapisseries</a>
# </li>
# <li>
# <a href="/specialites/464/Textile%2C%20dentelles%2C%20tissu?lotGroupTheme=all&amp;offset=0">
# <i class="fa fa-angle-right"></i>Textile, dentelles, tissu</a>
# </li>
# <li>
# <a href="/specialites/190/Valises%20et%20malles?lotGroupTheme=all&amp;offset=0">
# <i class="fa fa-angle-right"></i>Valises et malles</a>
# </li>
# <li>
# <a href="/specialites/185/V%C3%AAtements%20et%20mode?lotGroupTheme=all&amp;offset=0">
# <i class="fa fa-angle-right"></i>Vêtements et mode</a>
# </li>
# </ul>
# </div>
# <div class="col-sm-12 col-md-3">
# <ul class="wstliststy02 clearfix">
# <li class="wstheading clearfix">
# <a href="/specialites/622/Montres%20et%20horlogerie?lotGroupTheme=all&amp;offset=0">
#                                                     Montres et horlogerie</a>
# </li>
# <li>
# <a href="/specialites/9/Montres%20bracelet?lotGroupTheme=all&amp;offset=0">
# <i class="fa fa-angle-right"></i>Montres bracelet</a>
# </li>
# <li>
# <a href="/specialites/701/Montres%20gousset%20et%20poche?lotGroupTheme=all&amp;offset=0">
# <i class="fa fa-angle-right"></i>Montres gousset et poche</a>
# </li>
# <li>
# <a href="/specialites/437/Pendules%20et%20garniture%20de%20chemin%C3%A9e?lotGroupTheme=all&amp;offset=0">
# <i class="fa fa-angle-right"></i>Pendules et garniture de cheminée</a>
# </li>
# </ul>
# <ul class="wstliststy02 clearfix">
# <li class="wstheading clearfix">
#
#                                                     Marques de luxe
#                                                     <span class="wstmenutag greentag">nouveau</span>
# </li>
# <li><i class="fa fa-angle-right"></i><a href="/recherche/lots?query=cartier&amp;categorie=1,204">Cartier</a></li>
# <li><i class="fa fa-angle-right"></i><a href="/recherche/lots?query=chanel&amp;categorie=1,204">Chanel</a></li>
# <li><i class="fa fa-angle-right"></i><a href="/recherche/lots?query=hermès&amp;categorie=1,204">Hermès</a></li>
# <li><i class="fa fa-angle-right"></i><a href="/recherche/lots?query=rolex&amp;categorie=622">Rolex</a></li>
# </ul>
# <ul class="wstliststy02 clearfix">
# <li class="wstheading clearfix" style="border-bottom:transparent">
# <a href="/specialites/65/Chevaux%2C%20Equitation?lotGroupTheme=all&amp;offset=0">
#                                                     Chevaux, Equitation</a>
# </li>
# </ul>
# </div>
# <div class="col-sm-12 col-md-3">
# <ul class="wstliststy02 clearfix">
# <li class="wstheading clearfix">
# <a href="/specialites/205/Arts%20de%20la%20table%20et%20argenterie?lotGroupTheme=all&amp;offset=0">
#                                                     Arts de la table et argenterie</a>
# </li>
# <li>
# <a href="/specialites/634/Accessoires%20de%20cuisine?lotGroupTheme=all&amp;offset=0">
# <i class="fa fa-angle-right"></i>Accessoires de cuisine</a>
# </li>
# <li>
# <a href="/specialites/628/Assiettes%20et%20Plats?lotGroupTheme=all&amp;offset=0">
# <i class="fa fa-angle-right"></i>Assiettes et Plats</a>
# </li>
# <li>
# <a href="/specialites/629/M%C3%A9nag%C3%A8res%20et%20Couverts?lotGroupTheme=all&amp;offset=0">
# <i class="fa fa-angle-right"></i>Ménagères et Couverts</a>
# </li>
# <li>
# <a href="/specialites/631/Pi%C3%A8ces%20de%20forme?lotGroupTheme=all&amp;offset=0">
# <i class="fa fa-angle-right"></i>Pièces de forme</a>
# </li>
# <li>
# <a href="/specialites/632/Services%20de%20table?lotGroupTheme=all&amp;offset=0">
# <i class="fa fa-angle-right"></i>Services de table</a>
# </li>
# <li>
# <a href="/specialites/194/Verres%2C%20carafes%20et%20caves%20%C3%A0%20liqueur?lotGroupTheme=all&amp;offset=0">
# <i class="fa fa-angle-right"></i>Verres, carafes et caves à liqueur</a>
# </li>
# </ul>
# <ul class="wstliststy02 clearfix">
# <li class="wstheading clearfix">
# <a href="/specialites/187/Vins%20et%20Spiritueux?lotGroupTheme=all&amp;offset=0">
#                                                     Vins et Spiritueux</a>
# </li>
# <li>
# <a href="/specialites/724/Bi%C3%A8re?lotGroupTheme=all&amp;offset=0">
# <i class="fa fa-angle-right"></i>Bière</a>
# </li>
# <li>
# <a href="/specialites/358/Champagne?lotGroupTheme=all&amp;offset=0">
# <i class="fa fa-angle-right"></i>Champagne</a>
# </li>
# <li>
# <a href="/specialites/727/Vin%20et%20pineau?lotGroupTheme=all&amp;offset=0">
# <i class="fa fa-angle-right"></i>Vin et pineau</a>
# </li>
# <li>
# <a href="/specialites/726/Whisky%2C%20rhum%20et%20cognac?lotGroupTheme=all&amp;offset=0">
# <i class="fa fa-angle-right"></i>Whisky, rhum et cognac</a>
# </li>
# </ul>
# </div>
# </div>
# </div>
# </div>
# </li>
# <li aria-haspopup="true" class="wscatmain"><span class="wsmenu-click"><i class="wsmenu-arrow"></i></span>
# <a class="navtext c-cat3" href="/specialites/1052/Collections?lotGroupTheme=all&amp;offset=0">
# <span>Collections</span></a>
# <div class="wsmegamenu clearfix">
# <div class="container-fluid">
# <div class="row">
# <div class="col-sm-12 col-md-5">
# <ul class="wstliststy02 clearfix">
# <li class="wstheading clearfix">
# <a href="/specialites/206/Objets%20de%20collection?lotGroupTheme=all&amp;offset=0">
#                                                     Objets de collection</a>
# </li>
# <li>
# <a href="/specialites/363/Animalia%20et%20taxidermie?lotGroupTheme=all&amp;offset=0">
# <i class="fa fa-angle-right"></i>Animalia et taxidermie</a>
# </li>
# <li>
# <a href="/specialites/711/Appareils%20photo%2C%20cam%C3%A9ras%20et%20t%C3%A9l%C3%A9viseurs?lotGroupTheme=all&amp;offset=0">
# <i class="fa fa-angle-right"></i>Appareils photo, caméras et téléviseurs</a>
# </li>
# <li>
# <a href="/specialites/132/cannes?lotGroupTheme=all&amp;offset=0">
# <i class="fa fa-angle-right"></i>Cannes </a>
# </li>
# <li>
# <a href="/specialites/49/Flacons%20et%20parfums?lotGroupTheme=all&amp;offset=0">
# <i class="fa fa-angle-right"></i>Flacons et parfums</a>
# </li>
# <li>
# <a href="/specialites/74/Histoire%20Naturelle?lotGroupTheme=all&amp;offset=0">
# <i class="fa fa-angle-right"></i>Histoire Naturelle</a>
# </li>
# <li>
# <a href="/specialites/133/Instruments%20scientifiques?lotGroupTheme=all&amp;offset=0">
# <i class="fa fa-angle-right"></i>Instruments scientifiques</a>
# </li>
# <li>
# <a href="/specialites/707/Musique?lotGroupTheme=all&amp;offset=0">
# <i class="fa fa-angle-right"></i>Musique</a>
# </li>
# <li>
# <a href="/specialites/273/Panneaux%20publicitaires%20et%20plaques%20%C3%A9maill%C3%A9es?lotGroupTheme=all&amp;offset=0">
# <i class="fa fa-angle-right"></i>Panneaux publicitaires et plaques émaillées</a>
# </li>
# <li>
# <a href="/specialites/82/Pipes%2C%20briquets%20et%20univers%20du%20tabac?lotGroupTheme=all&amp;offset=0">
# <i class="fa fa-angle-right"></i>Pipes, briquets et univers du tabac</a>
# </li>
# <li>
# <a href="/specialites/712/Stylos%2C%20presse-papiers%20et%20encriers?lotGroupTheme=all&amp;offset=0">
# <i class="fa fa-angle-right"></i>Stylos, presse-papiers et encriers</a>
# </li>
# <li>
# <a href="/specialites/36/Timbres?lotGroupTheme=all&amp;offset=0">
# <i class="fa fa-angle-right"></i>Timbres</a>
# </li>
# <li>
# <a href="/specialites/714/Voitures%2C%20v%C3%A9los%20et%20autres?lotGroupTheme=all&amp;offset=0">
# <i class="fa fa-angle-right"></i>Voitures, vélos et autres</a>
# </li>
# </ul>
# </div>
# <div class="col-sm-12 col-md-7">
# <div class="col-sm-12 col-md-6 noPaddingLeft">
# <ul class="wstliststy02 clearfix">
# <li class="wstheading clearfix">
# <a href="/specialites/203/Livres%20et%20Manuscrits?lotGroupTheme=all&amp;offset=0">
#                                                         Livres et Manuscrits</a>
# </li>
# <li>
# <a href="/specialites/27/Bandes%20dessin%C3%A9es?lotGroupTheme=all&amp;offset=0">
# <i class="fa fa-angle-right"></i>Bandes dessinées</a>
# </li>
# <li>
# <a href="/specialites/352/Cartes%20de%20g%C3%A9ographie?lotGroupTheme=all&amp;offset=0">
# <i class="fa fa-angle-right"></i>Cartes de géographie</a>
# </li>
# <li>
# <a href="/specialites/46/Cartes%20postales?lotGroupTheme=all&amp;offset=0">
# <i class="fa fa-angle-right"></i>Cartes postales</a>
# </li>
# <li>
# <a href="/specialites/665/lettres-et-autographes?lotGroupTheme=all&amp;offset=0">
# <i class="fa fa-angle-right"></i>Lettres et autographes </a>
# </li>
# <li>
# <a href="/specialites/203/Livres%20et%20Manuscrits?lotGroupTheme=all&amp;offset=0">
# <i class="fa fa-angle-right"></i>Livres et Manuscrits</a>
# </li>
# <li>
# <a href="/specialites/765/Livres%20religieux?lotGroupTheme=all&amp;offset=0">
# <i class="fa fa-angle-right"></i>Livres religieux</a>
# </li>
# </ul>
# </div>
# <div class="col-sm-12 col-md-6 noPaddingLeft">
# <ul class="wstliststy02 clearfix">
# <li class="wstheading clearfix">
# <a href="/specialites/26/Armes%2C%20chasse%20et%20militaria?lotGroupTheme=all&amp;offset=0">
#                                                         Armes, chasse et militaria</a>
# </li>
# <li>
# <a href="/specialites/671/Armes?lotGroupTheme=all&amp;offset=0">
# <i class="fa fa-angle-right"></i>Armes</a>
# </li>
# <li>
# <a href="/specialites/672/Casques%20et%20uniformes?lotGroupTheme=all&amp;offset=0">
# <i class="fa fa-angle-right"></i>Casques et uniformes</a>
# </li>
# <li>
# <a href="/specialites/282/Chasse%20%28sur%20le%20th%C3%A8me%20de%29?lotGroupTheme=all&amp;offset=0">
# <i class="fa fa-angle-right"></i>Chasse (sur le thème de)</a>
# </li>
# <li>
# <a href="/specialites/674/Drapeaux%20et%20troph%C3%A9es?lotGroupTheme=all&amp;offset=0">
# <i class="fa fa-angle-right"></i>Drapeaux et trophées</a>
# </li>
# <li>
# <a href="/specialites/675/Souvenirs%20historiques?lotGroupTheme=all&amp;offset=0">
# <i class="fa fa-angle-right"></i>Souvenirs historiques</a>
# </li>
# <li>
# <a href="/specialites/325/M%C3%A9dailles%20et%20insignes?lotGroupTheme=all&amp;offset=0">
# <i class="fa fa-angle-right"></i>Médailles et insignes</a>
# </li>
# </ul>
# </div>
# <div class="col-sm-12 col-md-6 noPaddingLeft">
# <ul class="wstliststy02 clearfix">
# <li class="wstheading clearfix">
# <a href="/specialites/615/Jouets%20et%20maquettes?lotGroupTheme=all&amp;offset=0">
#                                                         Jouets et maquettes</a>
# </li>
# <li>
# <a href="/specialites/371/Jeux%20de%20soci%C3%A9t%C3%A9?lotGroupTheme=all&amp;offset=0">
# <i class="fa fa-angle-right"></i>Jeux de société</a>
# </li>
# <li>
# <a href="/specialites/661/Jeux?lotGroupTheme=all&amp;offset=0">
# <i class="fa fa-angle-right"></i>Jeux</a>
# </li>
# <li>
# <a href="/specialites/660/Maquettes%20et%20mod%C3%A8les%20r%C3%A9duits?lotGroupTheme=all&amp;offset=0">
# <i class="fa fa-angle-right"></i>Maquettes et modèles réduits</a>
# </li>
# <li>
# <a href="/specialites/662/Poup%C3%A9es%2C%20peluches%20et%20jouets?lotGroupTheme=all&amp;offset=0">
# <i class="fa fa-angle-right"></i>Poupées, peluches et jouets</a>
# </li>
# </ul>
# </div>
# <div class="col-sm-12 col-md-6 noPaddingLeft">
# <ul class="wstliststy02 clearfix">
# <li class="wstheading clearfix">
# <a href="/specialites/14/Numismatique?lotGroupTheme=all&amp;offset=0">
#                                                         Numismatique</a>
# </li>
# <li>
# <a href="/specialites/700/lingots?lotGroupTheme=all&amp;offset=0">
# <i class="fa fa-angle-right"></i>Lingots </a>
# </li>
# <li>
# <a href="/specialites/699/Pi%C3%A8ces%20et%20billets?lotGroupTheme=all&amp;offset=0">
# <i class="fa fa-angle-right"></i>Pièces et billets</a>
# </li>
# </ul>
# </div>
# </div>
# </div>
# </div>
# </div>
# </li>
# <li aria-haspopup="true" class="wscatmain"><span class="wsmenu-click"><i class="wsmenu-arrow"></i></span>
# <a class="navtext c-cat2" href="/specialites/1051/Mobilier%20%26%20Objets%20d%27art?lotGroupTheme=all&amp;offset=0">
# <span>Mobilier &amp; Objets d'art</span></a>
# <div class="wsmegamenu clearfix">
# <div class="container-fluid">
# <div class="row">
# <div class="col-sm-12 col-md-3">
# <ul class="wstliststy02 clearfix">
# <li class="wstheading clearfix">
# <a href="/specialites/199/Mobilier?lotGroupTheme=all&amp;offset=0">
#                                                     Mobilier</a>
# </li>
# <li>
# <a href="/specialites/677/Biblioth%C3%A8ques?lotGroupTheme=all&amp;offset=0">
# <i class="fa fa-angle-right"></i>Bibliothèques</a>
# </li>
# <li>
# <a href="/specialites/678/Buffets%20et%20enfilades?lotGroupTheme=all&amp;offset=0">
# <i class="fa fa-angle-right"></i>Buffets et enfilades</a>
# </li>
# <li>
# <a href="/specialites/679/Bureaux?lotGroupTheme=all&amp;offset=0">
# <i class="fa fa-angle-right"></i>Bureaux</a>
# </li>
# <li>
# <a href="/specialites/682/Coffres?lotGroupTheme=all&amp;offset=0">
# <i class="fa fa-angle-right"></i>Coffres</a>
# </li>
# <li>
# <a href="/specialites/684/Consoles%20et%20encoignures?lotGroupTheme=all&amp;offset=0">
# <i class="fa fa-angle-right"></i>Consoles et encoignures</a>
# </li>
# <li>
# <a href="/specialites/691/Ensembles%20de%20mobilier?lotGroupTheme=all&amp;offset=0">
# <i class="fa fa-angle-right"></i>Ensembles de mobilier</a>
# </li>
# <li>
# <a href="/specialites/686/Lits?lotGroupTheme=all&amp;offset=0">
# <i class="fa fa-angle-right"></i>Lits</a>
# </li>
# <li>
# <a href="/specialites/687/Paravents?lotGroupTheme=all&amp;offset=0">
# <i class="fa fa-angle-right"></i>Paravents</a>
# </li>
# <li>
# <a href="/specialites/689/Tables?lotGroupTheme=all&amp;offset=0">
# <i class="fa fa-angle-right"></i>Tables</a>
# </li>
# </ul>
# </div>
# <div class="col-sm-12 col-md-3">
# <ul class="wstliststy02 clearfix">
# <li class="wstheading clearfix">
# <a href="/specialites/230/Objets%20d%27Art?lotGroupTheme=all&amp;offset=0">
#                                                     Objets d'Art</a>
# </li>
# <li>
# <a href="/specialites/67/Cadres%20anciens%20et%20modernes?lotGroupTheme=all&amp;offset=0">
# <i class="fa fa-angle-right"></i>Cadres anciens et modernes</a>
# </li>
# <li>
# <a href="/specialites/153/C%C3%A9ramiques?lotGroupTheme=all&amp;offset=0">
# <i class="fa fa-angle-right"></i>Céramiques</a>
# </li>
# <li>
# <a href="/specialites/637/Coffrets%20et%20bo%C3%AEtes?lotGroupTheme=all&amp;offset=0">
# <i class="fa fa-angle-right"></i>Coffrets et boîtes</a>
# </li>
# <li>
# <a href="/specialites/37/Objets%20de%20vitrine?lotGroupTheme=all&amp;offset=0">
# <i class="fa fa-angle-right"></i>Objets de vitrine</a>
# </li>
# <li>
# <a href="/specialites/638/Miroirs?lotGroupTheme=all&amp;offset=0">
# <i class="fa fa-angle-right"></i>Miroirs</a>
# </li>
# <li>
# <a href="/specialites/41/Tapis?lotGroupTheme=all&amp;offset=0">
# <i class="fa fa-angle-right"></i>Tapis</a>
# </li>
# <li>
# <a href="/specialites/643/Vases?lotGroupTheme=all&amp;offset=0">
# <i class="fa fa-angle-right"></i>Vases</a>
# </li>
# </ul>
# </div>
# <div class="col-sm-12 col-md-3">
# <ul class="wstliststy02 clearfix">
# <li class="wstheading clearfix">
# <a href="/specialites/617/Luminaires?lotGroupTheme=all&amp;offset=0">
#                                                     Luminaires</a>
# </li>
# <li>
# <a href="/specialites/666/Appliques?lotGroupTheme=all&amp;offset=0">
# <i class="fa fa-angle-right"></i>Appliques</a>
# </li>
# <li>
# <a href="/specialites/667/Chandeliers%2C%20flambeaux%20et%20cand%C3%A9labres?lotGroupTheme=all&amp;offset=0">
# <i class="fa fa-angle-right"></i>Chandeliers, flambeaux et candélabres</a>
# </li>
# <li>
# <a href="/specialites/668/Lampadaire?lotGroupTheme=all&amp;offset=0">
# <i class="fa fa-angle-right"></i>Lampadaire</a>
# </li>
# <li>
# <a href="/specialites/669/Lampes%20et%20lanternes?lotGroupTheme=all&amp;offset=0">
# <i class="fa fa-angle-right"></i>Lampes et lanternes</a>
# </li>
# <li>
# <a href="/specialites/670/Lustres%20et%20suspensions?lotGroupTheme=all&amp;offset=0">
# <i class="fa fa-angle-right"></i>Lustres et suspensions</a>
# </li>
# </ul>
# </div>
# <div class="col-sm-12 col-md-3">
# <ul class="wstliststy02 clearfix">
# <li class="wstheading clearfix">
# <a href="/specialites/625/Si%C3%A8ges?lotGroupTheme=all&amp;offset=0">
#                                                     Sièges</a>
# </li>
# <li>
# <a href="/specialites/717/Berg%C3%A8res?lotGroupTheme=all&amp;offset=0">
# <i class="fa fa-angle-right"></i>Bergères</a>
# </li>
# <li>
# <a href="/specialites/718/Chaises?lotGroupTheme=all&amp;offset=0">
# <i class="fa fa-angle-right"></i>Chaises</a>
# </li>
# <li>
# <a href="/specialites/716/Canap%C3%A9s%20et%20banquettes?lotGroupTheme=all&amp;offset=0">
# <i class="fa fa-angle-right"></i>Canapés et banquettes</a>
# </li>
# <li>
# <a href="/specialites/719/Fauteuils?lotGroupTheme=all&amp;offset=0">
# <i class="fa fa-angle-right"></i>Fauteuils</a>
# </li>
# <li>
# <a href="/specialites/720/Tabourets?lotGroupTheme=all&amp;offset=0">
# <i class="fa fa-angle-right"></i>Tabourets</a>
# </li>
# </ul>
# </div>
# </div>
# </div>
# </div>
# </li>
# <li aria-haspopup="true" class="wscatmain"><span class="wsmenu-click"><i class="wsmenu-arrow"></i></span>
# <a class="navtext c-cat1" href="/specialites/1050/Beaux%20Arts?lotGroupTheme=all&amp;offset=0">
# <span>Beaux Arts</span></a>
# <div class="wsmegamenu clearfix">
# <div class="container-fluid">
# <div class="row">
# <div class="col-sm-12 col-md-5">
# <ul class="wstliststy02 clearfix">
# <li class="wstheading clearfix">
# <a href="/specialites/626/Tableaux?lotGroupTheme=all&amp;offset=0">
#                                                     Tableaux</a>
# </li>
# <li>
# <a href="/specialites/30/Ic%C3%B4nes?lotGroupTheme=all&amp;offset=0">
# <i class="fa fa-angle-right"></i>Icônes</a>
# </li>
# <li>
# <a href="/specialites/156/Tableaux%20anciens%20%28avant%201870%29?lotGroupTheme=all&amp;offset=0">
# <i class="fa fa-angle-right"></i>Tableaux anciens (avant 1870)</a>
# </li>
# <li>
# <a href="/specialites/39/Tableaux%20impressionnistes%20et%20modernes?lotGroupTheme=all&amp;offset=0">
# <i class="fa fa-angle-right"></i>Tableaux impressionnistes et modernes</a>
# </li>
# <li>
# <a href="/specialites/75/Tableaux%20apr%C3%A8s%20guerre%20et%20contemporains?lotGroupTheme=all&amp;offset=0">
# <i class="fa fa-angle-right"></i>Tableaux après guerre et contemporains</a>
# </li>
# </ul>
# </div>
# <div class="col-sm-12 col-md-3">
# <ul class="wstliststy02 clearfix">
# <li class="wstheading clearfix">
# <a href="/specialites/164/Arts%20graphiques?lotGroupTheme=all&amp;offset=0">
#                                                     Arts graphiques</a>
# </li>
# <li>
# <a href="/specialites/25/Affiches?lotGroupTheme=all&amp;offset=0">
# <i class="fa fa-angle-right"></i>Affiches</a>
# </li>
# <li>
# <a href="/specialites/310/Aquarelles?lotGroupTheme=all&amp;offset=0">
# <i class="fa fa-angle-right"></i>Aquarelles</a>
# </li>
# <li>
# <a href="/specialites/50/Lithographies?lotGroupTheme=all&amp;offset=0">
# <i class="fa fa-angle-right"></i>Lithographies</a>
# </li>
# <li>
# <a href="/specialites/28/%C5%92uvres%20sur%20papier?lotGroupTheme=all&amp;offset=0">
# <i class="fa fa-angle-right"></i>Œuvres sur papier</a>
# </li>
# <li>
# <a href="/specialites/21/Photographies?lotGroupTheme=all&amp;offset=0">
# <i class="fa fa-angle-right"></i>Photographies</a>
# </li>
# <li>
# <a href="/specialites/234/Street%20Art%2C%20graffiti?lotGroupTheme=all&amp;offset=0">
# <i class="fa fa-angle-right"></i>Street Art, graffiti</a>
# </li>
# </ul>
# </div>
# <div class="col-sm-12 col-md-4">
# <ul class="wstliststy02 clearfix">
# <li class="wstheading clearfix">
# <a href="/specialites/40/Sculptures%2C%20marbres%20et%20bronzes?lotGroupTheme=all&amp;offset=0">
#                                                     Sculptures, marbres et bronzes</a>
# </li>
# <li>
# <a href="/specialites/635/Bronzes?lotGroupTheme=all&amp;offset=0">
# <i class="fa fa-angle-right"></i>Bronzes</a>
# </li>
# <li>
# <a href="/specialites/803/Sculptures%20en%20bois?lotGroupTheme=all&amp;offset=0">
# <i class="fa fa-angle-right"></i>Sculptures en bois</a>
# </li>
# <li>
# <a href="/specialites/800/Sculptures%20en%20marbre?lotGroupTheme=all&amp;offset=0">
# <i class="fa fa-angle-right"></i>Sculptures en marbre</a>
# </li>
# <li>
# <a href="/specialites/801/Sculptures%20en%20pl%C3%A2tre?lotGroupTheme=all&amp;offset=0">
# <i class="fa fa-angle-right"></i>Sculptures en plâtre</a>
# </li>
# <li>
# <a href="/specialites/802/Sculptures%20en%20terre%20cuite?lotGroupTheme=all&amp;offset=0">
# <i class="fa fa-angle-right"></i>Sculptures en terre cuite</a>
# </li>
# </ul>
# </div>
# </div>
# </div>
# </div>
# </li>
# <li aria-haspopup="true" class="wsmdv menu-mobile-spec">
# <a class="dsi-modal-link navtext" data-dsi-url="/publicPasseport/publicLoginModal2?redirUri=%2Frecherche%2Flots%3Fquery%3Dappareil+photo" data-toggle="modal" href="#modal-content">
# <span>Connexion</span>
# </a>
# </li>
# <li class="menu-mobile-spec">
# <div class="floatRight choixLangue">
# <form id="dsi-save-language-form">
# <input id="dsi-redirect-url" name="url" type="hidden" value="/en/search/lots?query=appareil+photo"/>
# <input id="dsi-save-language-url" type="hidden" value="/passeport/saveLanguage"/>
# <select class="dsi-form-elm form-control" id="dsi-language" name="lang" onchange="this.form.submit()">
# <option selected="" value="fr">FR</option>
# <option value="en">EN</option>
# <option value="zh">中文</option>
# </select>
# </form>
# </div>
# </li>
# </ul>
# </nav>
# </div>
# </div>
# </div>
# </div>
# </div>
# </div>
# </div>
# </div>
# <div class="page-wrapper-row full-height">
# <div id="top"></div>
# <div class="page-wrapper-middle">
# <div class="page-container">
# <div class="page-content-wrapper">
# <div class="page-content padding0">
# <div class="container-fluid">
# <h1 class="alignCenter">
#             Recherche pour "appareil photo"
#
#                 <a class="dsi-modal-link" data-dsi-url="/alert/createModalData?query=appareil+photo&amp;mode=liste&amp;max=50&amp;offset=0&amp;theme=all&amp;cps=all&amp;venteType=all" data-toggle="modal" href="#modal-content" style="padding-right:0; padding-bottom:0;">
# <span class="btn mini secondary marginLeft15">
# <i class="fa fa-bell-o"></i> Créer une alerte " <span class="litzt600">appareil photo</span> "
#                     </span>
# </a>
# </h1>
# </div>
# <div class="PageListing container">
# <div id="list-lots">
# <div class="col-xs-4 col-sm-3 noPaddingLeft">
# <form action="/recherche/lots?id=#top" class="form-inline taille_120" id="searchForm" method="get">
# <script src="/js/vars" type="text/javascript"></script>
# <div class="col-xs-12 padding0 filtreCalendrier printHide">
# <div class="navbar yamm navbar-default">
# <!--Specialite categorie fille-->
# <div class="filter-reset">
# <a class="btn mini ghost filter marginTop5" href="/recherche/lots?id=&amp;theme=&amp;query=appareil+photo&amp;offset=0&amp;refurl=&amp;isAdvancedSearch="><i aria-hidden="true" class="fa fa-trash-o marginRight10"></i>Effacer tous les filtres</a>
# </div>
# <div class="clear"></div>
# <div class="noPaddingLeft noPaddingRight">
# <div class="noPaddingLeft noPaddingRight navbar-collapse collapse" id="navbar-collapse-1">
# <ul class="nav nav-pills navbar-nav">
# <!--specialite-->
# <input name="query" type="hidden" value="appareil photo"/>
# <!--artiste + recherche-->
# <div class="portletSousFiltre">
# <div class="portlet light">
# <div class="portlet-title">
# <div class="tools">
# <a class="collapse" data-original-title="" href="" title=""><h3><i aria-hidden="true" class="fa fa-sort-desc"></i> Date</h3></a>
# </div>
# </div>
# <div class="portlet-body marginTop10">
# <div class="checkbox-wrapper">
# <div class="dsi-selectDate">
# <span class="multiselect-native-select"><select id="selectDate" multiple="multiple" name="dateSelect">
# <option value="1612051200-1612137600">Demain </option>
# <option value="1612224000-1612310400">mar. 02 févr. </option>
# <option value="1612396800-1612483200">jeu. 04 févr. </option>
# <option value="1612483200-1612569600">ven. 05 févr. </option>
# <option value="1612569600-1612656000">sam. 06 févr. </option>
# <option value="1612742400-1612828800">08/02/2021 - 09/02/2021 </option>
# <option value="1612828800-1613433600">09/02/2021 - 16/02/2021 </option>
# </select><div id="selectDate"><ul class="multiselect-container checkbox-list"><li class="multiselect-item multiselect-filter" value="0"><div class="input-group"><span class="input-group-addon"><i class="glyphicon glyphicon-search"></i></span><input class="form-control multiselect-search" placeholder="Recherche" type="text"/><span class="input-group-btn"><button class="btn btn-default multiselect-clear-filter" type="button"><i class="glyphicon glyphicon-remove-circle"></i></button></span></div></li><li><a tabindex="0"><label class="checkbox" title="Demain "><input class="css-checkbox" type="checkbox" value="1612051200-1612137600"/> Demain <span class="tag"> 1</span></label></a></li><li><a tabindex="0"><label class="checkbox" title="mar. 02 févr. "><input class="css-checkbox" type="checkbox" value="1612224000-1612310400"/> mar. 02 févr. <span class="tag"> 4</span></label></a></li><li><a tabindex="0"><label class="checkbox" title="jeu. 04 févr. "><input class="css-checkbox" type="checkbox" value="1612396800-1612483200"/> jeu. 04 févr. <span class="tag"> 2</span></label></a></li><li><a tabindex="0"><label class="checkbox" title="ven. 05 févr. "><input class="css-checkbox" type="checkbox" value="1612483200-1612569600"/> ven. 05 févr. <span class="tag"> 2</span></label></a></li><li><a tabindex="0"><label class="checkbox" title="sam. 06 févr. "><input class="css-checkbox" type="checkbox" value="1612569600-1612656000"/> sam. 06 févr. <span class="tag"> 2</span></label></a></li><li><a tabindex="0"><label class="checkbox" title="08/02/2021 - 09/02/2021 "><input class="css-checkbox" type="checkbox" value="1612742400-1612828800"/> 08/02/2021 - 09/02/2021 <span class="tag"> 85</span></label></a></li><li><a tabindex="0"><label class="checkbox" title="09/02/2021 - 16/02/2021 "><input class="css-checkbox" type="checkbox" value="1612828800-1613433600"/> 09/02/2021 - 16/02/2021 <span class="tag"> 6</span></label></a></li></ul></div></span>
# </div>
# </div>
# </div>
# </div>
# </div>
# <li class="main filterlieu">
# <div class="portletSousFiltre">
# <div class="portlet light">
# <div class="portlet-title">
# <div class="tools">
# <a class="collapse" data-original-title="" href="" title=""><h3 class="capitalize"><i aria-hidden="true" class="fa fa-sort-desc"></i> Lieu</h3></a>
# </div>
# </div>
# <div class="portlet-body">
# <div class="yamm-content nolimit">
# <div class="checkbox-wrapper">
# <div class="dsi-selectLieu">
# <span class="multiselect-native-select"><select id="selectLieu" multiple="multiple" name="lieuxExpo">
# <option value="HOTEL-DROUOT">Hôtel Drouot</option>
# <option value="PARIS">Paris</option>
# <option value="75">France</option>
# <option value="109">Italie</option>
# <option value="140">Monaco</option>
# </select><div id="selectLieu"><ul class="multiselect-container checkbox-list"><li class="multiselect-item multiselect-filter" value="0"><div class="input-group"><span class="input-group-addon"><i class="glyphicon glyphicon-search"></i></span><input class="form-control multiselect-search" placeholder="Recherche" type="text"/><span class="input-group-btn"><button class="btn btn-default multiselect-clear-filter" type="button"><i class="glyphicon glyphicon-remove-circle"></i></button></span></div></li><li><a tabindex="0"><label class="checkbox" title="Hôtel Drouot"><input class="css-checkbox" type="checkbox" value="HOTEL-DROUOT"/> Hôtel Drouot<span class="tag"> 3</span></label></a></li><li><a tabindex="0"><label class="checkbox" title="Paris"><input class="css-checkbox" type="checkbox" value="PARIS"/> Paris<span class="tag"> 4</span></label></a></li><li><a tabindex="0"><label class="checkbox" title="France"><input class="css-checkbox" type="checkbox" value="75"/> France<span class="tag"> 99</span></label></a></li><li><a tabindex="0"><label class="checkbox" title="Italie"><input class="css-checkbox" type="checkbox" value="109"/> Italie<span class="tag"> 1</span></label></a></li><li><a tabindex="0"><label class="checkbox" title="Monaco"><input class="css-checkbox" type="checkbox" value="140"/> Monaco<span class="tag"> 2</span></label></a></li></ul></div></span>
# </div>
# </div>
# </div>
# </div>
# </div>
# </div>
# </li>
# <!--artiste + recherche-->
# <li class="main">
# <div class="portletSousFiltre">
# <div class="portlet light">
# <div class="portlet-title">
# <div class="tools">
# <a class="collapse" data-original-title="" href="" title=""><h3><i aria-hidden="true" class="fa fa-sort-desc"></i> Types de ventes</h3></a>
# </div>
# </div>
# <div class="portlet-body">
# <div class="dsi-type-sale marginTop10">
# <label class="marginRight20 checked checked">
# <div class="iradio_minimal checked" style="position: relative;"><input checked="" class="searchautosubmit" name="venteType" style="position: absolute; top: -20%; left: -20%; display: block; width: 140%; height: 140%; margin: 0px; padding: 0px; background: rgb(255, 255, 255); border: 0px; opacity: 0;" type="radio" value="all"/><ins class="iCheck-helper" style="position: absolute; top: -20%; left: -20%; display: block; width: 140%; height: 140%; margin: 0px; padding: 0px; background: rgb(255, 255, 255); border: 0px; opacity: 0;"></ins></div>
# <span class="labelTypeVente">Toutes les ventes</span>
# </label>
# <div class="clear"></div>
# <label class="tooltips" data-container="body" data-original-title="Ventes Live uniquement" data-placement="right">
# <div class="iradio_minimal" style="position: relative;"><input class="searchautosubmit" name="venteType" style="position: absolute; top: -20%; left: -20%; display: block; width: 140%; height: 140%; margin: 0px; padding: 0px; background: rgb(255, 255, 255); border: 0px; opacity: 0;" type="radio" value="live"/><ins class="iCheck-helper" style="position: absolute; top: -20%; left: -20%; display: block; width: 140%; height: 140%; margin: 0px; padding: 0px; background: rgb(255, 255, 255); border: 0px; opacity: 0;"></ins></div>
# <span class="labelTypeVente">Ventes Live</span>
# </label>
# <div class="clear"></div>
# <label class="tooltips" data-container="body" data-original-title="Ventes Online uniquement" data-placement="right">
# <div class="iradio_minimal" style="position: relative;"><input class="searchautosubmit" name="venteType" style="position: absolute; top: -20%; left: -20%; display: block; width: 140%; height: 140%; margin: 0px; padding: 0px; background: rgb(255, 255, 255); border: 0px; opacity: 0;" type="radio" value="online"/><ins class="iCheck-helper" style="position: absolute; top: -20%; left: -20%; display: block; width: 140%; height: 140%; margin: 0px; padding: 0px; background: rgb(255, 255, 255); border: 0px; opacity: 0;"></ins></div>
# <span class="labelTypeVente">Ventes Online</span>
# </label>
# <div class="clear"></div>
# <label class="tooltips" data-container="body" data-original-title="Ventes Buy Now uniquement" data-placement="right">
# <div class="iradio_minimal" style="position: relative;"><input class="searchautosubmit" name="venteType" style="position: absolute; top: -20%; left: -20%; display: block; width: 140%; height: 140%; margin: 0px; padding: 0px; background: rgb(255, 255, 255); border: 0px; opacity: 0;" type="radio" value="buynow"/><ins class="iCheck-helper" style="position: absolute; top: -20%; left: -20%; display: block; width: 140%; height: 140%; margin: 0px; padding: 0px; background: rgb(255, 255, 255); border: 0px; opacity: 0;"></ins></div>
# <span class="labelTypeVente">Ventes Buy Now</span>
# </label>
# </div>
# </div>
# </div>
# </div>
# </li>
# <!--vente-->
# <!--artiste + recherche-->
# <li class="main btFiltrePrices">
# <div class="portletSousFiltre">
# <div class="portlet light">
# <div class="portlet-title">
# <div class="tools">
# <a class="collapse" data-original-title="" href="" title=""><h3><i aria-hidden="true" class="fa fa-sort-desc"></i> Estimation</h3></a>
# </div>
# </div>
# <div class="portlet-body">
# <label class="marginTop10">
# <input class="priceFilter" name="minEstim" placeholder="Prix min" type="number" value=""/>
# <input class="priceFilter" name="maxEstim" placeholder="Prix max" type="number" value=""/>
# </label>
# </div>
# </div>
# </div>
# </li>
# <li class="yamm-fw main">
# <link href="/assets/jquery-grumble/grumble.min-1ae644b0d7198c1d405308e8be3f2673.css" rel="stylesheet" type="text/css"/>
# <div class="portletSousFiltre">
# <div class="portlet light">
# <div class="portlet-title">
# <div class="tools">
# <a class="collapse" data-original-title="" href="" title=""><h3><i aria-hidden="true" class="fa fa-sort-desc"></i> Thématiques</h3></a>
# </div>
# </div>
# <div class="portlet-body">
# <div class="yamm-content nolimit">
# <div>
# <div class="checkbox-wrapper">
# <span class="multiselect-native-select"><select id="selectCat" multiple="multiple" name="categorie">
# <option class="parentCat" value="203">Livres et Manuscrits</option>
# <option class="childCat" value="77">Livres, manuscrits</option>
# <option class="childCat" value="765">Livres religieux</option>
# <option class="parentCat" value="206">Objets de collection</option>
# <option class="childCat" value="711">Appareils photo, caméras et téléviseurs</option>
# <option class="parentCat" value="230">Objets d'Art</option>
# <option class="parentCat" value="164">Arts graphiques</option>
# <option class="childCat" value="25">Affiches</option>
# <option class="childCat" value="21">Photographies</option>
# ...
#
#         // if the target of the click isn't the container nor a descendant of the container
#         if (!container.is(e.target) && container.has(e.target).length === 0) {
#             $("#dsi-modal-ordre-confirm-" + 14243506).hide();
#         }
#     });
# </script><script>
# 	function addFavorisEvent() {
# 		dataLayer.push({
# 			"event": "Event",
# 			"eventCategory":"Lot",
# 			"eventAction":"Favori",
# 			"eventLabel":"14243508"
# 		});
# 	}
#
# 	function removeFavoris(adressUrl) {
# 		$.ajax({
# 	            url: adressUrl,
# 	            success:function(data){
# 	            	window.location.reload();
# 	            },
# 				error: function(data){
#
# 		        }
# 	        });
# }
#
# </script><script type="text/javascript">
#     $(document).mouseup(function(e)  {
#         var container = $("#dsi-modal-ordre-confirm-" + 14243508);
#
#         // if the target of the click isn't the container nor a descendant of the container
#         if (!container.is(e.target) && container.has(e.target).length === 0) {
#             $("#dsi-modal-ordre-confirm-" + 14243508).hide();
#         }
#     });
# </script><script>
# 	function addFavorisEvent() {
# 		dataLayer.push({
# 			"event": "Event",
# 			"eventCategory":"Lot",
# 			"eventAction":"Favori",
# 			"eventLabel":"14243509"
# 		});
# 	}
#
# 	function removeFavoris(adressUrl) {
# 		$.ajax({
# 	            url: adressUrl,
# 	            success:function(data){
# 	            	window.location.reload();
# 	            },
# 				error: function(data){
#
# 		        }
# 	        });
# }
#
# </script><script type="text/javascript">
#     $(document).mouseup(function(e)  {
#         var container = $("#dsi-modal-ordre-confirm-" + 14243509);
#
#         // if the target of the click isn't the container nor a descendant of the container
#         if (!container.is(e.target) && container.has(e.target).length === 0) {
#             $("#dsi-modal-ordre-confirm-" + 14243509).hide();
#         }
#     });
# </script><script>
# 	function addFavorisEvent() {
# 		dataLayer.push({
# 			"event": "Event",
# 			"eventCategory":"Lot",
# 			"eventAction":"Favori",
# 			"eventLabel":"14243511"
# 		});
# 	}
#
# 	function removeFavoris(adressUrl) {
# 		$.ajax({
# 	            url: adressUrl,
# 	            success:function(data){
# 	            	window.location.reload();
# 	            },
# 				error: function(data){
#
# 		        }
# 	        });
# }
#
# </script><script type="text/javascript">
#     $(document).mouseup(function(e)  {
#         var container = $("#dsi-modal-ordre-confirm-" + 14243511);
#
#         // if the target of the click isn't the container nor a descendant of the container
#         if (!container.is(e.target) && container.has(e.target).length === 0) {
#             $("#dsi-modal-ordre-confirm-" + 14243511).hide();
#         }
#     });
# </script><script>
# 	function addFavorisEvent() {
# 		dataLayer.push({
# 			"event": "Event",
# 			"eventCategory":"Lot",
# 			"eventAction":"Favori",
# 			"eventLabel":"14243514"
# 		});
# 	}
#
# 	function removeFavoris(adressUrl) {
# 		$.ajax({
# 	            url: adressUrl,
# 	            success:function(data){
# 	            	window.location.reload();
# 	            },
# 				error: function(data){
#
# 		        }
# 	        });
# }
#
# </script><script type="text/javascript">
#     $(document).mouseup(function(e)  {
#         var container = $("#dsi-modal-ordre-confirm-" + 14243514);
#
#         // if the target of the click isn't the container nor a descendant of the container
#         if (!container.is(e.target) && container.has(e.target).length === 0) {
#             $("#dsi-modal-ordre-confirm-" + 14243514).hide();
#         }
#     });
# </script><script>
# 	function addFavorisEvent() {
# 		dataLayer.push({
# 			"event": "Event",
# 			"eventCategory":"Lot",
# 			"eventAction":"Favori",
# 			"eventLabel":"14243542"
# 		});
# 	}
#
# 	function removeFavoris(adressUrl) {
# 		$.ajax({
# 	            url: adressUrl,
# 	            success:function(data){
# 	            	window.location.reload();
# 	            },
# 				error: function(data){
#
# 		        }
# 	        });
# }
#
# </script><script type="text/javascript">
#     $(document).mouseup(function(e)  {
#         var container = $("#dsi-modal-ordre-confirm-" + 14243542);
#
#         // if the target of the click isn't the container nor a descendant of the container
#         if (!container.is(e.target) && container.has(e.target).length === 0) {
#             $("#dsi-modal-ordre-confirm-" + 14243542).hide();
#         }
#     });
# </script><script>
# 	function addFavorisEvent() {
# 		dataLayer.push({
# 			"event": "Event",
# 			"eventCategory":"Lot",
# 			"eventAction":"Favori",
# 			"eventLabel":"14243559"
# 		});
# 	}
#
# 	function removeFavoris(adressUrl) {
# 		$.ajax({
# 	            url: adressUrl,
# 	            success:function(data){
# 	            	window.location.reload();
# 	            },
# 				error: function(data){
#
# 		        }
# 	        });
# }
#
# </script><script type="text/javascript">
#     $(document).mouseup(function(e)  {
#         var container = $("#dsi-modal-ordre-confirm-" + 14243559);
#
#         // if the target of the click isn't the container nor a descendant of the container
#         if (!container.is(e.target) && container.has(e.target).length === 0) {
#             $("#dsi-modal-ordre-confirm-" + 14243559).hide();
#         }
#     });
# </script><script>
# 	function addFavorisEvent() {
# 		dataLayer.push({
# 			"event": "Event",
# 			"eventCategory":"Lot",
# 			"eventAction":"Favori",
# 			"eventLabel":"14243560"
# 		});
# 	}
#
# 	function removeFavoris(adressUrl) {
# 		$.ajax({
# 	            url: adressUrl,
# 	            success:function(data){
# 	            	window.location.reload();
# 	            },
# 				error: function(data){
#
# 		        }
# 	        });
# }
#
# </script><script type="text/javascript">
#     $(document).mouseup(function(e)  {
#         var container = $("#dsi-modal-ordre-confirm-" + 14243560);
#
#         // if the target of the click isn't the container nor a descendant of the container
#         if (!container.is(e.target) && container.has(e.target).length === 0) {
#             $("#dsi-modal-ordre-confirm-" + 14243560).hide();
#         }
#     });
# </script><script>
# 	function addFavorisEvent() {
# 		dataLayer.push({
# 			"event": "Event",
# 			"eventCategory":"Lot",
# 			"eventAction":"Favori",
# 			"eventLabel":"14243562"
# 		});
# 	}
#
# 	function removeFavoris(adressUrl) {
# 		$.ajax({
# 	            url: adressUrl,
# 	            success:function(data){
# 	            	window.location.reload();
# 	            },
# 				error: function(data){
#
# 		        }
# 	        });
# }
#
# </script><script type="text/javascript">
#     $(document).mouseup(function(e)  {
#         var container = $("#dsi-modal-ordre-confirm-" + 14243562);
#
#         // if the target of the click isn't the container nor a descendant of the container
#         if (!container.is(e.target) && container.has(e.target).length === 0) {
#             $("#dsi-modal-ordre-confirm-" + 14243562).hide();
#         }
#     });
# </script><script>
# 	$(document).on('change', '#pageSelect', function() {
# 			window.location.href=$(this).val()
# 	});
# </script><script src="/assets/ordre-db37e3a461262fe3f9912ce928d238c3.js"></script><script>
#     $('.oc-catalogue').owlCarousel({
#     items:1,
#     lazyLoad:true,
#     nav:true,
#     dots:false,
#     navText: ["<i class='fa fa-angle-left'></i>","<i class='fa fa-angle-right'></i>"],
#     autoplay:false,
#     })
# </script><script type="text/javascript">
#     function getCautionState() {
#         $.ajax({
#             url: "/lot/getCautionState",
#             success: function (result) {
#                 $('#dsi-cal-caution').html(result);
#                 setTimeout(function () {
#                     getCautionState();
#                 }, 30000);
#             }
#         });
#     }
#     $(document).ready(function () {
#         getCautionState();
#         if ($('body').hasClass('isNormal page-container-bg-solid page-header-menu-fixed device-xxs')) {
#             var portlets = $('.portlet .portlet-title > .tools > .collapse');
#             var elts = portlets.closest(".portlet").children(".portlet-body");
#             portlets.removeClass("collapse").addClass("expand");
#             elts.slideUp(200);
#         }
#         if ($('body').hasClass('isNormal page-container-bg-solid page-header-menu-fixed device-xs')) {
#             var portlets = $('.portlet .portlet-title > .tools > .collapse');
#             var elts = portlets.closest(".portlet").children(".portlet-body");
#             portlets.removeClass("collapse").addClass("expand");
#             elts.slideUp(200);
#         }
#
#         if ($('body').hasClass('isTablet page-container-bg-solid page-header-menu-fixed device-xxs')) {
#             var portlets = $('.portlet .portlet-title > .tools > .collapse');
#             var elts = portlets.closest(".portlet").children(".portlet-body");
#             portlets.removeClass("collapse").addClass("expand");
#             elts.slideUp(200);
#         }
#         if ($('body').hasClass('isTablet page-container-bg-solid page-header-menu-fixed device-xs')) {
#             var portlets = $('.portlet .portlet-title > .tools > .collapse');
#             var elts = portlets.closest(".portlet").children(".portlet-body");
#             portlets.removeClass("collapse").addClass("expand");
#             elts.slideUp(200);
#         }
#
#     });
# </script><script type="text/javascript">
#         $(document).ready(function() {
#             $.toast({
#               icon: 'success',
#               text : "<p class=''>Enregistrez cette recherche et recevez des  <a data-dsi-url=\"/alert/createModalData?query=appareil+photo&amp;mode=liste&amp;max=50&amp;offset=0&amp;theme=all&amp;cps=all&amp;venteType=all&amp;venteId=\" data-toggle=\"modal\" class=\"dsi-modal-link\" href=\"#modal-content\" >alertes email.</a></p>",
#               allowToastClose: true,
#               showHideTransition : 'slide',  // It can be plain, fade or slide
#               hideAfter : 10000,             // `false` to make it sticky or time in miliseconds to hide after
#               stack : 2,                     // `false` to show one stack at a time count showing the number of toasts that can be shown at once
#               textAlign : 'left',            // Alignment of text i.e. left, right, center
#               position : 'bottom-right',      // bottom-left or bottom-right or bottom-center or top-left or top-right or top-center or mid-center or an object representing the left, right, top, bottom values to position the toast on page
#             });
#         });
#     </script><script src="/assets/jquery-toast/jquery.toast-54a993c75d0e24b1d45c96b550a0f24f.js"></script><script type="text/javascript">
#         $(function() {
#             $("#dsi-save-language-form").submit(function(e) {
#                 e.preventDefault();
#                 var url = form.attr('action');
#                 var dsiSaveLanguageUrl = $("#dsi-save-language-url").val();
#                 $.ajax({
#                     type: "POST",
#                     url: dsiSaveLanguageUrl,
#                     data: form.serialize(),
#                     success: function(data){
#                         window.location.href=$("#dsi-redirect-url").val();
#                     },
#                     error: function(data){
#                         window.location.href=$("#dsi-redirect-url").val();
#                     }
#                 });
#             });
#         });
#     </script><script type="text/javascript">
#         $(function() {
#             $("#dsi-save-language-form").submit(function(e) {
#                 e.preventDefault();
#                 var url = form.attr('action');
#                 var dsiSaveLanguageUrl = $("#dsi-save-language-url").val();
#                 $.ajax({
#                     type: "POST",
#                     url: dsiSaveLanguageUrl,
#                     data: form.serialize(),
#                     success: function(data){
#                         window.location.href=$("#dsi-redirect-url").val();
#                     },
#                     error: function(data){
#                         window.location.href=$("#dsi-redirect-url").val();
#                     }
#                 });
#             });
#         });
#     </script><script type="text/javascript">
#         $(function() {
#             $("#dsi-save-language-form").submit(function(e) {
#                 e.preventDefault();
#                 var url = form.attr('action');
#                 var dsiSaveLanguageUrl = $("#dsi-save-language-url").val();
#                 $.ajax({
#                     type: "POST",
#                     url: dsiSaveLanguageUrl,
#                     data: form.serialize(),
#                     success: function(data){
#                         window.location.href=$("#dsi-redirect-url").val();
#                     },
#                     error: function(data){
#                         window.location.href=$("#dsi-redirect-url").val();
#                     }
#                 });
#             });
#         });
#     </script><script>
#     document.addEventListener('DOMContentLoaded', function(event) {
#         cookieChoices.showCookieConsentBar("En naviguant sur notre site, vous acceptez l'utilisation de cookies qui nous permettront de réaliser des analyses et de vous proposer des contenus et des annonces les plus adaptés à vos centres d'intérêts.","J'accepte", "En savoir plus", "/politiqueConfidentialite");
#     });
# </script><script>
#     $(window).scroll(function(){if($(this).scrollTop()>1){$('.backtotop').css({bottom:"145px"});}else{$('.backtotop').css({bottom:"-100px"});}});$('.backtotop').click(function(){$('html, body').animate({scrollTop:'0px'},800);return false;});
# </script>
# <div aria-hidden="true" class="modal container fade" id="modal-content" tabindex="-1"></div>
# <script type="text/javascript">
#     $(document).ready(function () {
#         $('input').not('.css-checkbox').iCheck({
#             checkboxClass: 'icheckbox_minimal',
#             radioClass: 'iradio_minimal',
#             increaseArea: '20%' // optional
#         });
#         $('.sbm input').on('ifChecked', function (event) {
#             this.form.submit();
#         });
#         $('.sbm2 input').on('ifChanged', function (event) {
#             this.form.submit();
#         });
#     });
# </script>
# <script type="text/javascript">
#     function doPollList(id,urlParam,verif,duration=30000){
#         $.post(urlParam+"/?l="+id)
#         .done(function(data){ bttUpdate(data,verif);})
#         .always(function(data) {
#             var lot_near_to_close_time = data.l.reduce((min,p)=> (min != 0 && p.t >0 && p.t < min) || (min == 0 && p.t > 0)? p.t : min, data.t);
#             if(lot_near_to_close_time != 0 && duration == 30000 && lot_near_to_close_time - data.t <= 180000 ) {
#                     duration = 5000
#                     clearTimeout(t)
#             }
#             t=setTimeout('doPollList("'+id+'","'+urlParam+'","'+verif+'","'+duration+'")',duration)
#             ;})
#         ;
#     }
# </script><div class="holder"></div></div><div aria-live="polite" class="jq-toast-wrap bottom-right" role="alert"><div class="jq-toast-single jq-has-icon jq-icon-success" style="text-align: left; display: block; overflow: hidden; height: 45.3264px; padding-top: 5.61094px; margin-top: 0px; padding-bottom: 5.61094px; margin-bottom: 2.80547px;"><span class="jq-toast-loader"></span><span class="close-jq-toast-single">×</span><p class="">Enregistrez cette recherche et recevez des  <a class="dsi-modal-link" data-dsi-url="/alert/createModalData?query=appareil+photo&amp;mode=liste&amp;max=50&amp;offset=0&amp;theme=all&amp;cps=all&amp;venteType=all&amp;venteId=" data-toggle="modal" href="#modal-content">alertes email.</a></p></div></div><div id="cookieChoiceInfo" style="position: fixed; width: 100%; background-color: rgb(51, 51, 51); color: rgb(255, 255, 255); margin: 0px; left: 0px; bottom: 0px; padding: 10px 50px; z-index: 1000; text-align: center;"><span>En naviguant sur notre site, vous acceptez l'utilisation de cookies qui nous permettront de réaliser des analyses et de vous proposer des contenus et des annonces les plus adaptés à vos centres d'intérêts.</span><a href="/politiqueConfidentialite" style="margin-left: 15px; color: rgb(255, 255, 255);" target="_blank">En savoir plus</a><a href="#" id="cookieChoiceDismiss" style="margin-left: 15px; color: rgb(255, 255, 255);">J'accepte</a></div></body></html>>

# %%
for div in soup.find('div', id='list-lots').find_all('div', class_='lot vsListe'):
    link = str(div.find('div', class_='blog-page').find_all('a')[1])
    link = link[6 + link.find('href="'):link.find('?')]
    link = BASE_URL + link
    dt = div.find('div', class_='infoDateListe').text.replace("\n", "").replace('  ', '')
    description = div.find('div', class_='product-cell').find('h5').text.replace("\n", "").replace('  ', '')
    estimation = div.find('h5', class_='Estimation').text.replace("\n", "").replace('  ', '')

# %%
str(div.find('div', class_='blog-page').find_all('a')[1])
# Out:
# '<a href="/lots/14256294?actionParam=recherche&amp;controllerParam=lot&amp;fromId=&amp;query=appareil+photo&amp;offset=0&amp;max=50">\n<div class="bgStyle">\n<div class="bgStyle jsLazyLoad loaded" data-ll-status="loaded" style=\'transform: rotate(0deg); background-image: url("https://cdn.drouot.com/d/image/lot?size=ftall&amp;path=266/111778/350a2b7214e49350f9a77224b8758a42");\'>\n</div>\n</div>\n</a>'

# %%
class Drouot:
    BASE_URL = 'https://www.drouotonline.com'
    SEARCH_URL = '/recherche/lots?query='

    def __init__(self, item: str):
        """Get results for a searches

        Args:
            item (str): Item to search
        """
        self.client = Client()
        self.url = self.BASE_URL + self.SEARCH_URL
        self.url += urllib.parse.quote_plus(item)
        self.soup = self.client.run(self.url, False, False)

        # They have pages and not infinite scroll down
        self.nb_items = self.soup.find('div', class_='toolbar') \
            .find('h4').text.replace('\n', '').replace('  ', '')
        self.nb_items = int(self.nb_items[:self.nb_items.find('résultats')])

        # Iterate trought pages
        self.soups = []
        for i in range(0, self.nb_items, 50):
            url = self.url + f"&max=50&offset={i}"
            if i == max(range(0, self.nb_items, 50)):
                self.soups.append(self.client.run(url, False, True))
            else:
                self.soups.append(self.client.run(url, False, False))

    def transform(self) -> pd.DataFrame:
        """Transform the soup response into a panda dataframe

        Returns:
            pd.DataFrame: Pandas dataframe containing :
                - item description
                - item date
                - item number
                - item price estimation
                - link to the item
        """
        dfs = []
        for soup in self.soups:
            items = soup.find('div', id='list-lots') \
                .find_all('div', class_='lot vsListe')
            lst = []
            for div in items:
                link = str(
                    div.find(
                        'div',
                        class_='blog-page').find_all('a')[1])
                link = link[6 + link.find('href="'):link.find('?')]
                link = self.BASE_URL + link
                dt = div.find(
                    'div',
                    class_='infoDateListe').text.replace(
                        "\n",
                        "").replace('  ', '')
                description = div.find(
                    'div',
                    class_='product-cell').find('h5').text.replace(
                        "\n",
                        "").replace('  ', '')
                estimation = div.find('h5', class_='Estimation')
                if estimation:
                    estimation = estimation.text.replace(
                        "\n",
                        "").replace('  ', '')
                lst += [(description, description, dt, estimation, link)]
            dfs.append(
                pd.DataFrame(
                    lst,
                    columns=[
                        'item',
                        'description',
                        'date',
                        'estimation',
                        'link']))
        return pd.concat(dfs)
